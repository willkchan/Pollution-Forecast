# %% [markdown]
# ### Preprocess data and try different feature selection techniques
# * Retain top correlated features with the target
# * Eliminate collinear features, to reduce redundancy

# %% [markdown]
# ### Import Packages

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import sys
import os
import matplotlib.pyplot as plt
import klib
import plotly.figure_factory as ff
from IPython.core.display import display
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# pd.set_option('display.max_columns', None)
# pd.reset_option('max_rows')
#np.set_printoptions(threshold=sys.maxsize)

plt.style.use('dark_background')
plt.rcParams.update({"grid.linewidth":0.5, "grid.alpha":0.5})
sns.set(style='ticks', context='talk')

# %%
# define useful function to create scatterplots of target feature against desired columns
def scatterplots(df, target, columns, ncol=None, figsize=(20, 25)):
    if ncol is None:
        ncol = len(columns)
    nrow = int(np.ceil(len(columns) / ncol))
    fig, axes = plt.subplots(nrow, ncol, figsize=figsize, squeeze=False)
    fig.subplots_adjust(wspace=0.7, hspace=0.7)
    for i, col in enumerate(columns):
        # ax = axes.flatten()[i]
        # ax.scatter(x = col, y = target, data=df, alpha=0.5)
        sns.regplot(ax=axes.flatten()[i], x=col, y=target, data=df, scatter_kws={'alpha':0.5})
        # ax.set(xlabel=col, ylabel=target)
    nsubplots = nrow * ncol
    for empty in range(i+1, nsubplots):
        axes.flatten()[empty].set_visible(False)

# %% [markdown]
# ### Load data

# %%
pm10_2017_2019 = r'../../data/processed/pm10_2017_2019'
pm10_year_diff = r'../../data/processed/pm10_year_diff'
pm10_year_pct_change = r'../../data/processed/pm10_year_pct_change'
pm10_year_diff_top_corr =  r'../../data/processed/pm10_year_diff_top_corr'
pm10_year_pct_change_top_corr = r'../../data/processed/pm10_year_pct_change_top_corr'

df_norm = pd.read_csv(pm10_2017_2019)
df_year_diff = pd.read_csv(pm10_year_diff)
df_year_diff_top = pd.read_csv(pm10_year_diff_top_corr)
df_year_pct_change = pd.read_csv(pm10_year_pct_change)
df_year_pct_change_top = pd.read_csv(pm10_year_pct_change_top_corr)

# %%
# Work with top correlated variables with our target
# this reduces number of columns from 1000

display(df_year_pct_change_top)
display(df_year_diff_top)

df = pd.merge(df_year_diff_top, df_year_pct_change_top)
df
# Out:
#       AQI_2019  Personal income (thousands of dollars) 2018_2019_pct_change  \
# 0    20.073389                                           0.030317
# 1    12.958515                                           0.055158
# 2    13.125000                                           0.034268
# 3    11.247911                                           0.029182
# 4    17.413408                                           0.042433
# ..         ...                                                ...
# 203  10.503937                                           0.037141
# 204  14.431990                                           0.023454
# 205  15.656425                                           0.027782
# 206  13.354142                                           0.034302
# 207   9.385135                                           0.020824
#
#      Per capita personal income (dollars) 2018_2019_pct_change  \
# 0                                             0.031654
# 1                                             0.038434
# 2                                             0.034342
# 3                                             0.026966
# 4                                             0.046478
# ..                                                 ...
# 203                                           0.037051
# 204                                           0.024796
# 205                                           0.023512
# 206                                           0.027690
# 207                                           0.012100
#
#      BACH_TOT_2017_2019_pct_change  \
# 0                        -0.005177
# 1                         0.104207
# 2                         0.040944
# 3                        -0.230957
# 4                         0.096472
# ..                             ...
# 203                       0.171526
# 204                       0.073753
# 205                       0.007331
# 206                       0.112467
# 207                      -0.096423
#
#      Median Household Income_2017_2019_pct_change  \
# 0                                        0.066941
# 1                                        0.093371
# 2                                        0.150067
# 3                                        0.070584
# 4                                       -0.006453
# ..                                            ...
# 203                                      0.066849
# 204                                      0.119469
# 205                                      0.102182
# 206                                      0.129018
# 207                                      0.082802
#
#      90% CI UB medh inc_2017_2019_pct_change  \
# 0                                   0.085679
# 1                                   0.107546
# 2                                   0.125771
# 3                                   0.097186
# 4                                  -0.020749
# ..                                       ...
# 203                                 0.041718
# 204                                 0.120713
# 205                                 0.113662
# 206                                 0.112862
# 207                                 0.108546
#
#      BACH_TOT_ratio_2017_2019_pct_change  \
# 0                              -0.004235
# 1                               0.069080
# 2                               0.041679
# 3                              -0.233963
# 4                               0.086319
# ..                                   ...
# 203                             0.170819
# 204                             0.080973
# 205                            -0.001584
# 206                             0.099352
# 207                            -0.099942
#
#      90% CI Lower Bound LB medh inc_2017_2019_pct_change  \
# 0                                             0.047281
# 1                                             0.077970
# 2                                             0.177317
# 3                                             0.039399
# 4                                             0.009991
# ..                                                 ...
# 203                                           0.095264
# 204                                           0.118141
# 205                                           0.090107
# 206                                           0.147585
# 207                                           0.054228
#
#      Employed_2017_2019_pct_change  TOT_MALE_ratio_2017_2019_pct_change  ...  \
# 0                         0.038350                            -0.000481  ...
# 1                         0.063602                             0.001232  ...
# 2                         0.009473                            -0.003826  ...
# 3                         0.010616                             0.000006  ...
# 4                         0.023674                            -0.001054  ...
# ..                             ...                                  ...  ...
# 203                      -0.019522                            -0.001009  ...
# 204                      -0.017047                            -0.000150  ...
# 205                      -0.006761                             0.000780  ...
# 206                       0.007338                            -0.002162  ...
# 207                       0.008860                             0.000921  ...
#
#      HWAC_FEMALE_ratio_2017_2019_pct_change  \
# 0                                  0.066156
# 1                                  0.067250
# 2                                  0.056305
# 3                                  0.028091
# 4                                  0.001100
# ..                                      ...
# 203                                0.064546
# 204                                0.046970
# 205                                0.044822
# 206                                0.028606
# 207                                0.020542
#
#      HWA_FEMALE_ratio_2017_2018_pct_change  \
# 0                                 0.032477
# 1                                 0.035598
# 2                                 0.019292
# 3                                 0.013565
# 4                                -0.000633
# ..                                     ...
# 203                               0.022456
# 204                               0.030851
# 205                               0.021305
# 206                               0.010813
# 207                               0.013586
#
#      H_FEMALE_ratio_2017_2019_pct_change  NH_MALE_ratio_2017_2019_pct_change  \
# 0                               0.069673                           -0.002724
# 1                               0.065508                           -0.001108
# 2                               0.055696                           -0.005313
# 3                               0.031366                           -0.003912
# 4                               0.001121                           -0.004857
# ..                                   ...                                 ...
# 203                             0.066122                           -0.003205
# 204                             0.045745                           -0.007886
# 205                             0.047402                           -0.001170
# 206                             0.025964                           -0.002544
# 207                             0.025336                           -0.004005
#
#      HWAC_FEMALE_ratio_2017_2018_pct_change  \
# 0                                  0.033374
# 1                                  0.036139
# 2                                  0.023307
# 3                                  0.014217
# 4                                 -0.000383
# ..                                      ...
# 203                                0.024745
# 204                                0.030850
# 205                                0.022401
# 206                                0.008189
# 207                                0.015198
#
#      H_FEMALE_ratio_2017_2018_pct_change  NH_MALE_ratio_2018_2019_pct_change  \
# 0                               0.036809                           -0.001246
# 1                               0.036086                           -0.000012
# 2                               0.015763                           -0.004204
# 3                               0.031752                            0.001109
# 4                               0.000351                           -0.007802
# ..                                   ...                                 ...
# 203                             0.026686                           -0.001818
# 204                             0.029433                           -0.003559
# 205                             0.023545                           -0.000766
# 206                             0.009373                           -0.002465
# 207                             0.018741                           -0.001480
#
#      NH_FEMALE_ratio_2018_2019_pct_change  \
# 0                               -0.001100
# 1                               -0.002554
# 2                                0.001529
# 3                               -0.003511
# 4                                0.002468
# ..                                    ...
# 203                             -0.000372
# 204                             -0.002157
# 205                             -0.001552
# 206                             -0.001158
# 207                             -0.001433
#
#      NH_FEMALE_ratio_2017_2018_pct_change  \
# 0                               -0.000907
# 1                               -0.001858
# 2                                0.000176
# 3                                0.001533
# 4                               -0.001403
# ..                                    ...
# 203                             -0.001533
# 204                             -0.005276
# 205                             -0.001512
# 206                             -0.000593
# 207                             -0.001811
#
#      NH_FEMALE_ratio_2017_2019_pct_change
# 0                               -0.002005
# 1                               -0.004407
# 2                                0.001705
# 3                               -0.001983
# 4                                0.001062
# ..                                    ...
# 203                             -0.001905
# 204                             -0.007421
# 205                             -0.003062
# 206                             -0.001750
# 207                             -0.003241
#
# [208 rows x 75 columns]
#       AQI_2019  HAA_MALE_ratio_2018_2019_diff  HAAC_MALE_ratio_2017_2019_diff  \
# 0    20.073389                       0.001227                        0.004126
# 1    12.958515                      -0.001258                       -0.004820
# 2    13.125000                       0.000885                       -0.002493
# 3    11.247911                      -0.000051                       -0.001577
# 4    17.413408                       0.002806                        0.006851
# ..         ...                            ...                             ...
# 203  10.503937                       0.002276                        0.005661
# 204  14.431990                      -0.000792                        0.001185
# 205  15.656425                      -0.000568                        0.004939
# 206  13.354142                      -0.005542                        0.021831
# 207   9.385135                       0.003346                        0.008513
#
#      HAA_MALE_ratio_2017_2019_diff  HAA_MALE_2018_2019_diff  \
# 0                         0.002594                        8
# 1                        -0.001981                       -4
# 2                         0.000067                        2
# 3                         0.006876                        0
# 4                         0.002255                        3
# ..                             ...                      ...
# 203                       0.002258                        2
# 204                       0.000715                       -8
# 205                       0.000109                       -2
# 206                       0.012354                       -5
# 207                       0.003594                        3
#
#      HIA_FEMALE_2018_2019_diff  HIAC_FEMALE_2018_2019_diff  \
# 0                           14                          24
# 1                            8                          24
# 2                           -4                         -12
# 3                          -20                         -15
# 4                            3                         -14
# ..                         ...                         ...
# 203                          3                           0
# 204                         13                          17
# 205                          7                          20
# 206                        -10                          -5
# 207                          2                           9
#
#      HIA_MALE_2018_2019_diff  HIAC_MALE_2018_2019_diff  \
# 0                        -10                        20
# 1                         -7                         4
# 2                          5                         1
# 3                         13                        28
# 4                         14                        14
# ..                       ...                       ...
# 203                       -4                         2
# 204                       21                        19
# 205                       24                        33
# 206                        2                         6
# 207                       -3                         0
#
#      HAAC_MALE_2018_2019_diff  ...  90% CI LB percent 0-17_2017_2019_diff  \
# 0                          15  ...                                -1652.0
# 1                          -9  ...                                -1018.0
# 2                         -10  ...                                -6494.0
# 3                          -5  ...                                  -28.0
# 4                          19  ...                                  334.0
# ..                        ...  ...                                    ...
# 203                         6  ...                                 -160.0
# 204                        -2  ...                                -5720.0
# 205                        16  ...                                   92.0
# 206                        -2  ...                                 -117.0
# 207                         0  ...                                 -213.0
#
#      90% CI UB 0-17_2018_2019_diff  90% CI LB All Ages_2018_2019_diff  \
# 0                            128.0                              458.0
# 1                            -25.0                             -786.0
# 2                          -3587.0                            -9877.0
# 3                           -330.0                            -3297.0
# 4                            774.0                             1971.0
# ..                             ...                                ...
# 203                         -246.0                             -567.0
# 204                        -7350.0                           -20856.0
# 205                          327.0                            -1210.0
# 206                         -354.0                              562.0
# 207                          -60.0                               29.0
#
#      Poverty Estimate, Age 0-17_2018_2019_diff  \
# 0                                       -124.0
# 1                                         67.0
# 2                                      -4095.0
# 3                                       -557.0
# 4                                        836.0
# ..                                         ...
# 203                                     -242.0
# 204                                    -7668.0
# 205                                      348.0
# 206                                     -369.0
# 207                                      -85.0
#
#      90% CI LB percent 0-17_2018_2019_diff  TOT_FEMALE_ratio_2017_2018_diff  \
# 0                                   -376.0                         0.019808
# 1                                    159.0                        -0.005348
# 2                                  -4603.0                         0.035381
# 3                                   -784.0                         0.168415
# 4                                    898.0                        -0.037888
# ..                                     ...                              ...
# 203                                 -238.0                        -0.012916
# 204                                -7986.0                        -0.017496
# 205                                  369.0                        -0.018644
# 206                                 -384.0                         0.041256
# 207                                 -110.0                        -0.007536
#
#      90% CI UB 5-17 fam_2018_2019_diff  TOT_FEMALE_ratio_2017_2019_diff  \
# 0                               -279.0                         0.022760
# 1                               -256.0                        -0.060181
# 2                              -2513.0                         0.180431
# 3                                502.0                        -0.000273
# 4                                183.0                         0.053409
# ..                                 ...                              ...
# 203                              -91.0                         0.053309
# 204                            -2459.0                         0.007248
# 205                              284.0                        -0.038357
# 206                             -263.0                         0.109764
# 207                              -56.0                        -0.046369
#
#      Poverty Estimate, Age 5-17 in Families_2018_2019_diff  \
# 0                                               -307.0
# 1                                               -266.0
# 2                                              -2802.0
# 3                                                353.0
# 4                                                236.0
# ..                                                 ...
# 203                                              -89.0
# 204                                            -2473.0
# 205                                              262.0
# 206                                             -300.0
# 207                                              -73.0
#
#      90% CI LB 5-17 fam_2018_2019_diff
# 0                               -335.0
# 1                               -276.0
# 2                              -3091.0
# 3                                204.0
# 4                                289.0
# ..                                 ...
# 203                              -87.0
# 204                            -2487.0
# 205                              240.0
# 206                             -337.0
# 207                              -90.0
#
# [208 rows x 88 columns]
#       AQI_2019  HAA_MALE_ratio_2018_2019_diff  HAAC_MALE_ratio_2017_2019_diff  \
# 0    20.073389                       0.001227                        0.004126
# 1    12.958515                      -0.001258                       -0.004820
# 2    13.125000                       0.000885                       -0.002493
# 3    11.247911                      -0.000051                       -0.001577
# 4    17.413408                       0.002806                        0.006851
# ..         ...                            ...                             ...
# 203  10.503937                       0.002276                        0.005661
# 204  14.431990                      -0.000792                        0.001185
# 205  15.656425                      -0.000568                        0.004939
# 206  13.354142                      -0.005542                        0.021831
# 207   9.385135                       0.003346                        0.008513
#
#      HAA_MALE_ratio_2017_2019_diff  HAA_MALE_2018_2019_diff  \
# 0                         0.002594                        8
# 1                        -0.001981                       -4
# 2                         0.000067                        2
# 3                         0.006876                        0
# 4                         0.002255                        3
# ..                             ...                      ...
# 203                       0.002258                        2
# 204                       0.000715                       -8
# 205                       0.000109                       -2
# 206                       0.012354                       -5
# 207                       0.003594                        3
#
#      HIA_FEMALE_2018_2019_diff  HIAC_FEMALE_2018_2019_diff  \
# 0                           14                          24
# 1                            8                          24
# 2                           -4                         -12
# 3                          -20                         -15
# 4                            3                         -14
# ..                         ...                         ...
# 203                          3                           0
# 204                         13                          17
# 205                          7                          20
# 206                        -10                          -5
# 207                          2                           9
#
#      HIA_MALE_2018_2019_diff  HIAC_MALE_2018_2019_diff  \
# 0                        -10                        20
# 1                         -7                         4
# 2                          5                         1
# 3                         13                        28
# 4                         14                        14
# ..                       ...                       ...
# 203                       -4                         2
# 204                       21                        19
# 205                       24                        33
# 206                        2                         6
# 207                       -3                         0
#
#      HAAC_MALE_2018_2019_diff  ...  HWAC_FEMALE_ratio_2017_2019_pct_change  \
# 0                          15  ...                                0.066156
# 1                          -9  ...                                0.067250
# 2                         -10  ...                                0.056305
# 3                          -5  ...                                0.028091
# 4                          19  ...                                0.001100
# ..                        ...  ...                                     ...
# 203                         6  ...                                0.064546
# 204                        -2  ...                                0.046970
# 205                        16  ...                                0.044822
# 206                        -2  ...                                0.028606
# 207                         0  ...                                0.020542
#
#      HWA_FEMALE_ratio_2017_2018_pct_change  \
# 0                                 0.032477
# 1                                 0.035598
# 2                                 0.019292
# 3                                 0.013565
# 4                                -0.000633
# ..                                     ...
# 203                               0.022456
# 204                               0.030851
# 205                               0.021305
# 206                               0.010813
# 207                               0.013586
#
#      H_FEMALE_ratio_2017_2019_pct_change  NH_MALE_ratio_2017_2019_pct_change  \
# 0                               0.069673                           -0.002724
# 1                               0.065508                           -0.001108
# 2                               0.055696                           -0.005313
# 3                               0.031366                           -0.003912
# 4                               0.001121                           -0.004857
# ..                                   ...                                 ...
# 203                             0.066122                           -0.003205
# 204                             0.045745                           -0.007886
# 205                             0.047402                           -0.001170
# 206                             0.025964                           -0.002544
# 207                             0.025336                           -0.004005
#
#      HWAC_FEMALE_ratio_2017_2018_pct_change  \
# 0                                  0.033374
# 1                                  0.036139
# 2                                  0.023307
# 3                                  0.014217
# 4                                 -0.000383
# ..                                      ...
# 203                                0.024745
# 204                                0.030850
# 205                                0.022401
# 206                                0.008189
# 207                                0.015198
#
#      H_FEMALE_ratio_2017_2018_pct_change  NH_MALE_ratio_2018_2019_pct_change  \
# 0                               0.036809                           -0.001246
# 1                               0.036086                           -0.000012
# 2                               0.015763                           -0.004204
# 3                               0.031752                            0.001109
# 4                               0.000351                           -0.007802
# ..                                   ...                                 ...
# 203                             0.026686                           -0.001818
# 204                             0.029433                           -0.003559
# 205                             0.023545                           -0.000766
# 206                             0.009373                           -0.002465
# 207                             0.018741                           -0.001480
#
#      NH_FEMALE_ratio_2018_2019_pct_change  \
# 0                               -0.001100
# 1                               -0.002554
# 2                                0.001529
# 3                               -0.003511
# 4                                0.002468
# ..                                    ...
# 203                             -0.000372
# 204                             -0.002157
# 205                             -0.001552
# 206                             -0.001158
# 207                             -0.001433
#
#      NH_FEMALE_ratio_2017_2018_pct_change  \
# 0                               -0.000907
# 1                               -0.001858
# 2                                0.000176
# 3                                0.001533
# 4                               -0.001403
# ..                                    ...
# 203                             -0.001533
# 204                             -0.005276
# 205                             -0.001512
# 206                             -0.000593
# 207                             -0.001811
#
#      NH_FEMALE_ratio_2017_2019_pct_change
# 0                               -0.002005
# 1                               -0.004407
# 2                                0.001705
# 3                               -0.001983
# 4                                0.001062
# ..                                    ...
# 203                             -0.001905
# 204                             -0.007421
# 205                             -0.003062
# 206                             -0.001750
# 207                             -0.003241
#
# [208 rows x 162 columns]

# %% [markdown]
# * This reduces number of columns that we initally use to 161 columns

# %%
# checking how varied our data columns are for df

unique = []
var = []
for col in df.columns.tolist():
    unique.append([col, df[col].nunique()])
    var.append([col, df[col].var()])
unique.sort(key = lambda x: x[1])
var.sort(key = lambda x: x[1])

display(unique[:20])
display(var[:10])
# Out:
# [['HNA_MALE_2018_2019_diff', 48],
#  ['HNAC_FEMALE_2018_2019_diff', 60],
#  ['HNAC_MALE_2018_2019_diff', 65],
#  ['HAA_FEMALE_2018_2019_diff', 66],
#  ['HAA_MALE_2018_2019_diff', 69],
#  ['HNAC_FEMALE_2017_2019_diff', 73],
#  ['HNAC_MALE_2017_2019_diff', 82],
#  ['HAA_FEMALE_2017_2019_diff', 86],
#  ['HAAC_FEMALE_2017_2018_diff', 86],
#  ['HAA_MALE_2017_2019_diff', 87],
#  ['HAAC_FEMALE_2018_2019_diff', 89],
#  ['HAAC_MALE_2017_2018_diff', 94],
#  ['HAAC_MALE_2018_2019_diff', 95],
#  ['HIA_FEMALE_2017_2018_diff', 103],
#  ['HIA_MALE_2018_2019_diff', 105],
#  ['HIA_FEMALE_2018_2019_diff', 110],
#  ['HIA_MALE_2017_2018_diff', 111],
#  ['HAAC_FEMALE_2017_2019_diff', 112],
#  ['HAAC_MALE_2017_2019_diff', 113],
#  ['IA_MALE_2017_2018_diff', 118]]
# [['TOT_FEMALE_ratio_2017_2018_pct_change', 1.0073043916858045e-06],
#  ['TOT_MALE_ratio_2017_2018_pct_change', 1.0211047386463436e-06],
#  ['TOT_MALE_ratio_2017_2019_pct_change', 2.239312408564328e-06],
#  ['TOT_FEMALE_ratio_2017_2019_pct_change', 2.244951647902704e-06],
#  ['HAA_MALE_ratio_2018_2019_diff', 9.294324299686756e-06],
#  ['NH_MALE_ratio_2018_2019_pct_change', 1.802106764406489e-05],
#  ['NH_MALE_ratio_2017_2018_pct_change', 1.814542178707539e-05],
#  ['HAA_MALE_ratio_2017_2019_diff', 1.88870213721257e-05],
#  ['NH_FEMALE_ratio_2018_2019_pct_change', 1.9100318593048414e-05],
#  ['NH_FEMALE_ratio_2017_2018_pct_change', 2.0028645476703468e-05]]

# %% [markdown]
# * It appears we have somewhat varied data
# * The variance for some variables may appear to be very close to 0, but this is because
# those column themselves contain very small values, else they would appear in the top of the list containing
# least unique counts

# %% [markdown]
# ## Drop variables that are highly colinear or multicolinear
# * retain the variable with largest correlation with the target

# %%
X = df.drop('AQI_2019', axis=1)
y = df['AQI_2019']

# %%
# this function used to remove collinear variables
# variation inflation factor quantifies the severity of multicollinearity in an ordinary least squares regression analysis
# threshold greater than 5 means highly correlated for vif

from statsmodels.stats.outliers_influence import variance_inflation_factor

def calculate_vif_(X, thresh=5.0):
    variables = list(range(X.shape[1]))
    dropped = True
    while dropped:
        dropped = False
        vif = [variance_inflation_factor(X.iloc[:, variables].values, ix)
               for ix in range(X.iloc[:, variables].shape[1])]

        maxloc = vif.index(max(vif))
        if max(vif) > thresh:
            print('dropping \'' + X.iloc[:, variables].columns[maxloc] +
                  '\' at index: ' + str(maxloc))
            del variables[maxloc]
            dropped = True

    print('Remaining variables:')
    print(X.columns[variables])
    return X.iloc[:, variables]

# %%
calculate_vif_(X)
# Out:
# /home/wkc/.local/lib/python3.8/site-packages/statsmodels/stats/outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# dropping 'HAAC_MALE_ratio_2017_2019_diff' at index: 1
# dropping 'HIA_FEMALE_2018_2019_diff' at index: 3
# dropping 'HIAC_FEMALE_2018_2019_diff' at index: 3
# dropping 'HIA_MALE_2018_2019_diff' at index: 3
# dropping 'HIAC_MALE_2018_2019_diff' at index: 3
# dropping 'HAAC_MALE_2018_2019_diff' at index: 3
# dropping 'HAAC_FEMALE_2018_2019_diff' at index: 13
# dropping 'H_MALE_2018_2019_diff' at index: 18
# dropping 'HWAC_MALE_2018_2019_diff' at index: 19
# dropping 'HWA_MALE_2018_2019_diff' at index: 19
# dropping 'H_FEMALE_2018_2019_diff' at index: 23
# dropping 'HWAC_FEMALE_2018_2019_diff' at index: 23
# dropping 'HWA_FEMALE_2018_2019_diff' at index: 24
# dropping 'IA_MALE_2018_2019_diff' at index: 29
# dropping 'IAC_MALE_2017_2018_diff' at index: 31
# dropping 'TOT_MALE_ratio_2017_2019_diff' at index: 33
# dropping 'TOT_MALE_ratio_2017_2018_diff' at index: 39
# dropping '90% CI UB 0-17_2018_2019_diff' at index: 61
# dropping '90% CI UB 5-17 fam_2018_2019_diff' at index: 65
# dropping 'NHWAC_FEMALE_ratio_2017_2019_pct_change' at index: 126
# dropping 'NHWA_MALE_ratio_2017_2019_pct_change' at index: 111
# dropping 'HWAC_FEMALE_2017_2018_pct_change' at index: 106
# dropping 'TOT_FEMALE_ratio_2017_2018_diff' at index: 64
# dropping 'H_FEMALE_2017_2018_pct_change' at index: 107
# dropping 'HWAC_FEMALE_2017_2019_pct_change' at index: 89
# dropping 'NHWAC_MALE_ratio_2017_2019_pct_change' at index: 107
# dropping 'H_FEMALE_ratio_2017_2019_pct_change' at index: 127
# dropping 'HWAC_FEMALE_ratio_2017_2019_pct_change' at index: 125
# dropping 'NH_FEMALE_ratio_2017_2019_pct_change' at index: 132
# dropping 'HWAC_MALE_2017_2019_diff' at index: 20
# dropping 'HWAC_MALE_ratio_2017_2019_pct_change' at index: 118
# dropping 'NH_MALE_ratio_2017_2019_pct_change' at index: 124
# dropping 'Median Household Income_2017_2019_pct_change' at index: 69
# dropping 'HWA_FEMALE_2017_2018_pct_change' at index: 97
# dropping 'TOT_FEMALE_ratio_2017_2019_diff' at index: 63
# dropping 'NHWA_FEMALE_ratio_2017_2019_pct_change' at index: 116
# dropping 'H_FEMALE_2017_2019_pct_change' at index: 90
# dropping 'HWA_MALE_ratio_2017_2019_pct_change' at index: 113
# dropping 'HWAC_FEMALE_2017_2019_diff' at index: 27
# dropping 'Employed_2017_2019_pct_change' at index: 70
# dropping 'HWAC_MALE_2017_2018_diff' at index: 25
# dropping 'NHIA_FEMALE_2017_2018_pct_change' at index: 82
# dropping 'H_MALE_2017_2019_diff' at index: 21
# dropping 'HWA_FEMALE_ratio_2017_2019_pct_change' at index: 110
# dropping 'HWA_FEMALE_2017_2018_diff' at index: 29
# dropping 'HWA_FEMALE_2017_2019_pct_change' at index: 76
# dropping 'H_FEMALE_2017_2018_diff' at index: 35
# dropping 'H_MALE_ratio_2017_2019_pct_change' at index: 105
# dropping 'HWA_FEMALE_2017_2019_diff' at index: 24
# dropping 'HWA_MALE_2017_2018_diff' at index: 22
# dropping 'NHIA_FEMALE_2017_2019_pct_change' at index: 74
# dropping 'WAC_MALE_2017_2018_pct_change' at index: 68
# dropping 'BACH_TOT_2017_2019_pct_change' at index: 60
# dropping 'Poverty Estimate, Age 0-17_2018_2019_diff' at index: 54
# dropping 'TOT_FEMALE_ratio_2017_2018_pct_change' at index: 84
# dropping 'HWAC_MALE_ratio_2018_2019_diff' at index: 47
# dropping 'IAC_FEMALE_2017_2019_diff' at index: 34
# dropping 'NHWAC_FEMALE_ratio_2017_2018_pct_change' at index: 97
# dropping 'HIAC_MALE_2017_2019_diff' at index: 8
# dropping 'IAC_MALE_2017_2019_diff' at index: 24
# dropping 'NHWA_MALE_ratio_2017_2018_pct_change' at index: 69
# dropping '90% CI LB percent 0-17_2017_2019_diff' at index: 48
# dropping 'HWAC_FEMALE_2017_2018_diff' at index: 26
# dropping 'Poverty Estimate, All Ages_2018_2019_diff' at index: 45
# dropping 'NHWA_FEMALE_ratio_2018_2019_pct_change' at index: 83
# dropping 'IA_MALE_2017_2019_diff' at index: 24
# dropping 'HIAC_FEMALE_2017_2019_diff' at index: 9
# dropping 'HAAC_MALE_2017_2019_diff' at index: 5
# dropping 'Poverty Estimate, Age 5-17 in Families_2018_2019_diff' at index: 45
# dropping 'NHWAC_MALE_ratio_2018_2019_pct_change' at index: 80
# dropping 'HWAC_FEMALE_ratio_2017_2018_pct_change' at index: 86
# dropping 'HWA_MALE_2017_2019_diff' at index: 17
# dropping 'TOT_MALE_ratio_2017_2019_pct_change' at index: 50
# dropping 'IA_FEMALE_2017_2019_diff' at index: 23
# dropping 'TOM_MALE_2017_2019_diff' at index: 36
# dropping 'HWAC_MALE_ratio_2017_2018_pct_change' at index: 75
# dropping 'HWAC_MALE_ratio_2018_2019_pct_change' at index: 60
# dropping 'HAAC_FEMALE_2017_2019_diff' at index: 14
# dropping 'HWAC_FEMALE_ratio_2018_2019_pct_change' at index: 62
# dropping 'H_FEMALE_2017_2019_diff' at index: 19
# dropping 'HIA_FEMALE_2017_2019_diff' at index: 3
# dropping 'H_FEMALE_ratio_2017_2018_pct_change' at index: 76
# dropping 'Civilian_labor_force_2017_2019_pct_change' at index: 49
# dropping 'Personal income (thousands of dollars) 2018_2019_pct_change' at index: 40
# dropping 'HIA_MALE_2017_2018_diff' at index: 11
# dropping 'NHWA_MALE_ratio_2018_2019_pct_change' at index: 69
# dropping 'HIAC_FEMALE_2017_2018_diff' at index: 13
# dropping 'NHWAC_MALE_ratio_2017_2018_pct_change' at index: 53
# dropping 'IAC_FEMALE_2018_2019_diff' at index: 17
# dropping 'HAA_MALE_2017_2019_diff' at index: 3
# dropping 'NHWA_FEMALE_ratio_2017_2018_pct_change' at index: 66
# dropping 'H_FEMALE_ratio_2018_2019_pct_change' at index: 55
# dropping 'H_MALE_ratio_2017_2018_pct_change' at index: 62
# dropping 'Employed_2018_2019_pct_change' at index: 44
# dropping '90% CI LB percent 0-17_2018_2019_diff' at index: 34
# dropping 'TOT_MALE_2017_2018_pct_change' at index: 43
# dropping 'NH_MALE_ratio_2017_2018_pct_change' at index: 58
# dropping 'H_MALE_ratio_2018_2019_pct_change' at index: 48
# dropping 'NH_FEMALE_ratio_2018_2019_pct_change' at index: 61
# dropping 'HIAC_MALE_2017_2018_diff' at index: 8
# dropping 'HAA_FEMALE_2017_2019_diff' at index: 9
# dropping 'IAC_MALE_2018_2019_diff' at index: 15
# dropping 'Poverty Estimate, Age 0-17_2017_2019_diff' at index: 27
# dropping '90% CI UB medh inc_2017_2019_pct_change' at index: 32
# dropping 'Employed_2017_2018_diff' at index: 21
# dropping 'HAAC_MALE_2017_2018_diff' at index: 7
# dropping 'IAC_FEMALE_ratio_2017_2019_pct_change' at index: 40
# dropping 'HIA_FEMALE_2017_2018_diff' at index: 7
# dropping 'H_MALE_2017_2018_diff' at index: 10
# dropping 'IA_MALE_2017_2018_diff' at index: 13
# dropping 'NH_MALE_ratio_2018_2019_pct_change' at index: 49
# dropping 'TOM_MALE_2018_2019_diff' at index: 15
# dropping 'HNAC_FEMALE_2017_2019_diff' at index: 10
# dropping 'HTOM_MALE_2018_2019_diff' at index: 12
# dropping '90% CI LB All Ages_2018_2019_diff' at index: 21
# dropping 'Per capita personal income (dollars) 2018_2019_pct_change' at index: 22
# dropping 'BACH_TOT_2017_2019_diff' at index: 17
# dropping 'HNAC_MALE_2017_2019_diff' at index: 10
# dropping 'HWA_FEMALE_ratio_2017_2018_pct_change' at index: 41
# dropping 'HAA_MALE_2018_2019_diff' at index: 2
# dropping 'HWA_MALE_ratio_2018_2019_pct_change' at index: 29
# dropping 'NHIA_FEMALE_ratio_2017_2019_pct_change' at index: 37
# dropping 'NH_FEMALE_ratio_2017_2018_pct_change' at index: 38
# dropping 'HIA_MALE_2017_2019_diff' at index: 3
# dropping 'HNAC_MALE_2018_2019_diff' at index: 5
# dropping 'NHIAC_FEMALE_ratio_2017_2018_pct_change' at index: 31
# dropping 'HAA_MALE_ratio_2017_2019_diff' at index: 1
# dropping 'HAAC_FEMALE_2017_2018_diff' at index: 6
# dropping 'EDU_TOT_2017_2018_diff' at index: 10
# dropping 'HWA_MALE_ratio_2018_2019_diff' at index: 9
# dropping 'TOM_FEMALE_ratio_2017_2018_pct_change' at index: 25
# Remaining variables:
# Index(['HAA_MALE_ratio_2018_2019_diff', 'AQI_2017_2018_diff',
#        'HAA_FEMALE_2018_2019_diff', 'HAAC_MALE_ratio_2018_2019_diff',
#        'IA_FEMALE_2018_2019_diff', 'HAAC_MALE_ratio_2017_2018_diff',
#        'HNAC_FEMALE_2018_2019_diff', 'HNA_MALE_2018_2019_diff',
#        'VEHICLE_TOT_2017_2019_diff', 'BACH_TOT_2018_2019_diff',
#        '90% CI LB All Ages_2017_2019_diff', 'NHIA_FEMALE_ratio_2017_2019_diff',
#        '90% CI LB 5-17 fam_2018_2019_diff',
#        'BACH_TOT_ratio_2017_2019_pct_change',
#        '90% CI Lower Bound LB medh inc_2017_2019_pct_change',
#        'WA_MALE_2017_2018_pct_change', 'TOT_MALE_ratio_2017_2018_pct_change',
#        'Civilian_labor_force_2018_2019_pct_change',
#        'Employed_2017_2018_pct_change', 'IA_FEMALE_ratio_2017_2019_pct_change',
#        'HBAC_MALE_ratio_2017_2018_pct_change',
#        'IAC_FEMALE_ratio_2017_2018_pct_change',
#        'HBAC_FEMALE_ratio_2017_2019_pct_change',
#        'HWA_FEMALE_ratio_2018_2019_pct_change',
#        'NHIA_MALE_ratio_2017_2019_pct_change',
#        'TOT_FEMALE_ratio_2017_2019_pct_change',
#        'NHWAC_FEMALE_ratio_2018_2019_pct_change',
#        'NHIA_FEMALE_ratio_2017_2018_pct_change',
#        'HWA_MALE_ratio_2017_2018_pct_change',
#        'NHIAC_FEMALE_ratio_2017_2019_pct_change'],
#       dtype='object')
#      HAA_MALE_ratio_2018_2019_diff  AQI_2017_2018_diff  \
# 0                         0.001227            1.008865
# 1                        -0.001258            0.689292
# 2                         0.000885            0.292164
# 3                        -0.000051           -1.114232
# 4                         0.002806           -2.926909
# ..                             ...                 ...
# 203                       0.002276            1.567276
# 204                      -0.000792            1.676852
# 205                      -0.000568            3.299519
# 206                      -0.005542            0.921309
# 207                       0.003346           -0.201293
#
#      HAA_FEMALE_2018_2019_diff  HAAC_MALE_ratio_2018_2019_diff  \
# 0                           -7                        0.002302
# 1                           12                       -0.002948
# 2                            2                       -0.004412
# 3                            1                       -0.007052
# 4                            8                        0.015924
# ..                         ...                             ...
# 203                         -1                        0.006829
# 204                         -2                       -0.000115
# 205                         14                        0.003824
# 206                         -4                       -0.002894
# 207                          1                       -0.000713
#
#      IA_FEMALE_2018_2019_diff  HAAC_MALE_ratio_2017_2018_diff  \
# 0                          -3                        0.001824
# 1                          26                       -0.001872
# 2                          -1                        0.001918
# 3                          -1                        0.005475
# 4                          -1                       -0.009073
# ..                        ...                             ...
# 203                        11                       -0.001168
# 204                         4                        0.001300
# 205                        20                        0.001115
# 206                        -3                        0.024725
# 207                        31                        0.009226
#
#      HNAC_FEMALE_2018_2019_diff  HNA_MALE_2018_2019_diff  \
# 0                             2                        1
# 1                            -5                        1
# 2                             3                        0
# 3                             1                       -1
# 4                           -11                       -3
# ..                          ...                      ...
# 203                          -2                        0
# 204                           0                        1
# 205                          10                       -5
# 206                          13                        2
# 207                           0                        1
#
#      VEHICLE_TOT_2017_2019_diff  BACH_TOT_2018_2019_diff  ...  \
# 0                          6470                  -2655.0  ...
# 1                          7085                    454.0  ...
# 2                          4490                   4311.0  ...
# 3                         -1440                   -159.0  ...
# 4                           110                   1769.0  ...
# ..                          ...                      ...  ...
# 203                        1310                    817.0  ...
# 204                        3175                  10877.0  ...
# 205                       -1095                   2637.0  ...
# 206                        2500                    -27.0  ...
# 207                        1045                   -949.0  ...
#
#      HBAC_MALE_ratio_2017_2018_pct_change  \
# 0                                0.018996
# 1                               -0.018464
# 2                                0.016001
# 3                                0.022342
# 4                               -0.001984
# ..                                    ...
# 203                              0.125119
# 204                              0.018398
# 205                              0.051299
# 206                              0.040990
# 207                             -0.002787
#
#      IAC_FEMALE_ratio_2017_2018_pct_change  \
# 0                                -0.002974
# 1                                 0.004038
# 2                                 0.018639
# 3                                 0.003563
# 4                                 0.026225
# ..                                     ...
# 203                               0.034853
# 204                              -0.000276
# 205                               0.031354
# 206                              -0.009526
# 207                               0.023141
#
#      HBAC_FEMALE_ratio_2017_2019_pct_change  \
# 0                                  0.107636
# 1                                  0.066636
# 2                                  0.125612
# 3                                 -0.097338
# 4                                 -0.045128
# ..                                      ...
# 203                                0.131604
# 204                                0.045399
# 205                                0.066896
# 206                                0.085173
# 207                                0.256211
#
#      HWA_FEMALE_ratio_2018_2019_pct_change  \
# 0                                 0.030658
# 1                                 0.027882
# 2                                 0.041764
# 3                                 0.010845
# 4                                 0.001668
# ..                                     ...
# 203                               0.035868
# 204                               0.016254
# 205                               0.019079
# 206                               0.015892
# 207                               0.000016
#
#      NHIA_MALE_ratio_2017_2019_pct_change  \
# 0                               -0.036437
# 1                                0.018573
# 2                               -0.009262
# 3                               -0.003859
# 4                                0.039698
# ..                                    ...
# 203                              0.002145
# 204                             -0.025498
# 205                              0.064301
# 206                              0.015436
# 207                              0.046176
#
#      TOT_FEMALE_ratio_2017_2019_pct_change  \
# 0                                 0.000432
# 1                                -0.001176
# 2                                 0.003414
# 3                                -0.000005
# 4                                 0.001083
# ..                                     ...
# 203                               0.001131
# 204                               0.000140
# 205                              -0.000755
# 206                               0.002230
# 207                              -0.000934
#
#      NHWAC_FEMALE_ratio_2018_2019_pct_change  \
# 0                                  -0.004376
# 1                                  -0.002074
# 2                                  -0.015083
# 3                                  -0.008480
# 4                                   0.003684
# ..                                       ...
# 203                                -0.000559
# 204                                -0.004367
# 205                                -0.002823
# 206                                -0.001258
# 207                                -0.004433
#
#      NHIA_FEMALE_ratio_2017_2018_pct_change  \
# 0                                 -0.035419
# 1                                  0.001338
# 2                                  0.032503
# 3                                  0.001860
# 4                                  0.045735
# ..                                      ...
# 203                                0.025530
# 204                               -0.010237
# 205                                0.039651
# 206                               -0.017259
# 207                                0.056049
#
#      HWA_MALE_ratio_2017_2018_pct_change  \
# 0                               0.023389
# 1                               0.029045
# 2                               0.010148
# 3                               0.002976
# 4                              -0.002318
# ..                                   ...
# 203                             0.030857
# 204                             0.026461
# 205                             0.012786
# 206                            -0.008776
# 207                             0.026485
#
#      NHIAC_FEMALE_ratio_2017_2019_pct_change
# 0                                  -0.026519
# 1                                  -0.008553
# 2                                   0.044733
# 3                                   0.000302
# 4                                   0.029941
# ..                                       ...
# 203                                 0.055941
# 204                                -0.008540
# 205                                 0.036447
# 206                                -0.011286
# 207                                 0.062075
#
# [208 rows x 30 columns]

# %%
columns = ['HAA_MALE_ratio_2018_2019_diff', 'AQI_2017_2018_diff',
       'HAA_FEMALE_2018_2019_diff', 'HAAC_MALE_ratio_2018_2019_diff',
       'IA_FEMALE_2018_2019_diff', 'HAAC_MALE_ratio_2017_2018_diff',
       'HNAC_FEMALE_2018_2019_diff', 'HNA_MALE_2018_2019_diff',
       'VEHICLE_TOT_2017_2019_diff', 'BACH_TOT_2018_2019_diff',
       '90% CI LB All Ages_2017_2019_diff', 'NHIA_FEMALE_ratio_2017_2019_diff',
       '90% CI LB 5-17 fam_2018_2019_diff',
       'BACH_TOT_ratio_2017_2019_pct_change',
       '90% CI Lower Bound LB medh inc_2017_2019_pct_change',
       'WA_MALE_2017_2018_pct_change', 'TOT_MALE_ratio_2017_2018_pct_change',
       'Civilian_labor_force_2018_2019_pct_change',
       'Employed_2017_2018_pct_change', 'IA_FEMALE_ratio_2017_2019_pct_change',
       'HBAC_MALE_ratio_2017_2018_pct_change',
       'IAC_FEMALE_ratio_2017_2018_pct_change',
       'HBAC_FEMALE_ratio_2017_2019_pct_change',
       'HWA_FEMALE_ratio_2018_2019_pct_change',
       'NHIA_MALE_ratio_2017_2019_pct_change',
       'TOT_FEMALE_ratio_2017_2019_pct_change',
       'NHWAC_FEMALE_ratio_2018_2019_pct_change',
       'NHIA_FEMALE_ratio_2017_2018_pct_change',
       'HWA_MALE_ratio_2017_2018_pct_change',
       'NHIAC_FEMALE_ratio_2017_2019_pct_change']
X = X[columns]
X
# Out:
#      HAA_MALE_ratio_2018_2019_diff  AQI_2017_2018_diff  \
# 0                         0.001227            1.008865
# 1                        -0.001258            0.689292
# 2                         0.000885            0.292164
# 3                        -0.000051           -1.114232
# 4                         0.002806           -2.926909
# ..                             ...                 ...
# 203                       0.002276            1.567276
# 204                      -0.000792            1.676852
# 205                      -0.000568            3.299519
# 206                      -0.005542            0.921309
# 207                       0.003346           -0.201293
#
#      HAA_FEMALE_2018_2019_diff  HAAC_MALE_ratio_2018_2019_diff  \
# 0                           -7                        0.002302
# 1                           12                       -0.002948
# 2                            2                       -0.004412
# 3                            1                       -0.007052
# 4                            8                        0.015924
# ..                         ...                             ...
# 203                         -1                        0.006829
# 204                         -2                       -0.000115
# 205                         14                        0.003824
# 206                         -4                       -0.002894
# 207                          1                       -0.000713
#
#      IA_FEMALE_2018_2019_diff  HAAC_MALE_ratio_2017_2018_diff  \
# 0                          -3                        0.001824
# 1                          26                       -0.001872
# 2                          -1                        0.001918
# 3                          -1                        0.005475
# 4                          -1                       -0.009073
# ..                        ...                             ...
# 203                        11                       -0.001168
# 204                         4                        0.001300
# 205                        20                        0.001115
# 206                        -3                        0.024725
# 207                        31                        0.009226
#
#      HNAC_FEMALE_2018_2019_diff  HNA_MALE_2018_2019_diff  \
# 0                             2                        1
# 1                            -5                        1
# 2                             3                        0
# 3                             1                       -1
# 4                           -11                       -3
# ..                          ...                      ...
# 203                          -2                        0
# 204                           0                        1
# 205                          10                       -5
# 206                          13                        2
# 207                           0                        1
#
#      VEHICLE_TOT_2017_2019_diff  BACH_TOT_2018_2019_diff  ...  \
# 0                          6470                  -2655.0  ...
# 1                          7085                    454.0  ...
# 2                          4490                   4311.0  ...
# 3                         -1440                   -159.0  ...
# 4                           110                   1769.0  ...
# ..                          ...                      ...  ...
# 203                        1310                    817.0  ...
# 204                        3175                  10877.0  ...
# 205                       -1095                   2637.0  ...
# 206                        2500                    -27.0  ...
# 207                        1045                   -949.0  ...
#
#      HBAC_MALE_ratio_2017_2018_pct_change  \
# 0                                0.018996
# 1                               -0.018464
# 2                                0.016001
# 3                                0.022342
# 4                               -0.001984
# ..                                    ...
# 203                              0.125119
# 204                              0.018398
# 205                              0.051299
# 206                              0.040990
# 207                             -0.002787
#
#      IAC_FEMALE_ratio_2017_2018_pct_change  \
# 0                                -0.002974
# 1                                 0.004038
# 2                                 0.018639
# 3                                 0.003563
# 4                                 0.026225
# ..                                     ...
# 203                               0.034853
# 204                              -0.000276
# 205                               0.031354
# 206                              -0.009526
# 207                               0.023141
#
#      HBAC_FEMALE_ratio_2017_2019_pct_change  \
# 0                                  0.107636
# 1                                  0.066636
# 2                                  0.125612
# 3                                 -0.097338
# 4                                 -0.045128
# ..                                      ...
# 203                                0.131604
# 204                                0.045399
# 205                                0.066896
# 206                                0.085173
# 207                                0.256211
#
#      HWA_FEMALE_ratio_2018_2019_pct_change  \
# 0                                 0.030658
# 1                                 0.027882
# 2                                 0.041764
# 3                                 0.010845
# 4                                 0.001668
# ..                                     ...
# 203                               0.035868
# 204                               0.016254
# 205                               0.019079
# 206                               0.015892
# 207                               0.000016
#
#      NHIA_MALE_ratio_2017_2019_pct_change  \
# 0                               -0.036437
# 1                                0.018573
# 2                               -0.009262
# 3                               -0.003859
# 4                                0.039698
# ..                                    ...
# 203                              0.002145
# 204                             -0.025498
# 205                              0.064301
# 206                              0.015436
# 207                              0.046176
#
#      TOT_FEMALE_ratio_2017_2019_pct_change  \
# 0                                 0.000432
# 1                                -0.001176
# 2                                 0.003414
# 3                                -0.000005
# 4                                 0.001083
# ..                                     ...
# 203                               0.001131
# 204                               0.000140
# 205                              -0.000755
# 206                               0.002230
# 207                              -0.000934
#
#      NHWAC_FEMALE_ratio_2018_2019_pct_change  \
# 0                                  -0.004376
# 1                                  -0.002074
# 2                                  -0.015083
# 3                                  -0.008480
# 4                                   0.003684
# ..                                       ...
# 203                                -0.000559
# 204                                -0.004367
# 205                                -0.002823
# 206                                -0.001258
# 207                                -0.004433
#
#      NHIA_FEMALE_ratio_2017_2018_pct_change  \
# 0                                 -0.035419
# 1                                  0.001338
# 2                                  0.032503
# 3                                  0.001860
# 4                                  0.045735
# ..                                      ...
# 203                                0.025530
# 204                               -0.010237
# 205                                0.039651
# 206                               -0.017259
# 207                                0.056049
#
#      HWA_MALE_ratio_2017_2018_pct_change  \
# 0                               0.023389
# 1                               0.029045
# 2                               0.010148
# 3                               0.002976
# 4                              -0.002318
# ..                                   ...
# 203                             0.030857
# 204                             0.026461
# 205                             0.012786
# 206                            -0.008776
# 207                             0.026485
#
#      NHIAC_FEMALE_ratio_2017_2019_pct_change
# 0                                  -0.026519
# 1                                  -0.008553
# 2                                   0.044733
# 3                                   0.000302
# 4                                   0.029941
# ..                                       ...
# 203                                 0.055941
# 204                                -0.008540
# 205                                 0.036447
# 206                                -0.011286
# 207                                 0.062075
#
# [208 rows x 30 columns]

# %%
correlations = []
for col in X.columns:
    correlations.append(y.corr(X[col]))
correlations
# Out:
# [0.4059375819961343,
#  0.2932747836981395,
#  0.28843360172225463,
#  0.28411541831513853,
#  0.24292413091087106,
#  0.24112415352928296,
#  0.21193551464333302,
#  0.2115491939329167,
#  0.20540567725312617,
#  0.20066567105166258,
#  -0.2006561164491064,
#  -0.20116368054279685,
#  -0.23545240814680868,
#  0.2312257996714313,
#  0.22898601969675852,
#  0.22210090707408645,
#  0.2198168765965636,
#  0.21395750867729485,
#  0.20968671804218483,
#  -0.20377904864728577,
#  -0.20500227187580183,
#  -0.20931014980096693,
#  -0.2130814572414299,
#  -0.21808477265989828,
#  -0.2251559553594255,
#  -0.23972995993697643,
#  -0.25359857116118406,
#  -0.254390353683562,
#  -0.25829708691121994,
#  -0.2754981665031909]

# %%
scatterplots(df, 'AQI_2019', columns, ncol=4, figsize=(30,30))
