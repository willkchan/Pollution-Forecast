# %% [markdown]
# # Running processes same as DataWrangling11 on all counties available in US

# %% [markdown]
# # Clean up new added datasets unemployment rates, poverty rate, education and vehicle
#
# # Importing libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import sys
import os
import matplotlib.pyplot as plt
import klib

from IPython.core.display import display

# pd.set_option('display.max_columns', None)
# pd.reset_optio('max_rows')
#np.set_printoptions(threshold=sys.maxsize)

plt.style.use('dark_background')
plt.rcParams.update({"grid.linewidth":0.5, "grid.alpha":0.5})
sns.set(style='ticks', context='talk')

# %% [markdown]
# # Load data and constants

# %%
daily_aqi_by_county_2017 = pd.read_csv('../../data/raw/daily_aqi_by_county_2017.csv')
daily_aqi_by_county_2018 = pd.read_csv('../../data/raw/daily_aqi_by_county_2018.csv')
daily_aqi_by_county_2019 = pd.read_csv('../../data/raw/daily_aqi_by_county_2019.csv')

county_demographic = pd.read_csv('../../data/raw/county_cc-est2019-alldata.csv', encoding='latin-1')

unemployment = pd.read_excel('../../data/raw/Unemployment.xls', header=None, sheet_name=0)

# Small area income and poverty estimates
saipe2017 = pd.read_excel('../../data/raw/saipe_economic/est17all.xls')
saipe2018 = pd.read_excel('../../data/raw/saipe_economic/est18all.xls')
saipe2019 = pd.read_excel('../../data/raw/saipe_economic/est19all.xls')

educ_vehicle_2017 = pd.read_csv('../../data/processed/acs1_edu_vehicle2017.csv')
educ_vehicle_2018 = pd.read_csv('../../data/processed/acs1_edu_vehicle2018.csv')
educ_vehicle_2019 = pd.read_csv('../../data/processed/acs1_edu_vehicle2019.csv')

annual_income_by_county = pd.read_csv('../../data/raw/CAINC1__ALL_AREAS_1969_2019.csv', encoding='latin-1')

# %%
def remove_col(df, col_name):
    '''Returns a dataframe with removed column or columns from old dataframe'''
    new_df = df.copy()

    if(type(col_name) != str and len(col_name) > 1):
        for index in col_name:
            new_df = new_df.drop(str(index), axis=1)
    else:
        new_df = new_df.drop(str(col_name), axis=1)
    return new_df

def get_df_with_geofips(df, state_code, county_code):
    ''' Returns dataframe with geofips column '''
    state_code = df[state_code].astype(str).values
    county_code = df[county_code].astype(str).values

    geofips = []
    for stateID, countyID in zip(state_code, county_code):
        id = ''
        stateLen = len(stateID)
        countyLen = len(countyID)
        if(stateLen < 2):
            id += '0' + stateID
        else:
            id += stateID
        if(countyLen == 1):
            id += '00' + countyID
        elif(countyLen == 2):
            id += '0' + countyID
        else:
            id += countyID
        geofips.append(id)

    df.insert(loc=0, column='GeoFIPS', value=geofips)
    return df

# %% [markdown]
# ## Clean up and set up income datasets

# %%
annual_income_by_county

all_incomes_2017_2019 = remove_col(annual_income_by_county, range(1969, 2017))

# used to remove last 4 rows as they are not index data; looks like extra info
all_incomes_2017_2019 = all_incomes_2017_2019[:len(all_incomes_2017_2019) - 4]

# all_incomes_2017_2019.info()
all_incomes_2017_2019
# Out:
#        GeoFIPS         GeoName Region TableName  LineCode  \
# 0      "00000"   United States           CAINC1       1.0
# 1      "00000"   United States           CAINC1       2.0
# 2      "00000"   United States           CAINC1       3.0
# 3      "01000"         Alabama      5    CAINC1       1.0
# 4      "01000"         Alabama      5    CAINC1       2.0
# ...        ...             ...    ...       ...       ...
# 9589   "97000"  Rocky Mountain      7    CAINC1       2.0
# 9590   "97000"  Rocky Mountain      7    CAINC1       3.0
# 9591   "98000"        Far West      8    CAINC1       1.0
# 9592   "98000"        Far West      8    CAINC1       2.0
# 9593   "98000"        Far West      8    CAINC1       3.0
#
#      IndustryClassification                              Description  \
# 0                       ...   Personal income (thousands of dollars)
# 1                       ...                  Population (persons) 1/
# 2                       ...  Per capita personal income (dollars) 2/
# 3                       ...   Personal income (thousands of dollars)
# 4                       ...                  Population (persons) 1/
# ...                     ...                                      ...
# 9589                    ...                  Population (persons) 1/
# 9590                    ...  Per capita personal income (dollars) 2/
# 9591                    ...   Personal income (thousands of dollars)
# 9592                    ...                  Population (persons) 1/
# 9593                    ...  Per capita personal income (dollars) 2/
#
#                       Unit         2017         2018         2019
# 0     Thousands of dollars  16937582000  17839255000  18542262000
# 1        Number of persons    324985539    326687501    328239523
# 2                  Dollars        52118        54606        56490
# 3     Thousands of dollars    199999756    208752683    216449038
# 4        Number of persons      4874486      4887681      4903185
# ...                    ...          ...          ...          ...
# 9589     Number of persons     12062055     12233639     12399296
# 9590               Dollars        49991        52936        54873
# 9591  Thousands of dollars   3279057722   3472097346   3634009401
# 9592     Number of persons     56059482     56350416     56572426
# 9593               Dollars        58492        61616        64236
#
# [9594 rows x 11 columns]

# %% [markdown]
# * Years 1969 to 2016 were removed as we only have interest on 2017-2019
# * Also last four rows were remoed as they were not row data, there were just caption text

# %%
all_incomes_2017_2019['2017'] = pd.to_numeric(all_incomes_2017_2019['2017'], downcast='float', errors='coerce')
all_incomes_2017_2019['2018'] = pd.to_numeric(all_incomes_2017_2019['2018'], downcast='float', errors='coerce')
all_incomes_2017_2019['2019'] = pd.to_numeric(all_incomes_2017_2019['2019'], downcast='float', errors='coerce')

# all_incomes_2017_2019 = remove_col(all_incomes_2017_2019, range(2017,2020))
all_incomes_2017_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9594 entries, 0 to 9593
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   GeoFIPS                 9594 non-null   object
#  1   GeoName                 9594 non-null   object
#  2   Region                  9594 non-null   object
#  3   TableName               9594 non-null   object
#  4   LineCode                9594 non-null   float64
#  5   IndustryClassification  9594 non-null   object
#  6   Description             9594 non-null   object
#  7   Unit                    9594 non-null   object
#  8   2017                    9519 non-null   float32
#  9   2018                    9519 non-null   float32
#  10  2019                    9519 non-null   float32
# dtypes: float32(3), float64(1), object(7)
# memory usage: 712.2+ KB

# %% [markdown]
# * Columns were changed to appropriate types
# * Income was changed to type float
# * 'NA' string was changed to np.nan
# ** Rename column income data to be more descriptive and remove old column in place of new column names

# %%
personal_income = all_incomes_2017_2019['Description'] == ('Personal income (thousands of dollars)')
per_capita_personal_income = all_incomes_2017_2019['Description'] == ('Per capita personal income (dollars) 2/')
county_personal_incomes = all_incomes_2017_2019[personal_income]
county_per_capita_personal_income = all_incomes_2017_2019[per_capita_personal_income]
county_personal_incomes.rename(columns={'2017':'Personal income (thousands of dollars) 2017',
                                        '2018':'Personal income (thousands of dollars) 2018',
                                        '2019':'Personal income (thousands of dollars) 2019',}, inplace=True)
county_per_capita_personal_income.rename(columns={'2017':'Per capita personal income (dollars) 2017',
                                                  '2018':'Per capita personal income (dollars) 2018',
                                                  '2019':'Per capita personal income (dollars) 2019',}, inplace=True)

display(county_personal_incomes)
display(county_per_capita_personal_income)
# Out:
# /home/wkc/.local/lib/python3.8/site-packages/pandas/core/frame.py:4300: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#        GeoFIPS         GeoName Region TableName  LineCode  \
# 0      "00000"   United States           CAINC1       1.0
# 3      "01000"         Alabama      5    CAINC1       1.0
# 6      "01001"     Autauga, AL      5    CAINC1       1.0
# 9      "01003"     Baldwin, AL      5    CAINC1       1.0
# 12     "01005"     Barbour, AL      5    CAINC1       1.0
# ...        ...             ...    ...       ...       ...
# 9579   "94000"          Plains      4    CAINC1       1.0
# 9582   "95000"       Southeast      5    CAINC1       1.0
# 9585   "96000"       Southwest      6    CAINC1       1.0
# 9588   "97000"  Rocky Mountain      7    CAINC1       1.0
# 9591   "98000"        Far West      8    CAINC1       1.0
#
#      IndustryClassification                             Description  \
# 0                       ...  Personal income (thousands of dollars)
# 3                       ...  Personal income (thousands of dollars)
# 6                       ...  Personal income (thousands of dollars)
# 9                       ...  Personal income (thousands of dollars)
# 12                      ...  Personal income (thousands of dollars)
# ...                     ...                                     ...
# 9579                    ...  Personal income (thousands of dollars)
# 9582                    ...  Personal income (thousands of dollars)
# 9585                    ...  Personal income (thousands of dollars)
# 9588                    ...  Personal income (thousands of dollars)
# 9591                    ...  Personal income (thousands of dollars)
#
#                       Unit  Personal income (thousands of dollars) 2017  \
# 0     Thousands of dollars                                 1.693758e+10
# 3     Thousands of dollars                                 1.999998e+08
# 6     Thousands of dollars                                 2.276561e+06
# 9     Thousands of dollars                                 9.471242e+06
# 12    Thousands of dollars                                 8.381840e+05
# ...                    ...                                          ...
# 9579  Thousands of dollars                                 1.055029e+09
# 9582  Thousands of dollars                                 3.818755e+09
# 9585  Thousands of dollars                                 1.924648e+09
# 9588  Thousands of dollars                                 6.029942e+08
# 9591  Thousands of dollars                                 3.279058e+09
#
#       Personal income (thousands of dollars) 2018  \
# 0                                    1.783926e+10
# 3                                    2.087527e+08
# 6                                    2.360366e+06
# 9                                    1.006597e+07
# 12                                   8.721890e+05
# ...                                           ...
# 9579                                 1.107630e+09
# 9582                                 4.022276e+09
# 9585                                 2.051027e+09
# 9588                                 6.476007e+08
# 9591                                 3.472097e+09
#
#       Personal income (thousands of dollars) 2019
# 0                                    1.854226e+10
# 3                                    2.164490e+08
# 6                                    2.453617e+06
# 9                                    1.060026e+07
# 12                                   8.828340e+05
# ...                                           ...
# 9579                                 1.146515e+09
# 9582                                 4.173677e+09
# 9585                                 2.144764e+09
# 9588                                 6.803901e+08
# 9591                                 3.634009e+09
#
# [3198 rows x 11 columns]
#        GeoFIPS         GeoName Region TableName  LineCode  \
# 2      "00000"   United States           CAINC1       3.0
# 5      "01000"         Alabama      5    CAINC1       3.0
# 8      "01001"     Autauga, AL      5    CAINC1       3.0
# 11     "01003"     Baldwin, AL      5    CAINC1       3.0
# 14     "01005"     Barbour, AL      5    CAINC1       3.0
# ...        ...             ...    ...       ...       ...
# 9581   "94000"          Plains      4    CAINC1       3.0
# 9584   "95000"       Southeast      5    CAINC1       3.0
# 9587   "96000"       Southwest      6    CAINC1       3.0
# 9590   "97000"  Rocky Mountain      7    CAINC1       3.0
# 9593   "98000"        Far West      8    CAINC1       3.0
#
#      IndustryClassification                              Description     Unit  \
# 2                       ...  Per capita personal income (dollars) 2/  Dollars
# 5                       ...  Per capita personal income (dollars) 2/  Dollars
# 8                       ...  Per capita personal income (dollars) 2/  Dollars
# 11                      ...  Per capita personal income (dollars) 2/  Dollars
# 14                      ...  Per capita personal income (dollars) 2/  Dollars
# ...                     ...                                      ...      ...
# 9581                    ...  Per capita personal income (dollars) 2/  Dollars
# 9584                    ...  Per capita personal income (dollars) 2/  Dollars
# 9587                    ...  Per capita personal income (dollars) 2/  Dollars
# 9590                    ...  Per capita personal income (dollars) 2/  Dollars
# 9593                    ...  Per capita personal income (dollars) 2/  Dollars
#
#       Per capita personal income (dollars) 2017  \
# 2                                       52118.0
# 5                                       41030.0
# 8                                       41101.0
# 11                                      44566.0
# 14                                      33318.0
# ...                                         ...
# 9581                                    49609.0
# 9584                                    45657.0
# 9587                                    46531.0
# 9590                                    49991.0
# 9593                                    58492.0
#
#       Per capita personal income (dollars) 2018  \
# 2                                       54606.0
# 5                                       42710.0
# 8                                       42504.0
# 11                                      46205.0
# 14                                      35067.0
# ...                                         ...
# 9581                                    51879.0
# 9584                                    47715.0
# 9587                                    49045.0
# 9590                                    52936.0
# 9593                                    61616.0
#
#       Per capita personal income (dollars) 2019
# 2                                       56490.0
# 5                                       44145.0
# 8                                       43917.0
# 11                                      47485.0
# 14                                      35763.0
# ...                                         ...
# 9581                                    53509.0
# 9584                                    49159.0
# 9587                                    50670.0
# 9590                                    54873.0
# 9593                                    64236.0
#
# [3198 rows x 11 columns]

# %%
cols_to_remove = ['IndustryClassification', 'TableName', 'Unit', 'Description', 'LineCode', 'Region']

county_personal_incomes.drop(cols_to_remove, axis=1, inplace=True)
county_per_capita_personal_income.drop(cols_to_remove, axis=1, inplace=True)

county_incomes = pd.merge(county_personal_incomes, county_per_capita_personal_income, how='inner')
county_incomes
# Out:
# /home/wkc/.local/lib/python3.8/site-packages/pandas/core/frame.py:4167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#        GeoFIPS         GeoName  Personal income (thousands of dollars) 2017  \
# 0      "00000"   United States                                 1.693758e+10
# 1      "01000"         Alabama                                 1.999998e+08
# 2      "01001"     Autauga, AL                                 2.276561e+06
# 3      "01003"     Baldwin, AL                                 9.471242e+06
# 4      "01005"     Barbour, AL                                 8.381840e+05
# ...        ...             ...                                          ...
# 3193   "94000"          Plains                                 1.055029e+09
# 3194   "95000"       Southeast                                 3.818755e+09
# 3195   "96000"       Southwest                                 1.924648e+09
# 3196   "97000"  Rocky Mountain                                 6.029942e+08
# 3197   "98000"        Far West                                 3.279058e+09
#
#       Personal income (thousands of dollars) 2018  \
# 0                                    1.783926e+10
# 1                                    2.087527e+08
# 2                                    2.360366e+06
# 3                                    1.006597e+07
# 4                                    8.721890e+05
# ...                                           ...
# 3193                                 1.107630e+09
# 3194                                 4.022276e+09
# 3195                                 2.051027e+09
# 3196                                 6.476007e+08
# 3197                                 3.472097e+09
#
#       Personal income (thousands of dollars) 2019  \
# 0                                    1.854226e+10
# 1                                    2.164490e+08
# 2                                    2.453617e+06
# 3                                    1.060026e+07
# 4                                    8.828340e+05
# ...                                           ...
# 3193                                 1.146515e+09
# 3194                                 4.173677e+09
# 3195                                 2.144764e+09
# 3196                                 6.803901e+08
# 3197                                 3.634009e+09
#
#       Per capita personal income (dollars) 2017  \
# 0                                       52118.0
# 1                                       41030.0
# 2                                       41101.0
# 3                                       44566.0
# 4                                       33318.0
# ...                                         ...
# 3193                                    49609.0
# 3194                                    45657.0
# 3195                                    46531.0
# 3196                                    49991.0
# 3197                                    58492.0
#
#       Per capita personal income (dollars) 2018  \
# 0                                       54606.0
# 1                                       42710.0
# 2                                       42504.0
# 3                                       46205.0
# 4                                       35067.0
# ...                                         ...
# 3193                                    51879.0
# 3194                                    47715.0
# 3195                                    49045.0
# 3196                                    52936.0
# 3197                                    61616.0
#
#       Per capita personal income (dollars) 2019
# 0                                       56490.0
# 1                                       44145.0
# 2                                       43917.0
# 3                                       47485.0
# 4                                       35763.0
# ...                                         ...
# 3193                                    53509.0
# 3194                                    49159.0
# 3195                                    50670.0
# 3196                                    54873.0
# 3197                                    64236.0
#
# [3198 rows x 8 columns]

# %% [markdown]
# Removed redundant or uninterested columns
# * remove more columns
# * remove IndustryClassifaction as it only contains ... values and also not what we are interested in
# * remove TableName as only one value and not what we are interested in
# * remove Unit as that has the same value as Thousands of dollars
# * remove Description as that is all personal income now
# * remove LineCode as there are no unique values all value is 1
# * remove Region as not interested in this data

# %%
county_incomes['GeoFIPS'] = county_incomes['GeoFIPS'].str.strip('" "')
county_incomes
# Out:
#      GeoFIPS         GeoName  Personal income (thousands of dollars) 2017  \
# 0      00000   United States                                 1.693758e+10
# 1      01000         Alabama                                 1.999998e+08
# 2      01001     Autauga, AL                                 2.276561e+06
# 3      01003     Baldwin, AL                                 9.471242e+06
# 4      01005     Barbour, AL                                 8.381840e+05
# ...      ...             ...                                          ...
# 3193   94000          Plains                                 1.055029e+09
# 3194   95000       Southeast                                 3.818755e+09
# 3195   96000       Southwest                                 1.924648e+09
# 3196   97000  Rocky Mountain                                 6.029942e+08
# 3197   98000        Far West                                 3.279058e+09
#
#       Personal income (thousands of dollars) 2018  \
# 0                                    1.783926e+10
# 1                                    2.087527e+08
# 2                                    2.360366e+06
# 3                                    1.006597e+07
# 4                                    8.721890e+05
# ...                                           ...
# 3193                                 1.107630e+09
# 3194                                 4.022276e+09
# 3195                                 2.051027e+09
# 3196                                 6.476007e+08
# 3197                                 3.472097e+09
#
#       Personal income (thousands of dollars) 2019  \
# 0                                    1.854226e+10
# 1                                    2.164490e+08
# 2                                    2.453617e+06
# 3                                    1.060026e+07
# 4                                    8.828340e+05
# ...                                           ...
# 3193                                 1.146515e+09
# 3194                                 4.173677e+09
# 3195                                 2.144764e+09
# 3196                                 6.803901e+08
# 3197                                 3.634009e+09
#
#       Per capita personal income (dollars) 2017  \
# 0                                       52118.0
# 1                                       41030.0
# 2                                       41101.0
# 3                                       44566.0
# 4                                       33318.0
# ...                                         ...
# 3193                                    49609.0
# 3194                                    45657.0
# 3195                                    46531.0
# 3196                                    49991.0
# 3197                                    58492.0
#
#       Per capita personal income (dollars) 2018  \
# 0                                       54606.0
# 1                                       42710.0
# 2                                       42504.0
# 3                                       46205.0
# 4                                       35067.0
# ...                                         ...
# 3193                                    51879.0
# 3194                                    47715.0
# 3195                                    49045.0
# 3196                                    52936.0
# 3197                                    61616.0
#
#       Per capita personal income (dollars) 2019
# 0                                       56490.0
# 1                                       44145.0
# 2                                       43917.0
# 3                                       47485.0
# 4                                       35763.0
# ...                                         ...
# 3193                                    53509.0
# 3194                                    49159.0
# 3195                                    50670.0
# 3196                                    54873.0
# 3197                                    64236.0
#
# [3198 rows x 8 columns]

# %% [markdown]
# * remove "" characters from income dataset

# %%
county_incomes_2017_2019 = county_incomes
# county_incomes_2017_2019['GeoFIPS'] = pd.to_numeric(county_incomes_2017_2019['GeoFIPS'])
county_incomes_2017_2019
# Out:
#      GeoFIPS         GeoName  Personal income (thousands of dollars) 2017  \
# 0      00000   United States                                 1.693758e+10
# 1      01000         Alabama                                 1.999998e+08
# 2      01001     Autauga, AL                                 2.276561e+06
# 3      01003     Baldwin, AL                                 9.471242e+06
# 4      01005     Barbour, AL                                 8.381840e+05
# ...      ...             ...                                          ...
# 3193   94000          Plains                                 1.055029e+09
# 3194   95000       Southeast                                 3.818755e+09
# 3195   96000       Southwest                                 1.924648e+09
# 3196   97000  Rocky Mountain                                 6.029942e+08
# 3197   98000        Far West                                 3.279058e+09
#
#       Personal income (thousands of dollars) 2018  \
# 0                                    1.783926e+10
# 1                                    2.087527e+08
# 2                                    2.360366e+06
# 3                                    1.006597e+07
# 4                                    8.721890e+05
# ...                                           ...
# 3193                                 1.107630e+09
# 3194                                 4.022276e+09
# 3195                                 2.051027e+09
# 3196                                 6.476007e+08
# 3197                                 3.472097e+09
#
#       Personal income (thousands of dollars) 2019  \
# 0                                    1.854226e+10
# 1                                    2.164490e+08
# 2                                    2.453617e+06
# 3                                    1.060026e+07
# 4                                    8.828340e+05
# ...                                           ...
# 3193                                 1.146515e+09
# 3194                                 4.173677e+09
# 3195                                 2.144764e+09
# 3196                                 6.803901e+08
# 3197                                 3.634009e+09
#
#       Per capita personal income (dollars) 2017  \
# 0                                       52118.0
# 1                                       41030.0
# 2                                       41101.0
# 3                                       44566.0
# 4                                       33318.0
# ...                                         ...
# 3193                                    49609.0
# 3194                                    45657.0
# 3195                                    46531.0
# 3196                                    49991.0
# 3197                                    58492.0
#
#       Per capita personal income (dollars) 2018  \
# 0                                       54606.0
# 1                                       42710.0
# 2                                       42504.0
# 3                                       46205.0
# 4                                       35067.0
# ...                                         ...
# 3193                                    51879.0
# 3194                                    47715.0
# 3195                                    49045.0
# 3196                                    52936.0
# 3197                                    61616.0
#
#       Per capita personal income (dollars) 2019
# 0                                       56490.0
# 1                                       44145.0
# 2                                       43917.0
# 3                                       47485.0
# 4                                       35763.0
# ...                                         ...
# 3193                                    53509.0
# 3194                                    49159.0
# 3195                                    50670.0
# 3196                                    54873.0
# 3197                                    64236.0
#
# [3198 rows x 8 columns]

# %% [markdown]
# # Clean up Unemployment Data

# %%
display(unemployment)
unemployment2017_2019 = unemployment[4:]
unemployment2017_2019.reset_index(drop=True, inplace=True)
unemployment_header = unemployment2017_2019.iloc[0, :].values
unemployment2017_2019.columns = unemployment_header
unemployment2017_2019 = unemployment2017_2019.drop([0])
display(unemployment2017_2019)
# Out:
#                                                      0      1   \
# 0     Unemployment and median household income for t...    NaN
# 1     Sources: Unemployment: U.S. Department of Labo...    NaN
# 2     For definitions of rural classifications, see ...    NaN
# 3     This table was prepared by USDA, Economic Rese...    NaN
# 4                                              fips_txt  Stabr
# ...                                                 ...    ...
# 3275                                              72145     PR
# 3276                                              72147     PR
# 3277                                              72149     PR
# 3278                                              72151     PR
# 3279                                              72153     PR
#
#                            2                                3   \
# 0                         NaN                              NaN
# 1                         NaN                              NaN
# 2                         NaN                              NaN
# 3                         NaN                              NaN
# 4                   area_name  Rural_urban_continuum_code_2013
# ...                       ...                              ...
# 3275  Vega Baja Municipio, PR                                1
# 3276    Vieques Municipio, PR                                7
# 3277   Villalba Municipio, PR                                2
# 3278    Yabucoa Municipio, PR                                1
# 3279      Yauco Municipio, PR                                2
#
#                              4           5                          6   \
# 0                           NaN         NaN                        NaN
# 1                           NaN         NaN                        NaN
# 2                           NaN         NaN                        NaN
# 3                           NaN         NaN                        NaN
# 4     Urban_influence_code_2013  Metro_2013  Civilian_labor_force_2000
# ...                         ...         ...                        ...
# 3275                          1           1                      19805
# 3276                         12           0                       2441
# 3277                          2           1                       7636
# 3278                          1           1                      10613
# 3279                          2           1                      14664
#
#                  7                8                       9   ...  \
# 0               NaN              NaN                     NaN  ...
# 1               NaN              NaN                     NaN  ...
# 2               NaN              NaN                     NaN  ...
# 3               NaN              NaN                     NaN  ...
# 4     Employed_2000  Unemployed_2000  Unemployment_rate_2000  ...
# ...             ...              ...                     ...  ...
# 3275          17607             2198                    11.1  ...
# 3276           2120              321                    13.2  ...
# 3277           6648              988                    12.9  ...
# 3278           9005             1608                    15.2  ...
# 3279          12871             1793                    12.2  ...
#
#                              78             79               80  \
# 0                           NaN            NaN              NaN
# 1                           NaN            NaN              NaN
# 2                           NaN            NaN              NaN
# 3                           NaN            NaN              NaN
# 4     Civilian_labor_force_2018  Employed_2018  Unemployed_2018
# ...                         ...            ...              ...
# 3275                      13117          11750             1367
# 3276                       2718           2269              449
# 3277                       7311           6154             1157
# 3278                       8762           7509             1253
# 3279                       9716           8288             1428
#
#                           81                         82             83  \
# 0                        NaN                        NaN            NaN
# 1                        NaN                        NaN            NaN
# 2                        NaN                        NaN            NaN
# 3                        NaN                        NaN            NaN
# 4     Unemployment_rate_2018  Civilian_labor_force_2019  Employed_2019
# ...                      ...                        ...            ...
# 3275                    10.4                      13037          11791
# 3276                    16.5                       2585           2406
# 3277                    15.8                       7406           6231
# 3278                    14.3                       8691           7552
# 3279                    14.7                       9759           8331
#
#                    84                      85                            86  \
# 0                 NaN                     NaN                           NaN
# 1                 NaN                     NaN                           NaN
# 2                 NaN                     NaN                           NaN
# 3                 NaN                     NaN                           NaN
# 4     Unemployed_2019  Unemployment_rate_2019  Median_Household_Income_2019
# ...               ...                     ...                           ...
# 3275             1246                     9.6                           NaN
# 3276              179                     6.9                           NaN
# 3277             1175                    15.9                           NaN
# 3278             1139                    13.1                           NaN
# 3279             1428                    14.6                           NaN
#
#                                              87
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4     Med_HH_Income_Percent_of_State_Total_2019
# ...                                         ...
# 3275                                        NaN
# 3276                                        NaN
# 3277                                        NaN
# 3278                                        NaN
# 3279                                        NaN
#
# [3280 rows x 88 columns]
#      fips_txt Stabr                area_name Rural_urban_continuum_code_2013  \
# 1       00000    US            United States                             NaN
# 2       01000    AL                  Alabama                             NaN
# 3       01001    AL       Autauga County, AL                               2
# 4       01003    AL       Baldwin County, AL                               3
# 5       01005    AL       Barbour County, AL                               6
# ...       ...   ...                      ...                             ...
# 3271    72145    PR  Vega Baja Municipio, PR                               1
# 3272    72147    PR    Vieques Municipio, PR                               7
# 3273    72149    PR   Villalba Municipio, PR                               2
# 3274    72151    PR    Yabucoa Municipio, PR                               1
# 3275    72153    PR      Yauco Municipio, PR                               2
#
#      Urban_influence_code_2013 Metro_2013 Civilian_labor_force_2000  \
# 1                          NaN        NaN                 142601667
# 2                          NaN        NaN                   2133223
# 3                            2          1                     21720
# 4                            2          1                     69533
# 5                            6          0                     11373
# ...                        ...        ...                       ...
# 3271                         1          1                     19805
# 3272                        12          0                      2441
# 3273                         2          1                      7636
# 3274                         1          1                     10613
# 3275                         2          1                     14664
#
#      Employed_2000 Unemployed_2000 Unemployment_rate_2000  ...  \
# 1        136904680         5696987                3.99504  ...
# 2          2035594           97629                    4.6  ...
# 3            20846             874                      4  ...
# 4            66971            2562                    3.7  ...
# 5            10748             625                    5.5  ...
# ...            ...             ...                    ...  ...
# 3271         17607            2198                   11.1  ...
# 3272          2120             321                   13.2  ...
# 3273          6648             988                   12.9  ...
# 3274          9005            1608                   15.2  ...
# 3275         12871            1793                   12.2  ...
#
#      Civilian_labor_force_2018 Employed_2018 Unemployed_2018  \
# 1                    161389026     155102319         6286707
# 2                      2216627       2130845           85782
# 3                        26196         25261             935
# 4                        95233         91809            3424
# 5                         8414          7987             427
# ...                        ...           ...             ...
# 3271                     13117         11750            1367
# 3272                      2718          2269             449
# 3273                      7311          6154            1157
# 3274                      8762          7509            1253
# 3275                      9716          8288            1428
#
#      Unemployment_rate_2018 Civilian_labor_force_2019 Employed_2019  \
# 1                   3.89537                 163100055     157115247
# 2                       3.9                   2241747       2174483
# 3                       3.6                     26172         25458
# 4                       3.6                     97328         94675
# 5                       5.1                      8537          8213
# ...                     ...                       ...           ...
# 3271                   10.4                     13037         11791
# 3272                   16.5                      2585          2406
# 3273                   15.8                      7406          6231
# 3274                   14.3                      8691          7552
# 3275                   14.7                      9759          8331
#
#      Unemployed_2019 Unemployment_rate_2019 Median_Household_Income_2019  \
# 1            5984808                3.66941                        65712
# 2              67264                      3                        51771
# 3                714                    2.7                        58233
# 4               2653                    2.7                        59871
# 5                324                    3.8                        35972
# ...              ...                    ...                          ...
# 3271            1246                    9.6                          NaN
# 3272             179                    6.9                          NaN
# 3273            1175                   15.9                          NaN
# 3274            1139                   13.1                          NaN
# 3275            1428                   14.6                          NaN
#
#      Med_HH_Income_Percent_of_State_Total_2019
# 1                                          NaN
# 2                                          100
# 3                                      112.482
# 4                                      115.646
# 5                                      69.4829
# ...                                        ...
# 3271                                       NaN
# 3272                                       NaN
# 3273                                       NaN
# 3274                                       NaN
# 3275                                       NaN
#
# [3275 rows x 88 columns]

# %% [markdown]
# * fix header columns of csv file
# * remove empty rows

# %%
# used to remove other year data to keep only 2017-2019
display(unemployment2017_2019.columns)
cols_to_remove = unemployment2017_2019.iloc[:, 3:74].columns
unemployment2017_2019 = remove_col(unemployment2017_2019, cols_to_remove)


# unemployment2017_2019
# Out:
# Index(['fips_txt', 'Stabr', 'area_name', 'Rural_urban_continuum_code_2013',
#        'Urban_influence_code_2013', 'Metro_2013', 'Civilian_labor_force_2000',
#        'Employed_2000', 'Unemployed_2000', 'Unemployment_rate_2000',
#        'Civilian_labor_force_2001', 'Employed_2001', 'Unemployed_2001',
#        'Unemployment_rate_2001', 'Civilian_labor_force_2002', 'Employed_2002',
#        'Unemployed_2002', 'Unemployment_rate_2002',
#        'Civilian_labor_force_2003', 'Employed_2003', 'Unemployed_2003',
#        'Unemployment_rate_2003', 'Civilian_labor_force_2004', 'Employed_2004',
#        'Unemployed_2004', 'Unemployment_rate_2004',
#        'Civilian_labor_force_2005', 'Employed_2005', 'Unemployed_2005',
#        'Unemployment_rate_2005', 'Civilian_labor_force_2006', 'Employed_2006',
#        'Unemployed_2006', 'Unemployment_rate_2006',
#        'Civilian_labor_force_2007', 'Employed_2007', 'Unemployed_2007',
#        'Unemployment_rate_2007', 'Civilian_labor_force_2008', 'Employed_2008',
#        'Unemployed_2008', 'Unemployment_rate_2008',
#        'Civilian_labor_force_2009', 'Employed_2009', 'Unemployed_2009',
#        'Unemployment_rate_2009', 'Civilian_labor_force_2010', 'Employed_2010',
#        'Unemployed_2010', 'Unemployment_rate_2010',
#        'Civilian_labor_force_2011', 'Employed_2011', 'Unemployed_2011',
#        'Unemployment_rate_2011', 'Civilian_labor_force_2012', 'Employed_2012',
#        'Unemployed_2012', 'Unemployment_rate_2012',
#        'Civilian_labor_force_2013', 'Employed_2013', 'Unemployed_2013',
#        'Unemployment_rate_2013', 'Civilian_labor_force_2014', 'Employed_2014',
#        'Unemployed_2014', 'Unemployment_rate_2014',
#        'Civilian_labor_force_2015', 'Employed_2015', 'Unemployed_2015',
#        'Unemployment_rate_2015', 'Civilian_labor_force_2016', 'Employed_2016',
#        'Unemployed_2016', 'Unemployment_rate_2016',
#        'Civilian_labor_force_2017', 'Employed_2017', 'Unemployed_2017',
#        'Unemployment_rate_2017', 'Civilian_labor_force_2018', 'Employed_2018',
#        'Unemployed_2018', 'Unemployment_rate_2018',
#        'Civilian_labor_force_2019', 'Employed_2019', 'Unemployed_2019',
#        'Unemployment_rate_2019', 'Median_Household_Income_2019',
#        'Med_HH_Income_Percent_of_State_Total_2019'],
#       dtype='object')

# %%
unemployment_rates_2017_2019 = unemployment2017_2019.iloc[:,:-2]
display(unemployment_rates_2017_2019)
# Out:
#      fips_txt Stabr                area_name Civilian_labor_force_2017  \
# 1       00000    US            United States                 160158564
# 2       01000    AL                  Alabama                   2186869
# 3       01001    AL       Autauga County, AL                     26075
# 4       01003    AL       Baldwin County, AL                     92456
# 5       01005    AL       Barbour County, AL                      8349
# ...       ...   ...                      ...                       ...
# 3271    72145    PR  Vega Baja Municipio, PR                     13414
# 3272    72147    PR    Vieques Municipio, PR                      3027
# 3273    72149    PR   Villalba Municipio, PR                      7557
# 3274    72151    PR    Yabucoa Municipio, PR                      9000
# 3275    72153    PR      Yauco Municipio, PR                     10160
#
#      Employed_2017 Unemployed_2017 Unemployment_rate_2017  \
# 1        153183461         6975103                4.35512
# 2          2090373           96496                    4.4
# 3            25062            1013                    3.9
# 4            88711            3745                    4.1
# 5             7863             486                    5.8
# ...            ...             ...                    ...
# 3271         11746            1668                   12.4
# 3272          2589             438                   14.5
# 3273          6090            1467                   19.4
# 3274          7512            1488                   16.5
# 3275          8409            1751                   17.2
#
#      Civilian_labor_force_2018 Employed_2018 Unemployed_2018  \
# 1                    161389026     155102319         6286707
# 2                      2216627       2130845           85782
# 3                        26196         25261             935
# 4                        95233         91809            3424
# 5                         8414          7987             427
# ...                        ...           ...             ...
# 3271                     13117         11750            1367
# 3272                      2718          2269             449
# 3273                      7311          6154            1157
# 3274                      8762          7509            1253
# 3275                      9716          8288            1428
#
#      Unemployment_rate_2018 Civilian_labor_force_2019 Employed_2019  \
# 1                   3.89537                 163100055     157115247
# 2                       3.9                   2241747       2174483
# 3                       3.6                     26172         25458
# 4                       3.6                     97328         94675
# 5                       5.1                      8537          8213
# ...                     ...                       ...           ...
# 3271                   10.4                     13037         11791
# 3272                   16.5                      2585          2406
# 3273                   15.8                      7406          6231
# 3274                   14.3                      8691          7552
# 3275                   14.7                      9759          8331
#
#      Unemployed_2019 Unemployment_rate_2019
# 1            5984808                3.66941
# 2              67264                      3
# 3                714                    2.7
# 4               2653                    2.7
# 5                324                    3.8
# ...              ...                    ...
# 3271            1246                    9.6
# 3272             179                    6.9
# 3273            1175                   15.9
# 3274            1139                   13.1
# 3275            1428                   14.6
#
# [3275 rows x 15 columns]

# %% [markdown]
# * remove all other column data for years 2000 - 2016
# * make a df for only unemployment rates

# %%
# Retain only counties and not regions / individual state

UE_counties = unemployment_rates_2017_2019['area_name'].str.contains(',')
UE_county_rate = unemployment_rates_2017_2019.loc[UE_counties]

# %%
UE_county_rate.dropna(inplace=True)
UE_county_rate.reset_index(drop=True, inplace=True)

UE_county_rate.rename(columns={'fips_txt':'GeoFIPS'}, inplace=True)
# Out:
# <ipython-input-14-53a924a2cf8b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   UE_county_rate.dropna(inplace=True)
# /home/wkc/.local/lib/python3.8/site-packages/pandas/core/frame.py:4300: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %% [markdown]
# * 3 alaskan counties show unknown values;
# * These values will not be mergeable with aqi data as it we do not aqi data on those areas
# * drop these rows
# * Rename fips_txt to GeoFIPS

# %% [markdown]
# * we have 0 duplicates

# %%
display(UE_county_rate.info())

UE_county_rate['Unemployment_rate_2017'] = pd.to_numeric(UE_county_rate['Unemployment_rate_2017'], downcast='float')
UE_county_rate['Unemployment_rate_2018'] = pd.to_numeric(UE_county_rate['Unemployment_rate_2018'], downcast='float')
UE_county_rate['Unemployment_rate_2019'] = pd.to_numeric(UE_county_rate['Unemployment_rate_2019'], downcast='float')


for col in UE_county_rate.columns[[3,4,5,7,8,9,11,12,13]]:
    UE_county_rate[col] = pd.to_numeric(UE_county_rate[col], downcast='integer')


UE_county_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3218 entries, 0 to 3217
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   GeoFIPS                    3218 non-null   object
#  1   Stabr                      3218 non-null   object
#  2   area_name                  3218 non-null   object
#  3   Civilian_labor_force_2017  3218 non-null   object
#  4   Employed_2017              3218 non-null   object
#  5   Unemployed_2017            3218 non-null   object
#  6   Unemployment_rate_2017     3218 non-null   object
#  7   Civilian_labor_force_2018  3218 non-null   object
#  8   Employed_2018              3218 non-null   object
#  9   Unemployed_2018            3218 non-null   object
#  10  Unemployment_rate_2018     3218 non-null   object
#  11  Civilian_labor_force_2019  3218 non-null   object
#  12  Employed_2019              3218 non-null   object
#  13  Unemployed_2019            3218 non-null   object
#  14  Unemployment_rate_2019     3218 non-null   object
# dtypes: object(15)
# memory usage: 377.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3218 entries, 0 to 3217
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   GeoFIPS                    3218 non-null   object
#  1   Stabr                      3218 non-null   object
#  2   area_name                  3218 non-null   object
#  3   Civilian_labor_force_2017  3218 non-null   int32
#  4   Employed_2017              3218 non-null   int32
#  5   Unemployed_2017            3218 non-null   int32
#  6   Unemployment_rate_2017     3218 non-null   float32
#  7   Civilian_labor_force_2018  3218 non-null   int32
#  8   Employed_2018              3218 non-null   int32
#  9   Unemployed_2018            3218 non-null   int32
#  10  Unemployment_rate_2018     3218 non-null   float32
#  11  Civilian_labor_force_2019  3218 non-null   int32
#  12  Employed_2019              3218 non-null   int32
#  13  Unemployed_2019            3218 non-null   int32
#  14  Unemployment_rate_2019     3218 non-null   float32
# dtypes: float32(3), int32(9), object(3)
# memory usage: 226.4+ KB
# None
# <ipython-input-15-1d790d0a8427>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   UE_county_rate['Unemployment_rate_2017'] = pd.to_numeric(UE_county_rate['Unemployment_rate_2017'], downcast='float')
# <ipython-input-15-1d790d0a8427>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   UE_county_rate['Unemployment_rate_2018'] = pd.to_numeric(UE_county_rate['Unemployment_rate_2018'], downcast='float')
# <ipython-input-15-1d790d0a8427>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   UE_county_rate['Unemployment_rate_2019'] = pd.to_numeric(UE_county_rate['Unemployment_rate_2019'], downcast='float')
# <ipython-input-15-1d790d0a8427>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   UE_county_rate[col] = pd.to_numeric(UE_county_rate[col], downcast='integer')

# %% [markdown]
# * convert Unemployment rate columns to be type float

# %% [markdown]
# # clean up saipe data 2017

# %%
saipe_header = saipe2017.iloc[2, :].values
saipe_header
saipe2017.columns = saipe_header
saipe2017.drop([0,1,2], inplace=True)
saipe2017.reset_index(drop=True, inplace=True)
display(saipe2017)
# Out:
#      State FIPS Code County FIPS Code Postal Code               Name  \
# 0                 00              000          US      United States
# 1                 01              000          AL            Alabama
# 2                 01              001          AL     Autauga County
# 3                 01              003          AL     Baldwin County
# 4                 01              005          AL     Barbour County
# ...              ...              ...         ...                ...
# 3189              56              037          WY  Sweetwater County
# 3190              56              039          WY       Teton County
# 3191              56              041          WY       Uinta County
# 3192              56              043          WY    Washakie County
# 3193              56              045          WY      Weston County
#
#      Poverty Estimate, All Ages 90% CI Lower Bound 90% CI Upper Bound  \
# 0                      42583651           42342619           42824683
# 1                        802263             784517             820009
# 2                          7390               6147               8633
# 3                         21199              17444              24954
# 4                          7414               6325               8503
# ...                         ...                ...                ...
# 3189                       4253               3540               4966
# 3190                       1348               1021               1675
# 3191                       2067               1623               2511
# 3192                        845                632               1058
# 3193                        699                541                857
#
#      Poverty Percent, All Ages 90% CI Lower Bound 90% CI Upper Bound  ...  \
# 0                         13.4               13.3               13.5  ...
# 1                         16.9               16.5               17.3  ...
# 2                         13.4               11.1               15.7  ...
# 3                         10.1                8.3               11.9  ...
# 4                         33.4               28.5               38.3  ...
# ...                        ...                ...                ...  ...
# 3189                        10                8.3               11.7  ...
# 3190                       5.8                4.4                7.2  ...
# 3191                      10.2                  8               12.4  ...
# 3192                      10.7                  8               13.4  ...
# 3193                      10.6                8.2                 13  ...
#
#      90% CI Upper Bound Median Household Income 90% CI Lower Bound  \
# 0                  17.5                   60336              60250
# 1                  23.8                   48193              47451
# 2                  22.1                   58343              52121
# 3                  17.9                   56607              52439
# 4                    55                   32490              29218
# ...                 ...                     ...                ...
# 3189                 14                   75590              69190
# 3190                7.9                   90145              80434
# 3191               13.4                   67404              60925
# 3192               17.3                   57989              53142
# 3193               16.6                   56214              50250
#
#      90% CI Upper Bound Poverty Estimate, Age 0-4 90% CI Lower Bound  \
# 0                 60422                   3932969            3880645
# 1                 48935                     78986              75009
# 2                 64565                         .                  .
# 3                 60775                         .                  .
# 4                 35762                         .                  .
# ...                 ...                       ...                ...
# 3189              81990                         .                  .
# 3190              99856                         .                  .
# 3191              73883                         .                  .
# 3192              62836                         .                  .
# 3193              62178                         .                  .
#
#      90% CI Upper Bound Poverty Percent, Age 0-4 90% CI Lower Bound  \
# 0               3985293                     20.2               19.9
# 1                 82963                     27.7               26.3
# 2                     .                        .                  .
# 3                     .                        .                  .
# 4                     .                        .                  .
# ...                 ...                      ...                ...
# 3189                  .                        .                  .
# 3190                  .                        .                  .
# 3191                  .                        .                  .
# 3192                  .                        .                  .
# 3193                  .                        .                  .
#
#      90% CI Upper Bound
# 0                  20.5
# 1                  29.1
# 2                     .
# 3                     .
# 4                     .
# ...                 ...
# 3189                  .
# 3190                  .
# 3191                  .
# 3192                  .
# 3193                  .
#
# [3194 rows x 31 columns]

# %%
saipe2017.columns
saipe2017.iloc[:, [1,2,3,4,7]]
saipe_county = saipe2017['Name'].str.contains('County')
pov_rate_2017 = saipe2017.loc[saipe_county].iloc[:, :-6]
pov_rate_2017.reset_index(drop=True, inplace=True)
display(pov_rate_2017)
# Out:
#      State FIPS Code County FIPS Code Postal Code               Name  \
# 0                 01              001          AL     Autauga County
# 1                 01              003          AL     Baldwin County
# 2                 01              005          AL     Barbour County
# 3                 01              007          AL        Bibb County
# 4                 01              009          AL      Blount County
# ...              ...              ...         ...                ...
# 3002              56              037          WY  Sweetwater County
# 3003              56              039          WY       Teton County
# 3004              56              041          WY       Uinta County
# 3005              56              043          WY    Washakie County
# 3006              56              045          WY      Weston County
#
#      Poverty Estimate, All Ages 90% CI Lower Bound 90% CI Upper Bound  \
# 0                          7390               6147               8633
# 1                         21199              17444              24954
# 2                          7414               6325               8503
# 3                          4137               3187               5087
# 4                          7343               5805               8881
# ...                         ...                ...                ...
# 3002                       4253               3540               4966
# 3003                       1348               1021               1675
# 3004                       2067               1623               2511
# 3005                        845                632               1058
# 3006                        699                541                857
#
#      Poverty Percent, All Ages 90% CI Lower Bound 90% CI Upper Bound  ...  \
# 0                         13.4               11.1               15.7  ...
# 1                         10.1                8.3               11.9  ...
# 2                         33.4               28.5               38.3  ...
# 3                         20.2               15.5               24.9  ...
# 4                         12.8               10.1               15.5  ...
# ...                        ...                ...                ...  ...
# 3002                        10                8.3               11.7  ...
# 3003                       5.8                4.4                7.2  ...
# 3004                      10.2                  8               12.4  ...
# 3005                      10.7                  8               13.4  ...
# 3006                      10.6                8.2                 13  ...
#
#      90% CI Upper Bound Poverty Estimate, Age 5-17 in Families  \
# 0                  22.8                                   1842
# 1                  18.3                                   4871
# 2                  56.9                                   1904
# 3                    34                                    870
# 4                    23                                   1763
# ...                 ...                                    ...
# 3002               15.9                                    972
# 3003                8.9                                    189
# 3004               15.1                                    445
# 3005               18.2                                    185
# 3006               18.1                                    130
#
#      90% CI Lower Bound 90% CI Upper Bound  \
# 0                  1492               2192
# 1                  3641               6101
# 2                  1660               2148
# 3                   641               1099
# 4                  1307               2219
# ...                 ...                ...
# 3002                769               1175
# 3003                128                250
# 3004                304                586
# 3005                125                245
# 3006                 88                172
#
#      Poverty Percent, Age 5-17 in Families 90% CI Lower Bound  \
# 0                                     18.6               15.1
# 1                                     14.3               10.7
# 2                                     48.8               42.6
# 3                                     26.8               19.8
# 4                                     17.7               13.1
# ...                                    ...                ...
# 3002                                  11.6                9.2
# 3003                                     6                4.1
# 3004                                  10.2                  7
# 3005                                  13.1                8.9
# 3006                                  12.6                8.6
#
#      90% CI Upper Bound Median Household Income 90% CI Lower Bound  \
# 0                  22.1                   58343              52121
# 1                  17.9                   56607              52439
# 2                    55                   32490              29218
# 3                  33.8                   45795              40924
# 4                  22.3                   48253              43784
# ...                 ...                     ...                ...
# 3002                 14                   75590              69190
# 3003                7.9                   90145              80434
# 3004               13.4                   67404              60925
# 3005               17.3                   57989              53142
# 3006               16.6                   56214              50250
#
#      90% CI Upper Bound
# 0                 64565
# 1                 60775
# 2                 35762
# 3                 50666
# 4                 52722
# ...                 ...
# 3002              81990
# 3003              99856
# 3004              73883
# 3005              62836
# 3006              62178
#
# [3007 rows x 25 columns]

# %% [markdown]
# * Remove empty cells and clean up columns
# * Retain only US county information and poverty rates for all ages

# %%
print(pov_rate_2017.isnull().sum())
print(pov_rate_2017.duplicated().sum())
display(pov_rate_2017.info())
# Out:
# State FIPS Code                           0
# County FIPS Code                          0
# Postal Code                               0
# Name                                      0
# Poverty Estimate, All Ages                0
# 90% CI Lower Bound                        0
# 90% CI Upper Bound                        0
# Poverty Percent, All Ages                 0
# 90% CI Lower Bound                        0
# 90% CI Upper Bound                        0
# Poverty Estimate, Age 0-17                0
# 90% CI Lower Bound                        0
# 90% CI Upper Bound                        0
# Poverty Percent, Age 0-17                 0
# 90% CI Lower Bound                        0
# 90% CI Upper Bound                        0
# Poverty Estimate, Age 5-17 in Families    0
# 90% CI Lower Bound                        0
# 90% CI Upper Bound                        0
# Poverty Percent, Age 5-17 in Families     0
# 90% CI Lower Bound                        0
# 90% CI Upper Bound                        0
# Median Household Income                   0
# 90% CI Lower Bound                        0
# 90% CI Upper Bound                        0
# dtype: int64
# 0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3007 entries, 0 to 3006
# Data columns (total 25 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   State FIPS Code                         3007 non-null   object
#  1   County FIPS Code                        3007 non-null   object
#  2   Postal Code                             3007 non-null   object
#  3   Name                                    3007 non-null   object
#  4   Poverty Estimate, All Ages              3007 non-null   object
#  5   90% CI Lower Bound                      3007 non-null   object
#  6   90% CI Upper Bound                      3007 non-null   object
#  7   Poverty Percent, All Ages               3007 non-null   object
#  8   90% CI Lower Bound                      3007 non-null   object
#  9   90% CI Upper Bound                      3007 non-null   object
#  10  Poverty Estimate, Age 0-17              3007 non-null   object
#  11  90% CI Lower Bound                      3007 non-null   object
#  12  90% CI Upper Bound                      3007 non-null   object
#  13  Poverty Percent, Age 0-17               3007 non-null   object
#  14  90% CI Lower Bound                      3007 non-null   object
#  15  90% CI Upper Bound                      3007 non-null   object
#  16  Poverty Estimate, Age 5-17 in Families  3007 non-null   object
#  17  90% CI Lower Bound                      3007 non-null   object
#  18  90% CI Upper Bound                      3007 non-null   object
#  19  Poverty Percent, Age 5-17 in Families   3007 non-null   object
#  20  90% CI Lower Bound                      3007 non-null   object
#  21  90% CI Upper Bound                      3007 non-null   object
#  22  Median Household Income                 3007 non-null   object
#  23  90% CI Lower Bound                      3007 non-null   object
#  24  90% CI Upper Bound                      3007 non-null   object
# dtypes: object(25)
# memory usage: 587.4+ KB
# None

# %% [markdown]
# * No duplicates or missing values for poverty rates in 2017
# * also convert poverty percent to float

# %%
pov_rate_2017.info()

pov_rate_2017.drop(518, inplace=True)

# pov_rate_2017['Poverty Percent, All Ages'] = pd.to_numeric(pov_rate_2017['Poverty Percent, All Ages'], downcast='float')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3007 entries, 0 to 3006
# Data columns (total 25 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   State FIPS Code                         3007 non-null   object
#  1   County FIPS Code                        3007 non-null   object
#  2   Postal Code                             3007 non-null   object
#  3   Name                                    3007 non-null   object
#  4   Poverty Estimate, All Ages              3007 non-null   object
#  5   90% CI Lower Bound                      3007 non-null   object
#  6   90% CI Upper Bound                      3007 non-null   object
#  7   Poverty Percent, All Ages               3007 non-null   object
#  8   90% CI Lower Bound                      3007 non-null   object
#  9   90% CI Upper Bound                      3007 non-null   object
#  10  Poverty Estimate, Age 0-17              3007 non-null   object
#  11  90% CI Lower Bound                      3007 non-null   object
#  12  90% CI Upper Bound                      3007 non-null   object
#  13  Poverty Percent, Age 0-17               3007 non-null   object
#  14  90% CI Lower Bound                      3007 non-null   object
#  15  90% CI Upper Bound                      3007 non-null   object
#  16  Poverty Estimate, Age 5-17 in Families  3007 non-null   object
#  17  90% CI Lower Bound                      3007 non-null   object
#  18  90% CI Upper Bound                      3007 non-null   object
#  19  Poverty Percent, Age 5-17 in Families   3007 non-null   object
#  20  90% CI Lower Bound                      3007 non-null   object
#  21  90% CI Upper Bound                      3007 non-null   object
#  22  Median Household Income                 3007 non-null   object
#  23  90% CI Lower Bound                      3007 non-null   object
#  24  90% CI Upper Bound                      3007 non-null   object
# dtypes: object(25)
# memory usage: 587.4+ KB

# %%
pov_rate_2017.columns = ['State FIPS Code', 'County FIPS Code', 'Postal Code', 'Name',
       'Poverty Estimate, All Ages', '90% CI LB All Ages',
       '90% CI UB All Ages', 'Poverty Percent, All Ages', '90% CI LB percent',
       '90% CI UB percent', 'Poverty Estimate, Age 0-17',
       '90% CI LB percent 0-17', '90% CI UB 0-17', 'Poverty Percent, Age 0-17',
       '90% CI LB percent 0-17 percent', '90% CI UB 0-17 percent',
       'Poverty Estimate, Age 5-17 in Families', '90% CI LB 5-17 fam',
       '90% CI UB 5-17 fam', 'Poverty Percent, Age 5-17 in Families',
       '90% CI LB 5-17 percent', '90% CI UB percent 5-17 percent', 'Median Household Income',
       '90% CI Lower Bound LB medh inc', '90% CI UB medh inc']

pov_cols = pov_rate_2017.columns[4:]

# %%
for col in pov_cols:
    pov_rate_2017[col] = pd.to_numeric(pov_rate_2017[col], downcast='float')

pov_rate_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3006 entries, 0 to 3006
# Data columns (total 25 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   State FIPS Code                         3006 non-null   object
#  1   County FIPS Code                        3006 non-null   object
#  2   Postal Code                             3006 non-null   object
#  3   Name                                    3006 non-null   object
#  4   Poverty Estimate, All Ages              3006 non-null   float32
#  5   90% CI LB All Ages                      3006 non-null   float32
#  6   90% CI UB All Ages                      3006 non-null   float32
#  7   Poverty Percent, All Ages               3006 non-null   float32
#  8   90% CI LB percent                       3006 non-null   float32
#  9   90% CI UB percent                       3006 non-null   float32
#  10  Poverty Estimate, Age 0-17              3006 non-null   float32
#  11  90% CI LB percent 0-17                  3006 non-null   float32
#  12  90% CI UB 0-17                          3006 non-null   float32
#  13  Poverty Percent, Age 0-17               3006 non-null   float32
#  14  90% CI LB percent 0-17 percent          3006 non-null   float32
#  15  90% CI UB 0-17 percent                  3006 non-null   float32
#  16  Poverty Estimate, Age 5-17 in Families  3006 non-null   float32
#  17  90% CI LB 5-17 fam                      3006 non-null   float32
#  18  90% CI UB 5-17 fam                      3006 non-null   float32
#  19  Poverty Percent, Age 5-17 in Families   3006 non-null   float32
#  20  90% CI LB 5-17 percent                  3006 non-null   float32
#  21  90% CI UB percent 5-17 percent          3006 non-null   float32
#  22  Median Household Income                 3006 non-null   float32
#  23  90% CI Lower Bound LB medh inc          3006 non-null   float32
#  24  90% CI UB medh inc                      3006 non-null   float32
# dtypes: float32(21), object(4)
# memory usage: 364.0+ KB

# %% [markdown]
# * from further inspection it was noted that Kalawao county is now excluded in their survey results starting 2017
# * Kalawao county records removed
# * Poverty rates in Hawaii appear to around 10-20s

# %% [markdown]
# # Repeat clean up steps on saipe data 2018

# %%
saipe_header = saipe2018.iloc[2, :].values
saipe_header
saipe2018.columns = saipe_header
saipe2018.drop([0,1,2], inplace=True)
saipe2018.reset_index(drop=True, inplace=True)
display(saipe2018)
# Out:
#      State FIPS Code County FIPS Code Postal Code               Name  \
# 0                 00              000          US      United States
# 1                 01              000          AL            Alabama
# 2                 01              001          AL     Autauga County
# 3                 01              003          AL     Baldwin County
# 4                 01              005          AL     Barbour County
# ...              ...              ...         ...                ...
# 3189              56              037          WY  Sweetwater County
# 3190              56              039          WY       Teton County
# 3191              56              041          WY       Uinta County
# 3192              56              043          WY    Washakie County
# 3193              56              045          WY      Weston County
#
#      Poverty Estimate, All Ages 90% CI Lower Bound 90% CI Upper Bound  \
# 0                      41852315           41619366           42085264
# 1                        801758             785668             817848
# 2                          7587               6334               8840
# 3                         21069              17390              24748
# 4                          6788               5662               7914
# ...                         ...                ...                ...
# 3189                       3540               2804               4276
# 3190                       1443               1137               1749
# 3191                       2010               1585               2435
# 3192                        918                700               1136
# 3193                        777                608                946
#
#      Poverty Percent, All Ages 90% CI Lower Bound 90% CI Upper Bound  ...  \
# 0                         13.1                 13               13.2  ...
# 1                         16.8               16.5               17.1  ...
# 2                         13.8               11.5               16.1  ...
# 3                          9.8                8.1               11.5  ...
# 4                         30.9               25.8                 36  ...
# ...                        ...                ...                ...  ...
# 3189                       8.4                6.7               10.1  ...
# 3190                       6.3                  5                7.6  ...
# 3191                        10                7.9               12.1  ...
# 3192                      11.9                9.1               14.7  ...
# 3193                      11.8                9.2               14.4  ...
#
#      90% CI Upper Bound Median Household Income 90% CI Lower Bound  \
# 0                  17.2                   61937              61843
# 1                  23.7                   49881              49123
# 2                  23.9                   59338              53628
# 3                  16.9                   57588              54437
# 4                  45.9                   34382              31157
# ...                 ...                     ...                ...
# 3189               11.2                   73315              67141
# 3190                7.7                   99087              88142
# 3191                 14                   63401              56812
# 3192               19.3                   55190              49263
# 3193               19.1                   54319              48315
#
#      90% CI Upper Bound Poverty Estimate, Age 0-4 90% CI Lower Bound  \
# 0                 62031                   3758704            3714862
# 1                 50639                     73915              69990
# 2                 65048                         .                  .
# 3                 60739                         .                  .
# 4                 37607                         .                  .
# ...                 ...                       ...                ...
# 3189              79489                         .                  .
# 3190             110032                         .                  .
# 3191              69990                         .                  .
# 3192              61117                         .                  .
# 3193              60323                         .                  .
#
#      90% CI Upper Bound Poverty Percent, Age 0-4 90% CI Lower Bound  \
# 0               3802546                     19.5               19.3
# 1                 77840                       26               24.6
# 2                     .                        .                  .
# 3                     .                        .                  .
# 4                     .                        .                  .
# ...                 ...                      ...                ...
# 3189                  .                        .                  .
# 3190                  .                        .                  .
# 3191                  .                        .                  .
# 3192                  .                        .                  .
# 3193                  .                        .                  .
#
#      90% CI Upper Bound
# 0                  19.7
# 1                  27.4
# 2                     .
# 3                     .
# 4                     .
# ...                 ...
# 3189                  .
# 3190                  .
# 3191                  .
# 3192                  .
# 3193                  .
#
# [3194 rows x 31 columns]

# %%
saipe2018.columns
saipe2018.iloc[:, [1,2,3,4,7]]
saipe_county = saipe2018['Name'].str.contains('County')
pov_rate_2018 = saipe2018.loc[saipe_county].iloc[:, :-6]
pov_rate_2018.reset_index(drop=True, inplace=True)
display(pov_rate_2018)
# Out:
#      State FIPS Code County FIPS Code Postal Code               Name  \
# 0                 01              001          AL     Autauga County
# 1                 01              003          AL     Baldwin County
# 2                 01              005          AL     Barbour County
# 3                 01              007          AL        Bibb County
# 4                 01              009          AL      Blount County
# ...              ...              ...         ...                ...
# 3002              56              037          WY  Sweetwater County
# 3003              56              039          WY       Teton County
# 3004              56              041          WY       Uinta County
# 3005              56              043          WY    Washakie County
# 3006              56              045          WY      Weston County
#
#      Poverty Estimate, All Ages 90% CI Lower Bound 90% CI Upper Bound  \
# 0                          7587               6334               8840
# 1                         21069              17390              24748
# 2                          6788               5662               7914
# 3                          4400               3445               5355
# 4                          7527               6045               9009
# ...                         ...                ...                ...
# 3002                       3540               2804               4276
# 3003                       1443               1137               1749
# 3004                       2010               1585               2435
# 3005                        918                700               1136
# 3006                        777                608                946
#
#      Poverty Percent, All Ages 90% CI Lower Bound 90% CI Upper Bound  ...  \
# 0                         13.8               11.5               16.1  ...
# 1                          9.8                8.1               11.5  ...
# 2                         30.9               25.8                 36  ...
# 3                         21.8               17.1               26.5  ...
# 4                         13.2               10.6               15.8  ...
# ...                        ...                ...                ...  ...
# 3002                       8.4                6.7               10.1  ...
# 3003                       6.3                  5                7.6  ...
# 3004                        10                7.9               12.1  ...
# 3005                      11.9                9.1               14.7  ...
# 3006                      11.8                9.2               14.4  ...
#
#      90% CI Upper Bound Poverty Estimate, Age 5-17 in Families  \
# 0                  23.5                                   1891
# 1                  17.6                                   4534
# 2                  52.8                                   1411
# 3                  34.9                                    840
# 4                  22.5                                   1520
# ...                 ...                                    ...
# 3002               12.7                                    697
# 3003                8.5                                    180
# 3004               15.6                                    454
# 3005               20.8                                    191
# 3006               20.9                                    150
#
#      90% CI Lower Bound 90% CI Upper Bound  \
# 0                  1469               2313
# 1                  3223               5845
# 2                  1056               1766
# 3                   606               1074
# 4                  1053               1987
# ...                 ...                ...
# 3002                479                915
# 3003                126                234
# 3004                306                602
# 3005                127                255
# 3006                 99                201
#
#      Poverty Percent, Age 5-17 in Families 90% CI Lower Bound  \
# 0                                     19.5               15.1
# 1                                     13.1                9.3
# 2                                     36.7               27.5
# 3                                     26.3                 19
# 4                                     15.5               10.7
# ...                                    ...                ...
# 3002                                   8.5                5.8
# 3003                                   5.9                4.1
# 3004                                  10.6                7.2
# 3005                                  14.5                9.7
# 3006                                  14.2                9.3
#
#      90% CI Upper Bound Median Household Income 90% CI Lower Bound  \
# 0                  23.9                   59338              53628
# 1                  16.9                   57588              54437
# 2                  45.9                   34382              31157
# 3                  33.6                   46064              41283
# 4                  20.3                   50412              46157
# ...                 ...                     ...                ...
# 3002               11.2                   73315              67141
# 3003                7.7                   99087              88142
# 3004                 14                   63401              56812
# 3005               19.3                   55190              49263
# 3006               19.1                   54319              48315
#
#      90% CI Upper Bound
# 0                 65048
# 1                 60739
# 2                 37607
# 3                 50845
# 4                 54667
# ...                 ...
# 3002              79489
# 3003             110032
# 3004              69990
# 3005              61117
# 3006              60323
#
# [3007 rows x 25 columns]

# %% [markdown]
# * Remove empty cells and clean up columns
# * Retain only US county information and poverty rates for all ages

# %%
print(pov_rate_2017.isnull().sum())
print(pov_rate_2017.duplicated().sum())
display(pov_rate_2017.info())
# Out:
# State FIPS Code                           0
# County FIPS Code                          0
# Postal Code                               0
# Name                                      0
# Poverty Estimate, All Ages                0
# 90% CI LB All Ages                        0
# 90% CI UB All Ages                        0
# Poverty Percent, All Ages                 0
# 90% CI LB percent                         0
# 90% CI UB percent                         0
# Poverty Estimate, Age 0-17                0
# 90% CI LB percent 0-17                    0
# 90% CI UB 0-17                            0
# Poverty Percent, Age 0-17                 0
# 90% CI LB percent 0-17 percent            0
# 90% CI UB 0-17 percent                    0
# Poverty Estimate, Age 5-17 in Families    0
# 90% CI LB 5-17 fam                        0
# 90% CI UB 5-17 fam                        0
# Poverty Percent, Age 5-17 in Families     0
# 90% CI LB 5-17 percent                    0
# 90% CI UB percent 5-17 percent            0
# Median Household Income                   0
# 90% CI Lower Bound LB medh inc            0
# 90% CI UB medh inc                        0
# dtype: int64
# 0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3006 entries, 0 to 3006
# Data columns (total 25 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   State FIPS Code                         3006 non-null   object
#  1   County FIPS Code                        3006 non-null   object
#  2   Postal Code                             3006 non-null   object
#  3   Name                                    3006 non-null   object
#  4   Poverty Estimate, All Ages              3006 non-null   float32
#  5   90% CI LB All Ages                      3006 non-null   float32
#  6   90% CI UB All Ages                      3006 non-null   float32
#  7   Poverty Percent, All Ages               3006 non-null   float32
#  8   90% CI LB percent                       3006 non-null   float32
#  9   90% CI UB percent                       3006 non-null   float32
#  10  Poverty Estimate, Age 0-17              3006 non-null   float32
#  11  90% CI LB percent 0-17                  3006 non-null   float32
#  12  90% CI UB 0-17                          3006 non-null   float32
#  13  Poverty Percent, Age 0-17               3006 non-null   float32
#  14  90% CI LB percent 0-17 percent          3006 non-null   float32
#  15  90% CI UB 0-17 percent                  3006 non-null   float32
#  16  Poverty Estimate, Age 5-17 in Families  3006 non-null   float32
#  17  90% CI LB 5-17 fam                      3006 non-null   float32
#  18  90% CI UB 5-17 fam                      3006 non-null   float32
#  19  Poverty Percent, Age 5-17 in Families   3006 non-null   float32
#  20  90% CI LB 5-17 percent                  3006 non-null   float32
#  21  90% CI UB percent 5-17 percent          3006 non-null   float32
#  22  Median Household Income                 3006 non-null   float32
#  23  90% CI Lower Bound LB medh inc          3006 non-null   float32
#  24  90% CI UB medh inc                      3006 non-null   float32
# dtypes: float32(21), object(4)
# memory usage: 364.0+ KB
# None

# %% [markdown]
# * No duplicates or missing values for poverty rates in 2017
# * also convert poverty percent to float

# %%
pov_rate_2018.info()

pov_rate_2018.drop(518, inplace=True)
# pov_rate_2017['Poverty Percent, All Ages'] = pd.to_numeric(pov_rate_2017['Poverty Percent, All Ages'], downcast='float')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3007 entries, 0 to 3006
# Data columns (total 25 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   State FIPS Code                         3007 non-null   object
#  1   County FIPS Code                        3007 non-null   object
#  2   Postal Code                             3007 non-null   object
#  3   Name                                    3007 non-null   object
#  4   Poverty Estimate, All Ages              3007 non-null   object
#  5   90% CI Lower Bound                      3007 non-null   object
#  6   90% CI Upper Bound                      3007 non-null   object
#  7   Poverty Percent, All Ages               3007 non-null   object
#  8   90% CI Lower Bound                      3007 non-null   object
#  9   90% CI Upper Bound                      3007 non-null   object
#  10  Poverty Estimate, Age 0-17              3007 non-null   object
#  11  90% CI Lower Bound                      3007 non-null   object
#  12  90% CI Upper Bound                      3007 non-null   object
#  13  Poverty Percent, Age 0-17               3007 non-null   object
#  14  90% CI Lower Bound                      3007 non-null   object
#  15  90% CI Upper Bound                      3007 non-null   object
#  16  Poverty Estimate, Age 5-17 in Families  3007 non-null   object
#  17  90% CI Lower Bound                      3007 non-null   object
#  18  90% CI Upper Bound                      3007 non-null   object
#  19  Poverty Percent, Age 5-17 in Families   3007 non-null   object
#  20  90% CI Lower Bound                      3007 non-null   object
#  21  90% CI Upper Bound                      3007 non-null   object
#  22  Median Household Income                 3007 non-null   object
#  23  90% CI Lower Bound                      3007 non-null   object
#  24  90% CI Upper Bound                      3007 non-null   object
# dtypes: object(25)
# memory usage: 587.4+ KB

# %%
pov_rate_2018.columns = ['State FIPS Code', 'County FIPS Code', 'Postal Code', 'Name',
       'Poverty Estimate, All Ages', '90% CI LB All Ages',
       '90% CI UB All Ages', 'Poverty Percent, All Ages', '90% CI LB percent',
       '90% CI UB percent', 'Poverty Estimate, Age 0-17',
       '90% CI LB percent 0-17', '90% CI UB 0-17', 'Poverty Percent, Age 0-17',
       '90% CI LB percent 0-17 percent', '90% CI UB 0-17 percent',
       'Poverty Estimate, Age 5-17 in Families', '90% CI LB 5-17 fam',
       '90% CI UB 5-17 fam', 'Poverty Percent, Age 5-17 in Families',
       '90% CI LB 5-17 percent', '90% CI UB percent 5-17 percent', 'Median Household Income',
       '90% CI Lower Bound LB medh inc', '90% CI UB medh inc']

pov_cols = pov_rate_2018.columns[4:]

# %%
for col in pov_cols:
    pov_rate_2018[col] = pd.to_numeric(pov_rate_2018[col], downcast='float')

pov_rate_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3006 entries, 0 to 3006
# Data columns (total 25 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   State FIPS Code                         3006 non-null   object
#  1   County FIPS Code                        3006 non-null   object
#  2   Postal Code                             3006 non-null   object
#  3   Name                                    3006 non-null   object
#  4   Poverty Estimate, All Ages              3006 non-null   float32
#  5   90% CI LB All Ages                      3006 non-null   float32
#  6   90% CI UB All Ages                      3006 non-null   float32
#  7   Poverty Percent, All Ages               3006 non-null   float32
#  8   90% CI LB percent                       3006 non-null   float32
#  9   90% CI UB percent                       3006 non-null   float32
#  10  Poverty Estimate, Age 0-17              3006 non-null   float32
#  11  90% CI LB percent 0-17                  3006 non-null   float32
#  12  90% CI UB 0-17                          3006 non-null   float32
#  13  Poverty Percent, Age 0-17               3006 non-null   float32
#  14  90% CI LB percent 0-17 percent          3006 non-null   float32
#  15  90% CI UB 0-17 percent                  3006 non-null   float32
#  16  Poverty Estimate, Age 5-17 in Families  3006 non-null   float32
#  17  90% CI LB 5-17 fam                      3006 non-null   float32
#  18  90% CI UB 5-17 fam                      3006 non-null   float32
#  19  Poverty Percent, Age 5-17 in Families   3006 non-null   float32
#  20  90% CI LB 5-17 percent                  3006 non-null   float32
#  21  90% CI UB percent 5-17 percent          3006 non-null   float32
#  22  Median Household Income                 3006 non-null   float32
#  23  90% CI Lower Bound LB medh inc          3006 non-null   float32
#  24  90% CI UB medh inc                      3006 non-null   float32
# dtypes: float32(21), object(4)
# memory usage: 364.0+ KB

# %% [markdown]
# * from further inspection it was noted that Kalawao county is now excluded in their survey results starting 2017
# * Kalawao county records removed
# * Poverty rates in Hawaii appear to around 10-20s

# %% [markdown]
# # Repeat clean up steps for saipe data 2019

# %%
saipe_header = saipe2019.iloc[2, :].values
saipe_header
saipe2019.columns = saipe_header
saipe2019.drop([0,1,2], inplace=True)
saipe2019.reset_index(drop=True, inplace=True)
display(saipe2019)
# Out:
#      State FIPS Code County FIPS Code Postal Code               Name  \
# 0                 00              000          US      United States
# 1                 01              000          AL            Alabama
# 2                 01              001          AL     Autauga County
# 3                 01              003          AL     Baldwin County
# 4                 01              005          AL     Barbour County
# ...              ...              ...         ...                ...
# 3189              56              037          WY  Sweetwater County
# 3190              56              039          WY       Teton County
# 3191              56              041          WY       Uinta County
# 3192              56              043          WY    Washakie County
# 3193              56              045          WY      Weston County
#
#      Poverty Estimate, All Ages 90% CI Lower Bound 90% CI Upper Bound  \
# 0                      39490096           39248096           39732096
# 1                        747478             730491             764465
# 2                          6723               5517               7929
# 3                         22360              18541              26179
# 4                          5909               4787               7031
# ...                         ...                ...                ...
# 3189                       3453               2743               4163
# 3190                       1396               1073               1719
# 3191                       1699               1264               2134
# 3192                        845                626               1064
# 3193                        692                523                861
#
#      Poverty Percent, All Ages 90% CI Lower Bound 90% CI Upper Bound  ...  \
# 0                         12.3               12.2               12.4  ...
# 1                         15.6               15.2                 16  ...
# 2                         12.1                9.9               14.3  ...
# 3                         10.1                8.4               11.8  ...
# 4                         27.1                 22               32.2  ...
# ...                        ...                ...                ...  ...
# 3189                       8.3                6.6                 10  ...
# 3190                         6                4.6                7.4  ...
# 3191                       8.5                6.3               10.7  ...
# 3192                      11.1                8.2                 14  ...
# 3193                      10.5                7.9               13.1  ...
#
#      90% CI Upper Bound Median Household Income 90% CI Lower Bound  \
# 0                    16                   65712              65594
# 1                  21.6                   51771              51179
# 2                  19.4                   58233              52517
# 3                  17.2                   59871              54593
# 4                    49                   35972              31822
# ...                 ...                     ...                ...
# 3189               11.1                   80639              73437
# 3190                6.7                   98837              86531
# 3191               11.1                   70756              63191
# 3192               17.4                   55122              50050
# 3193               16.7                   59410              52275
#
#      90% CI Upper Bound Poverty Estimate, Age 0-4 90% CI Lower Bound  \
# 0                 65830                   3457689            3405854
# 1                 52363                     69236              65296
# 2                 63949                         .                  .
# 3                 65149                         .                  .
# 4                 40122                         .                  .
# ...                 ...                       ...                ...
# 3189              87841                         .                  .
# 3190             111143                         .                  .
# 3191              78321                         .                  .
# 3192              60194                         .                  .
# 3193              66545                         .                  .
#
#      90% CI Upper Bound Poverty Percent, Age 0-4 90% CI Lower Bound  \
# 0               3509524                     18.2               17.9
# 1                 73176                     24.2               22.8
# 2                     .                        .                  .
# 3                     .                        .                  .
# 4                     .                        .                  .
# ...                 ...                      ...                ...
# 3189                  .                        .                  .
# 3190                  .                        .                  .
# 3191                  .                        .                  .
# 3192                  .                        .                  .
# 3193                  .                        .                  .
#
#      90% CI Upper Bound
# 0                  18.5
# 1                  25.6
# 2                     .
# 3                     .
# 4                     .
# ...                 ...
# 3189                  .
# 3190                  .
# 3191                  .
# 3192                  .
# 3193                  .
#
# [3194 rows x 31 columns]

# %%
saipe2019.columns
saipe2019.iloc[:, [1,2,3,4,7]]
saipe_county = saipe2019['Name'].str.contains('County')
pov_rate_2019 = saipe2019.loc[saipe_county].iloc[:, :-6]
pov_rate_2019.reset_index(drop=True, inplace=True)
display(pov_rate_2019)
# Out:
#      State FIPS Code County FIPS Code Postal Code               Name  \
# 0                 01              001          AL     Autauga County
# 1                 01              003          AL     Baldwin County
# 2                 01              005          AL     Barbour County
# 3                 01              007          AL        Bibb County
# 4                 01              009          AL      Blount County
# ...              ...              ...         ...                ...
# 3002              56              037          WY  Sweetwater County
# 3003              56              039          WY       Teton County
# 3004              56              041          WY       Uinta County
# 3005              56              043          WY    Washakie County
# 3006              56              045          WY      Weston County
#
#      Poverty Estimate, All Ages 90% CI Lower Bound 90% CI Upper Bound  \
# 0                          6723               5517               7929
# 1                         22360              18541              26179
# 2                          5909               4787               7031
# 3                          4101               3225               4977
# 4                          9324               8037              10611
# ...                         ...                ...                ...
# 3002                       3453               2743               4163
# 3003                       1396               1073               1719
# 3004                       1699               1264               2134
# 3005                        845                626               1064
# 3006                        692                523                861
#
#      Poverty Percent, All Ages 90% CI Lower Bound 90% CI Upper Bound  ...  \
# 0                         12.1                9.9               14.3  ...
# 1                         10.1                8.4               11.8  ...
# 2                         27.1                 22               32.2  ...
# 3                         20.3                 16               24.6  ...
# 4                         16.3               14.1               18.5  ...
# ...                        ...                ...                ...  ...
# 3002                       8.3                6.6                 10  ...
# 3003                         6                4.6                7.4  ...
# 3004                       8.5                6.3               10.7  ...
# 3005                      11.1                8.2                 14  ...
# 3006                      10.5                7.9               13.1  ...
#
#      90% CI Upper Bound Poverty Estimate, Age 5-17 in Families  \
# 0                  20.3                                   1376
# 1                  17.4                                   4641
# 2                  50.8                                   1468
# 3                  33.1                                    808
# 4                  25.3                                   2067
# ...                 ...                                    ...
# 3002                 13                                    644
# 3003                7.8                                    142
# 3004               13.1                                    336
# 3005               18.9                                    160
# 3006               18.7                                    120
#
#      90% CI Lower Bound 90% CI Upper Bound  \
# 0                   902               1850
# 1                  3295               5987
# 2                  1114               1822
# 3                   566               1050
# 4                  1641               2493
# ...                 ...                ...
# 3002                416                872
# 3003                 83                201
# 3004                193                479
# 3005                 94                226
# 3006                 70                170
#
#      Poverty Percent, Age 5-17 in Families 90% CI Lower Bound  \
# 0                                     14.4                9.4
# 1                                     13.3                9.4
# 2                                     39.5                 30
# 3                                     25.2               17.7
# 4                                     21.4                 17
# ...                                    ...                ...
# 3002                                   8.2                5.3
# 3003                                   4.7                2.7
# 3004                                   7.8                4.5
# 3005                                  12.3                7.2
# 3006                                  11.8                6.9
#
#      90% CI Upper Bound Median Household Income 90% CI Lower Bound  \
# 0                  19.4                   58233              52517
# 1                  17.2                   59871              54593
# 2                    49                   35972              31822
# 3                  32.7                   47918              42291
# 4                  25.8                   52902              46777
# ...                 ...                     ...                ...
# 3002               11.1                   80639              73437
# 3003                6.7                   98837              86531
# 3004               11.1                   70756              63191
# 3005               17.4                   55122              50050
# 3006               16.7                   59410              52275
#
#      90% CI Upper Bound
# 0                 63949
# 1                 65149
# 2                 40122
# 3                 53545
# 4                 59027
# ...                 ...
# 3002              87841
# 3003             111143
# 3004              78321
# 3005              60194
# 3006              66545
#
# [3007 rows x 25 columns]

# %% [markdown]
# * Remove empty cells and clean up columns
# * Retain only US county information and poverty rates for all ages

# %%
print(pov_rate_2019.isnull().sum())
print(pov_rate_2019.duplicated().sum())
display(pov_rate_2019.info())
# Out:
# State FIPS Code                           0
# County FIPS Code                          0
# Postal Code                               0
# Name                                      0
# Poverty Estimate, All Ages                0
# 90% CI Lower Bound                        0
# 90% CI Upper Bound                        0
# Poverty Percent, All Ages                 0
# 90% CI Lower Bound                        0
# 90% CI Upper Bound                        0
# Poverty Estimate, Age 0-17                0
# 90% CI Lower Bound                        0
# 90% CI Upper Bound                        0
# Poverty Percent, Age 0-17                 0
# 90% CI Lower Bound                        0
# 90% CI Upper Bound                        0
# Poverty Estimate, Age 5-17 in Families    0
# 90% CI Lower Bound                        0
# 90% CI Upper Bound                        0
# Poverty Percent, Age 5-17 in Families     0
# 90% CI Lower Bound                        0
# 90% CI Upper Bound                        0
# Median Household Income                   0
# 90% CI Lower Bound                        0
# 90% CI Upper Bound                        0
# dtype: int64
# 0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3007 entries, 0 to 3006
# Data columns (total 25 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   State FIPS Code                         3007 non-null   object
#  1   County FIPS Code                        3007 non-null   object
#  2   Postal Code                             3007 non-null   object
#  3   Name                                    3007 non-null   object
#  4   Poverty Estimate, All Ages              3007 non-null   object
#  5   90% CI Lower Bound                      3007 non-null   object
#  6   90% CI Upper Bound                      3007 non-null   object
#  7   Poverty Percent, All Ages               3007 non-null   object
#  8   90% CI Lower Bound                      3007 non-null   object
#  9   90% CI Upper Bound                      3007 non-null   object
#  10  Poverty Estimate, Age 0-17              3007 non-null   object
#  11  90% CI Lower Bound                      3007 non-null   object
#  12  90% CI Upper Bound                      3007 non-null   object
#  13  Poverty Percent, Age 0-17               3007 non-null   object
#  14  90% CI Lower Bound                      3007 non-null   object
#  15  90% CI Upper Bound                      3007 non-null   object
#  16  Poverty Estimate, Age 5-17 in Families  3007 non-null   object
#  17  90% CI Lower Bound                      3007 non-null   object
#  18  90% CI Upper Bound                      3007 non-null   object
#  19  Poverty Percent, Age 5-17 in Families   3007 non-null   object
#  20  90% CI Lower Bound                      3007 non-null   object
#  21  90% CI Upper Bound                      3007 non-null   object
#  22  Median Household Income                 3007 non-null   object
#  23  90% CI Lower Bound                      3007 non-null   object
#  24  90% CI Upper Bound                      3007 non-null   object
# dtypes: object(25)
# memory usage: 587.4+ KB
# None

# %% [markdown]
# * No duplicates or missing values for poverty rates in 2017
# * also convert poverty percent to float

# %%
pov_rate_2019.info()

pov_rate_2019.drop(518, inplace=True)
# pov_rate_2017['Poverty Percent, All Ages'] = pd.to_numeric(pov_rate_2017['Poverty Percent, All Ages'], downcast='float')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3007 entries, 0 to 3006
# Data columns (total 25 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   State FIPS Code                         3007 non-null   object
#  1   County FIPS Code                        3007 non-null   object
#  2   Postal Code                             3007 non-null   object
#  3   Name                                    3007 non-null   object
#  4   Poverty Estimate, All Ages              3007 non-null   object
#  5   90% CI Lower Bound                      3007 non-null   object
#  6   90% CI Upper Bound                      3007 non-null   object
#  7   Poverty Percent, All Ages               3007 non-null   object
#  8   90% CI Lower Bound                      3007 non-null   object
#  9   90% CI Upper Bound                      3007 non-null   object
#  10  Poverty Estimate, Age 0-17              3007 non-null   object
#  11  90% CI Lower Bound                      3007 non-null   object
#  12  90% CI Upper Bound                      3007 non-null   object
#  13  Poverty Percent, Age 0-17               3007 non-null   object
#  14  90% CI Lower Bound                      3007 non-null   object
#  15  90% CI Upper Bound                      3007 non-null   object
#  16  Poverty Estimate, Age 5-17 in Families  3007 non-null   object
#  17  90% CI Lower Bound                      3007 non-null   object
#  18  90% CI Upper Bound                      3007 non-null   object
#  19  Poverty Percent, Age 5-17 in Families   3007 non-null   object
#  20  90% CI Lower Bound                      3007 non-null   object
#  21  90% CI Upper Bound                      3007 non-null   object
#  22  Median Household Income                 3007 non-null   object
#  23  90% CI Lower Bound                      3007 non-null   object
#  24  90% CI Upper Bound                      3007 non-null   object
# dtypes: object(25)
# memory usage: 587.4+ KB

# %%
pov_rate_2019.columns = ['State FIPS Code', 'County FIPS Code', 'Postal Code', 'Name',
       'Poverty Estimate, All Ages', '90% CI LB All Ages',
       '90% CI UB All Ages', 'Poverty Percent, All Ages', '90% CI LB percent',
       '90% CI UB percent', 'Poverty Estimate, Age 0-17',
       '90% CI LB percent 0-17', '90% CI UB 0-17', 'Poverty Percent, Age 0-17',
       '90% CI LB percent 0-17 percent', '90% CI UB 0-17 percent',
       'Poverty Estimate, Age 5-17 in Families', '90% CI LB 5-17 fam',
       '90% CI UB 5-17 fam', 'Poverty Percent, Age 5-17 in Families',
       '90% CI LB 5-17 percent', '90% CI UB percent 5-17 percent', 'Median Household Income',
       '90% CI Lower Bound LB medh inc', '90% CI UB medh inc']

pov_cols = pov_rate_2019.columns[4:]

# %%
for col in pov_cols:
    pov_rate_2019[col] = pd.to_numeric(pov_rate_2019[col], downcast='float')

pov_rate_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3006 entries, 0 to 3006
# Data columns (total 25 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   State FIPS Code                         3006 non-null   object
#  1   County FIPS Code                        3006 non-null   object
#  2   Postal Code                             3006 non-null   object
#  3   Name                                    3006 non-null   object
#  4   Poverty Estimate, All Ages              3006 non-null   float32
#  5   90% CI LB All Ages                      3006 non-null   float32
#  6   90% CI UB All Ages                      3006 non-null   float32
#  7   Poverty Percent, All Ages               3006 non-null   float32
#  8   90% CI LB percent                       3006 non-null   float32
#  9   90% CI UB percent                       3006 non-null   float32
#  10  Poverty Estimate, Age 0-17              3006 non-null   float32
#  11  90% CI LB percent 0-17                  3006 non-null   float32
#  12  90% CI UB 0-17                          3006 non-null   float32
#  13  Poverty Percent, Age 0-17               3006 non-null   float32
#  14  90% CI LB percent 0-17 percent          3006 non-null   float32
#  15  90% CI UB 0-17 percent                  3006 non-null   float32
#  16  Poverty Estimate, Age 5-17 in Families  3006 non-null   float32
#  17  90% CI LB 5-17 fam                      3006 non-null   float32
#  18  90% CI UB 5-17 fam                      3006 non-null   float32
#  19  Poverty Percent, Age 5-17 in Families   3006 non-null   float32
#  20  90% CI LB 5-17 percent                  3006 non-null   float32
#  21  90% CI UB percent 5-17 percent          3006 non-null   float32
#  22  Median Household Income                 3006 non-null   float32
#  23  90% CI Lower Bound LB medh inc          3006 non-null   float32
#  24  90% CI UB medh inc                      3006 non-null   float32
# dtypes: float32(21), object(4)
# memory usage: 364.0+ KB

# %% [markdown]
# # Clean education and vehicle 2017 dataset

# %%
educ_vehicle_2017.shape
educ_vehicle_2017.columns

educ_vehicle_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 837 entries, 0 to 836
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        837 non-null    int64
#  1   NAME              837 non-null    object
#  2   state             837 non-null    int64
#  3   county            837 non-null    int64
#  4   POP               837 non-null    int64
#  5   EDU_TOT           826 non-null    float64
#  6   LESS_HS_TOT       826 non-null    float64
#  7   HS_TOT            826 non-null    float64
#  8   COL_OR_ASSOC_TOT  826 non-null    float64
#  9   BACH_TOT          826 non-null    float64
#  10  GRAD_TOT          826 non-null    float64
#  11  VEHICLE_TOT       837 non-null    int64
#  12  WALK_TOT          226 non-null    float64
# dtypes: float64(7), int64(5), object(1)
# memory usage: 85.1+ KB

# %% [markdown]
# * Have 837 rows and 12 columns
# * Category types are appropriate for numerical and nominal columns

# %%
# educ_vehicle_2017.drop('Unnamed: 0', axis=1, inplace=True)
educ_vehicle_2017['WALK_TOT'].unique()
educ_vehicle_2017['WALK_TOT'].isnull().sum()

#drop walk b/c too many missing values and only retain counties and drop also drop that row index column
educ_vehicle_2017.state.unique()
cols_to_remove = ['Unnamed: 0', 'WALK_TOT']
educ_vehicle_2017 = remove_col(educ_vehicle_2017, cols_to_remove)

# %% [markdown]
# * drop first column as it is just an index column
# * drop total walk column as majority of data is missing
# * nb there is no fips state code for 4

# %%
edu_vehicle_estimates = educ_vehicle_2017.columns.values[4:]
# educ_vehicle_2017

for est in edu_vehicle_estimates:
    educ_vehicle_2017[est + '_ratio'] = educ_vehicle_2017[est] / educ_vehicle_2017['POP'] * 100
    # educ_vehicle_2017.drop(est, axis=1, inplace=True)

# convert into ratios
display(educ_vehicle_2017)
# Out:
#                               NAME  state  county      POP    EDU_TOT  \
# 0    St. Lawrence County, New York     36      89   109623    72555.0
# 1        Saratoga County, New York     36      91   229869   164414.0
# 2     Schenectady County, New York     36      93   155565   107453.0
# 3         Steuben County, New York     36     101    96281    68011.0
# 4         Suffolk County, New York     36     103  1492953  1036946.0
# ..                             ...    ...     ...      ...        ...
# 832        Putnam County, New York     36      79    99323    71447.0
# 833        Queens County, New York     36      81  2358582  1695302.0
# 834    Rensselaer County, New York     36      83   159722   111047.0
# 835      Richmond County, New York     36      85   479458   334079.0
# 836      Rockland County, New York     36      87   328868   205985.0
#
#      LESS_HS_TOT    HS_TOT  COL_OR_ASSOC_TOT  BACH_TOT  GRAD_TOT  VEHICLE_TOT  \
# 0         9164.0   25858.0           20091.0    8279.0    9163.0        35920
# 1        10656.0   39033.0           45561.0   37886.0   31278.0       105705
# 2        10085.0   32144.0           35263.0   17210.0   12751.0        60290
# 3         6510.0   25920.0           20685.0    7451.0    7445.0        35585
# 4       102621.0  277080.0          279213.0  208064.0  169968.0       617715
# ..           ...       ...               ...       ...       ...          ...
# 832       5090.0   20597.0           18095.0   14929.0   12736.0        42395
# 833     304984.0  493794.0          372885.0  335990.0  187649.0       391980
# 834       9095.0   31730.0           34954.0   20143.0   15125.0        65720
# 835      39031.0  100730.0           83679.0   66108.0   44531.0       127985
# 836      22972.0   46985.0           51510.0   46786.0   37732.0       112645
#
#      EDU_TOT_ratio  LESS_HS_TOT_ratio  HS_TOT_ratio  COL_OR_ASSOC_TOT_ratio  \
# 0        66.185928           8.359560     23.588116               18.327358
# 1        71.525086           4.635684     16.980541               19.820419
# 2        69.072735           6.482821     20.662745               22.667695
# 3        70.638028           6.761459     26.921199               21.483990
# 4        69.456038           6.873693     18.559191               18.702062
# ..             ...                ...           ...                     ...
# 832      71.933993           5.124694     20.737392               18.218338
# 833      71.878018          12.930820     20.936054               15.809711
# 834      69.525175           5.694269     19.865767               21.884274
# 835      69.678470           8.140650     21.009139               17.452832
# 836      62.634552           6.985173     14.286887               15.662819
#
#      BACH_TOT_ratio  GRAD_TOT_ratio  VEHICLE_TOT_ratio
# 0          7.552247        8.358647          32.766846
# 1         16.481561       13.606880          45.984887
# 2         11.062900        8.196574          38.755504
# 3          7.738806        7.732574          36.959525
# 4         13.936407       11.384685          41.375382
# ..              ...             ...                ...
# 832       15.030758       12.822810          42.683970
# 833       14.245424        7.956009          16.619308
# 834       12.611287        9.469578          41.146492
# 835       13.788069        9.287779          26.693683
# 836       14.226377       11.473296          34.252344
#
# [837 rows x 18 columns]

# %% [markdown]
# * convert all estimates of education and vehicles of a county to a ratio of estimated total / population of county
# * retrieve ratio estimate to county population

# %% [markdown]
# # Repeat Steps for education and vehicle 2018 data

# %%
educ_vehicle_2018.shape
educ_vehicle_2018.columns

educ_vehicle_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 838 entries, 0 to 837
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        838 non-null    int64
#  1   NAME              838 non-null    object
#  2   state             838 non-null    int64
#  3   county            838 non-null    int64
#  4   POP               838 non-null    int64
#  5   EDU_TOT           826 non-null    float64
#  6   LESS_HS_TOT       826 non-null    float64
#  7   HS_TOT            826 non-null    float64
#  8   COL_OR_ASSOC_TOT  826 non-null    float64
#  9   BACH_TOT          826 non-null    float64
#  10  GRAD_TOT          826 non-null    float64
#  11  VEHICLE_TOT       838 non-null    int64
#  12  WALK_TOT          231 non-null    float64
# dtypes: float64(7), int64(5), object(1)
# memory usage: 85.2+ KB

# %% [markdown]
# * Have 837 rows and 12 columns
# * Category types are appropriate for numerical and nominal columns

# %%
educ_vehicle_2018['WALK_TOT'].unique()
educ_vehicle_2018['WALK_TOT'].isnull().sum()

educ_vehicle_2018.state.unique()
cols_to_remove = ['Unnamed: 0', 'WALK_TOT']
educ_vehicle_2018 = remove_col(educ_vehicle_2018, cols_to_remove)

# %% [markdown]
# * drop first column as it is just an index column
# * drop total walk column as majority of data is missing
# * nb there is no fips state code for 4

# %%
educ_vehicle_2018.NAME.duplicated().sum()
educ_vehicle_2018.isnull().sum()
educ_vehicle_2018.loc[educ_vehicle_2018.isnull().any(axis=1)]
# Out:
#                                      NAME  state  county     POP  EDU_TOT  \
# 376             Jones County, Mississippi     28      67   68461      NaN
# 827        Arecibo Municipio, Puerto Rico     72      13   82114      NaN
# 828        Bayamón Municipio, Puerto Rico     72      21  170480      NaN
# 829         Caguas Municipio, Puerto Rico     72      25  124434      NaN
# 830       Carolina Municipio, Puerto Rico     72      31  147661      NaN
# 831       Guaynabo Municipio, Puerto Rico     72      61   83787      NaN
# 832       Mayagüez Municipio, Puerto Rico     72      97   71986      NaN
# 833          Ponce Municipio, Puerto Rico     72     113  133191      NaN
# 834       San Juan Municipio, Puerto Rico     72     127  320967      NaN
# 835       Toa Alta Municipio, Puerto Rico     72     135   71094      NaN
# 836       Toa Baja Municipio, Puerto Rico     72     137   74623      NaN
# 837  Trujillo Alto Municipio, Puerto Rico     72     139   63746      NaN
#
#      LESS_HS_TOT  HS_TOT  COL_OR_ASSOC_TOT  BACH_TOT  GRAD_TOT  VEHICLE_TOT
# 376          NaN     NaN               NaN       NaN       NaN        26755
# 827          NaN     NaN               NaN       NaN       NaN        21210
# 828          NaN     NaN               NaN       NaN       NaN        48105
# 829          NaN     NaN               NaN       NaN       NaN        37810
# 830          NaN     NaN               NaN       NaN       NaN        47205
# 831          NaN     NaN               NaN       NaN       NaN        27890
# 832          NaN     NaN               NaN       NaN       NaN        14200
# 833          NaN     NaN               NaN       NaN       NaN        32475
# 834          NaN     NaN               NaN       NaN       NaN        94245
# 835          NaN     NaN               NaN       NaN       NaN        24755
# 836          NaN     NaN               NaN       NaN       NaN        23700
# 837          NaN     NaN               NaN       NaN       NaN        22530

# %% [markdown]
# * All Missing values are Puerto Rico counties similar to previous data sets
# * Census Bureau keeps Puerto Rico as separate data column for education
# * No duplicated data shown

# %%
edu_vehicle_estimates = educ_vehicle_2018.columns.values[4:]
# educ_vehicle_2017

for est in edu_vehicle_estimates:
    educ_vehicle_2018[est + '_ratio'] = educ_vehicle_2018[est] / educ_vehicle_2018['POP'] * 100

# convert into ratios
display(educ_vehicle_2018)
# Out:
#                                      NAME  state  county     POP   EDU_TOT  \
# 0                 Baldwin County, Alabama      1       3  218022  155691.0
# 1                 Calhoun County, Alabama      1      15  114277   79172.0
# 2                 Cullman County, Alabama      1      43   83442   58319.0
# 3                  DeKalb County, Alabama      1      49   71385   48169.0
# 4                  Elmore County, Alabama      1      51   81887   56793.0
# ..                                    ...    ...     ...     ...       ...
# 833          Ponce Municipio, Puerto Rico     72     113  133191       NaN
# 834       San Juan Municipio, Puerto Rico     72     127  320967       NaN
# 835       Toa Alta Municipio, Puerto Rico     72     135   71094       NaN
# 836       Toa Baja Municipio, Puerto Rico     72     137   74623       NaN
# 837  Trujillo Alto Municipio, Puerto Rico     72     139   63746       NaN
#
#      LESS_HS_TOT   HS_TOT  COL_OR_ASSOC_TOT  BACH_TOT  GRAD_TOT  VEHICLE_TOT  \
# 0        15282.0  44013.0           47573.0   32210.0   16613.0        87745
# 1        12121.0  25761.0           27039.0    7914.0    6337.0        42760
# 2        10228.0  18149.0           22883.0    4916.0    2143.0        33065
# 3        11681.0  14333.0           14995.0    3931.0    3229.0        26150
# 4         7490.0  18457.0           16505.0   10146.0    4195.0        31600
# ..           ...      ...               ...       ...       ...          ...
# 833          NaN      NaN               NaN       NaN       NaN        32475
# 834          NaN      NaN               NaN       NaN       NaN        94245
# 835          NaN      NaN               NaN       NaN       NaN        24755
# 836          NaN      NaN               NaN       NaN       NaN        23700
# 837          NaN      NaN               NaN       NaN       NaN        22530
#
#      EDU_TOT_ratio  LESS_HS_TOT_ratio  HS_TOT_ratio  COL_OR_ASSOC_TOT_ratio  \
# 0        71.410683           7.009384     20.187412               21.820275
# 1        69.280783          10.606684     22.542594               23.660929
# 2        69.891661          12.257616     21.750437               27.423839
# 3        67.477761          16.363382     20.078448               21.005814
# 4        69.355331           9.146751     22.539597               20.155824
# ..             ...                ...           ...                     ...
# 833            NaN                NaN           NaN                     NaN
# 834            NaN                NaN           NaN                     NaN
# 835            NaN                NaN           NaN                     NaN
# 836            NaN                NaN           NaN                     NaN
# 837            NaN                NaN           NaN                     NaN
#
#      BACH_TOT_ratio  GRAD_TOT_ratio  VEHICLE_TOT_ratio
# 0         14.773738        7.619873          40.245938
# 1          6.925278        5.545298          37.417853
# 2          5.891517        2.568251          39.626327
# 3          5.506759        4.523359          36.632346
# 4         12.390245        5.122913          38.589764
# ..              ...             ...                ...
# 833             NaN             NaN          24.382278
# 834             NaN             NaN          29.362832
# 835             NaN             NaN          34.820097
# 836             NaN             NaN          31.759645
# 837             NaN             NaN          35.343394
#
# [838 rows x 18 columns]

# %% [markdown]
# * convert all estimates of education and vehicles of a county to a ratio of estimated total / population of county
# * retrieve ratio estimate to county population

# %% [markdown]
# # Repeat Steps for education and vehicle 2019 data

# %%
educ_vehicle_2019.shape
educ_vehicle_2019.columns

educ_vehicle_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 840 entries, 0 to 839
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        840 non-null    int64
#  1   NAME              840 non-null    object
#  2   state             840 non-null    int64
#  3   county            840 non-null    int64
#  4   POP               840 non-null    int64
#  5   EDU_TOT           827 non-null    float64
#  6   LESS_HS_TOT       827 non-null    float64
#  7   HS_TOT            827 non-null    float64
#  8   COL_OR_ASSOC_TOT  827 non-null    float64
#  9   BACH_TOT          827 non-null    float64
#  10  GRAD_TOT          827 non-null    float64
#  11  VEHICLE_TOT       840 non-null    int64
#  12  WALK_TOT          226 non-null    float64
# dtypes: float64(7), int64(5), object(1)
# memory usage: 85.4+ KB

# %% [markdown]
# * Have 837 rows and 12 columns
# * Category types are appropriate for numerical and nominal columns

# %%
educ_vehicle_2019['WALK_TOT'].unique()
educ_vehicle_2019['WALK_TOT'].isnull().sum()

educ_vehicle_2019.state.unique()
cols_to_remove = ['Unnamed: 0', 'WALK_TOT']
educ_vehicle_2019 = remove_col(educ_vehicle_2019, cols_to_remove)

# %% [markdown]
# * drop first column as it is just an index column
# * drop total walk column as majority of data is missing
# * nb there is no fips state code for 4

# %%
educ_vehicle_2019.NAME.duplicated().sum()
educ_vehicle_2019.isnull().sum()
educ_vehicle_2019.loc[educ_vehicle_2019.isnull().any(axis=1)]
# Out:
#                                      NAME  state  county     POP  EDU_TOT  \
# 291          St. Landry Parish, Louisiana     22      97   82124      NaN
# 559                Muskingum County, Ohio     39     119   86215      NaN
# 829        Arecibo Municipio, Puerto Rico     72      13   81966      NaN
# 830        Bayamón Municipio, Puerto Rico     72      21  169269      NaN
# 831         Caguas Municipio, Puerto Rico     72      25  124606      NaN
# 832       Carolina Municipio, Puerto Rico     72      31  146984      NaN
# 833       Guaynabo Municipio, Puerto Rico     72      61   83728      NaN
# 834       Mayagüez Municipio, Puerto Rico     72      97   71530      NaN
# 835          Ponce Municipio, Puerto Rico     72     113  131881      NaN
# 836       San Juan Municipio, Puerto Rico     72     127  318441      NaN
# 837       Toa Alta Municipio, Puerto Rico     72     135   72025      NaN
# 838       Toa Baja Municipio, Puerto Rico     72     137   74271      NaN
# 839  Trujillo Alto Municipio, Puerto Rico     72     139   63674      NaN
#
#      LESS_HS_TOT  HS_TOT  COL_OR_ASSOC_TOT  BACH_TOT  GRAD_TOT  VEHICLE_TOT
# 291          NaN     NaN               NaN       NaN       NaN        27175
# 559          NaN     NaN               NaN       NaN       NaN        33710
# 829          NaN     NaN               NaN       NaN       NaN        20780
# 830          NaN     NaN               NaN       NaN       NaN        53730
# 831          NaN     NaN               NaN       NaN       NaN        39305
# 832          NaN     NaN               NaN       NaN       NaN        48385
# 833          NaN     NaN               NaN       NaN       NaN        30465
# 834          NaN     NaN               NaN       NaN       NaN        16695
# 835          NaN     NaN               NaN       NaN       NaN        31635
# 836          NaN     NaN               NaN       NaN       NaN        92055
# 837          NaN     NaN               NaN       NaN       NaN        24230
# 838          NaN     NaN               NaN       NaN       NaN        22900
# 839          NaN     NaN               NaN       NaN       NaN        25900

# %% [markdown]
# * All Missing values are Puerto Rico counties similar to previous data sets
# * Census Bureau keeps Puerto Rico as separate data column for education
# * No duplicated data shown

# %%
edu_vehicle_estimates = educ_vehicle_2019.columns.values[4:]
# educ_vehicle_2017

for est in edu_vehicle_estimates:
    educ_vehicle_2019[est + '_ratio'] = educ_vehicle_2019[est] / educ_vehicle_2019['POP'] * 100

# convert into ratios
display(educ_vehicle_2019)
# Out:
#                                      NAME  state  county     POP   EDU_TOT  \
# 0                 Baldwin County, Alabama      1       3  223234  159717.0
# 1                 Calhoun County, Alabama      1      15  113605   79084.0
# 2                 Cullman County, Alabama      1      43   83768   58795.0
# 3                  DeKalb County, Alabama      1      49   71513   47007.0
# 4                  Elmore County, Alabama      1      51   81209   57553.0
# ..                                    ...    ...     ...     ...       ...
# 835          Ponce Municipio, Puerto Rico     72     113  131881       NaN
# 836       San Juan Municipio, Puerto Rico     72     127  318441       NaN
# 837       Toa Alta Municipio, Puerto Rico     72     135   72025       NaN
# 838       Toa Baja Municipio, Puerto Rico     72     137   74271       NaN
# 839  Trujillo Alto Municipio, Puerto Rico     72     139   63674       NaN
#
#      LESS_HS_TOT   HS_TOT  COL_OR_ASSOC_TOT  BACH_TOT  GRAD_TOT  VEHICLE_TOT  \
# 0        15158.0  41884.0           51204.0   32781.0   18690.0        85170
# 1        12195.0  27277.0           24355.0    9082.0    6175.0        41330
# 2        11014.0  17924.0           20616.0    5935.0    3306.0        31840
# 3        10043.0  17881.0           13084.0    3693.0    2306.0        28065
# 4         5940.0  19992.0           17311.0    9418.0    4892.0        33005
# ..           ...      ...               ...       ...       ...          ...
# 835          NaN      NaN               NaN       NaN       NaN        31635
# 836          NaN      NaN               NaN       NaN       NaN        92055
# 837          NaN      NaN               NaN       NaN       NaN        24230
# 838          NaN      NaN               NaN       NaN       NaN        22900
# 839          NaN      NaN               NaN       NaN       NaN        25900
#
#      EDU_TOT_ratio  LESS_HS_TOT_ratio  HS_TOT_ratio  COL_OR_ASSOC_TOT_ratio  \
# 0        71.546897           6.790184     18.762375               22.937366
# 1        69.613133          10.734563     24.010387               21.438317
# 2        70.187900          13.148219     21.397192               24.610830
# 3        65.732105          14.043600     25.003845               18.295974
# 4        70.870224           7.314460     24.617961               21.316603
# ..             ...                ...           ...                     ...
# 835            NaN                NaN           NaN                     NaN
# 836            NaN                NaN           NaN                     NaN
# 837            NaN                NaN           NaN                     NaN
# 838            NaN                NaN           NaN                     NaN
# 839            NaN                NaN           NaN                     NaN
#
#      BACH_TOT_ratio  GRAD_TOT_ratio  VEHICLE_TOT_ratio
# 0         14.684591        8.372381          38.152790
# 1          7.994366        5.435500          36.380441
# 2          7.085044        3.946614          38.009741
# 3          5.164096        3.224589          39.244613
# 4         11.597237        6.023963          40.642047
# ..              ...             ...                ...
# 835             NaN             NaN          23.987534
# 836             NaN             NaN          28.908024
# 837             NaN             NaN          33.641097
# 838             NaN             NaN          30.833030
# 839             NaN             NaN          40.675943
#
# [840 rows x 18 columns]

# %% [markdown]
# * convert all estimates of education and vehicles of a county to a ratio of estimated total / population of county
# * retrieve ratio estimate to county population

# %% [markdown]
# ## merge education and vehicle rates for 2017-2019 into one dataframe

# %%
educ_vehicle_ratios = educ_vehicle_2017.columns[3:]
educ_vehicle_ratios
for ratio in educ_vehicle_ratios:
    educ_vehicle_2017.rename(columns={ratio:ratio + '_2017'}, inplace=True)
    educ_vehicle_2018.rename(columns={ratio:ratio + '_2018'}, inplace=True)
    educ_vehicle_2019.rename(columns={ratio:ratio + '_2019'}, inplace=True)

# educ_vehicle_2017.drop('POP', axis=1, inplace=True)
# educ_vehicle_2018.drop('POP', axis=1, inplace=True)
# educ_vehicle_2019.drop('POP', axis=1, inplace=True)

# %%
educ_vehicle_2017_2018 = pd.merge(educ_vehicle_2017, educ_vehicle_2018, how='inner')
educ_vehicle_2017_2019 = pd.merge(educ_vehicle_2017_2018, educ_vehicle_2019, how='inner')
educ_vehicle_2017_2019
# Out:
#                               NAME  state  county  POP_2017  EDU_TOT_2017  \
# 0    St. Lawrence County, New York     36      89    109623       72555.0
# 1        Saratoga County, New York     36      91    229869      164414.0
# 2     Schenectady County, New York     36      93    155565      107453.0
# 3         Steuben County, New York     36     101     96281       68011.0
# 4         Suffolk County, New York     36     103   1492953     1036946.0
# ..                             ...    ...     ...       ...           ...
# 831        Putnam County, New York     36      79     99323       71447.0
# 832        Queens County, New York     36      81   2358582     1695302.0
# 833    Rensselaer County, New York     36      83    159722      111047.0
# 834      Richmond County, New York     36      85    479458      334079.0
# 835      Rockland County, New York     36      87    328868      205985.0
#
#      LESS_HS_TOT_2017  HS_TOT_2017  COL_OR_ASSOC_TOT_2017  BACH_TOT_2017  \
# 0              9164.0      25858.0                20091.0         8279.0
# 1             10656.0      39033.0                45561.0        37886.0
# 2             10085.0      32144.0                35263.0        17210.0
# 3              6510.0      25920.0                20685.0         7451.0
# 4            102621.0     277080.0               279213.0       208064.0
# ..                ...          ...                    ...            ...
# 831            5090.0      20597.0                18095.0        14929.0
# 832          304984.0     493794.0               372885.0       335990.0
# 833            9095.0      31730.0                34954.0        20143.0
# 834           39031.0     100730.0                83679.0        66108.0
# 835           22972.0      46985.0                51510.0        46786.0
#
#      GRAD_TOT_2017  ...  BACH_TOT_2019  GRAD_TOT_2019  VEHICLE_TOT_2019  \
# 0           9163.0  ...         8684.0         7733.0             33650
# 1          31278.0  ...        40148.0        30363.0            104085
# 2          12751.0  ...        22627.0        15566.0             59970
# 3           7445.0  ...         8066.0         8475.0             35505
# 4         169968.0  ...       214035.0       182346.0            629360
# ..             ...  ...            ...            ...               ...
# 831        12736.0  ...        15240.0        12261.0             42420
# 832       187649.0  ...       334272.0       207624.0            387870
# 833        15125.0  ...        20896.0        18203.0             65615
# 834        44531.0  ...        71914.0        48875.0            128740
# 835        37732.0  ...        46487.0        39510.0            111705
#
#      EDU_TOT_ratio_2019  LESS_HS_TOT_ratio_2019  HS_TOT_ratio_2019  \
# 0             67.044737                8.564136          23.762762
# 1             72.095118                4.492676          17.754924
# 2             70.183324                5.047682          20.198456
# 3             71.044989                6.093585          25.791841
# 4             70.148605                6.397598          18.389192
# ..                  ...                     ...                ...
# 831           73.443857                5.721115          19.355167
# 832           72.484558               12.328372          19.812340
# 833           70.327759                5.902441          19.919478
# 834           70.041143                7.701258          20.426427
# 835           62.486456                6.950511          13.296029
#
#      COL_OR_ASSOC_TOT_ratio_2019  BACH_TOT_ratio_2019  GRAD_TOT_ratio_2019  \
# 0                      19.480230             8.060145             7.177464
# 1                      19.172290            17.466056            13.209172
# 2                      20.343982            14.569959            10.023245
# 3                      21.817171             8.456788             8.885604
# 4                      18.517663            14.495114            12.349037
# ..                           ...                  ...                  ...
# 831                    20.396664            15.500407            12.470504
# 832                    16.300805            14.831103             9.211938
# 833                    19.870963            13.165820            11.469058
# 834                    16.545240            15.103446            10.264773
# 835                    15.843383            14.269051            12.127481
#
#      VEHICLE_TOT_ratio_2019
# 0                 31.232597
# 1                 45.281320
# 2                 38.615831
# 3                 37.225175
# 4                 42.622211
# ..                      ...
# 831               43.144833
# 832               17.209159
# 833               41.341659
# 834               27.038096
# 835               34.287530
#
# [836 rows x 48 columns]

# %%
educ_vehicle_2017_2019 = get_df_with_geofips(educ_vehicle_2017_2019, 'state', 'county')
educ_vehicle_2017_2019
# Out:
#     GeoFIPS                           NAME  state  county  POP_2017  \
# 0     36089  St. Lawrence County, New York     36      89    109623
# 1     36091      Saratoga County, New York     36      91    229869
# 2     36093   Schenectady County, New York     36      93    155565
# 3     36101       Steuben County, New York     36     101     96281
# 4     36103       Suffolk County, New York     36     103   1492953
# ..      ...                            ...    ...     ...       ...
# 831   36079        Putnam County, New York     36      79     99323
# 832   36081        Queens County, New York     36      81   2358582
# 833   36083    Rensselaer County, New York     36      83    159722
# 834   36085      Richmond County, New York     36      85    479458
# 835   36087      Rockland County, New York     36      87    328868
#
#      EDU_TOT_2017  LESS_HS_TOT_2017  HS_TOT_2017  COL_OR_ASSOC_TOT_2017  \
# 0         72555.0            9164.0      25858.0                20091.0
# 1        164414.0           10656.0      39033.0                45561.0
# 2        107453.0           10085.0      32144.0                35263.0
# 3         68011.0            6510.0      25920.0                20685.0
# 4       1036946.0          102621.0     277080.0               279213.0
# ..            ...               ...          ...                    ...
# 831       71447.0            5090.0      20597.0                18095.0
# 832     1695302.0          304984.0     493794.0               372885.0
# 833      111047.0            9095.0      31730.0                34954.0
# 834      334079.0           39031.0     100730.0                83679.0
# 835      205985.0           22972.0      46985.0                51510.0
#
#      BACH_TOT_2017  ...  BACH_TOT_2019  GRAD_TOT_2019  VEHICLE_TOT_2019  \
# 0           8279.0  ...         8684.0         7733.0             33650
# 1          37886.0  ...        40148.0        30363.0            104085
# 2          17210.0  ...        22627.0        15566.0             59970
# 3           7451.0  ...         8066.0         8475.0             35505
# 4         208064.0  ...       214035.0       182346.0            629360
# ..             ...  ...            ...            ...               ...
# 831        14929.0  ...        15240.0        12261.0             42420
# 832       335990.0  ...       334272.0       207624.0            387870
# 833        20143.0  ...        20896.0        18203.0             65615
# 834        66108.0  ...        71914.0        48875.0            128740
# 835        46786.0  ...        46487.0        39510.0            111705
#
#      EDU_TOT_ratio_2019  LESS_HS_TOT_ratio_2019  HS_TOT_ratio_2019  \
# 0             67.044737                8.564136          23.762762
# 1             72.095118                4.492676          17.754924
# 2             70.183324                5.047682          20.198456
# 3             71.044989                6.093585          25.791841
# 4             70.148605                6.397598          18.389192
# ..                  ...                     ...                ...
# 831           73.443857                5.721115          19.355167
# 832           72.484558               12.328372          19.812340
# 833           70.327759                5.902441          19.919478
# 834           70.041143                7.701258          20.426427
# 835           62.486456                6.950511          13.296029
#
#      COL_OR_ASSOC_TOT_ratio_2019  BACH_TOT_ratio_2019  GRAD_TOT_ratio_2019  \
# 0                      19.480230             8.060145             7.177464
# 1                      19.172290            17.466056            13.209172
# 2                      20.343982            14.569959            10.023245
# 3                      21.817171             8.456788             8.885604
# 4                      18.517663            14.495114            12.349037
# ..                           ...                  ...                  ...
# 831                    20.396664            15.500407            12.470504
# 832                    16.300805            14.831103             9.211938
# 833                    19.870963            13.165820            11.469058
# 834                    16.545240            15.103446            10.264773
# 835                    15.843383            14.269051            12.127481
#
#      VEHICLE_TOT_ratio_2019
# 0                 31.232597
# 1                 45.281320
# 2                 38.615831
# 3                 37.225175
# 4                 42.622211
# ..                      ...
# 831               43.144833
# 832               17.209159
# 833               41.341659
# 834               27.038096
# 835               34.287530
#
# [836 rows x 49 columns]

# %% [markdown]
# # clean AQI and County demographic data

# %%
# add GeoFIPS for NE_aqi_2019

aqi_2017 = get_df_with_geofips(daily_aqi_by_county_2017, 'State Code', 'County Code')
aqi_2018 = get_df_with_geofips(daily_aqi_by_county_2018, 'State Code', 'County Code')
aqi_2019 = get_df_with_geofips(daily_aqi_by_county_2019, 'State Code', 'County Code')

# %%
## clean AQI data
cols_to_remove = ['Defining Site', 'Number of Sites Reporting', 'State Code', 'County Code']


aqi_2017 = remove_col(aqi_2017, cols_to_remove)
aqi_2018 = remove_col(aqi_2018, cols_to_remove)
aqi_2019 = remove_col(aqi_2019, cols_to_remove)

# %%
AQI_metrics = aqi_2017.columns[3:]

for metric in AQI_metrics:
    aqi_2017.rename(columns={metric:metric + '_2017'}, inplace=True)
    aqi_2018.rename(columns={metric:metric + '_2018'}, inplace=True)
    aqi_2019.rename(columns={metric:metric + '_2019'}, inplace=True)

# %% [markdown]
# * Give appropriate year name to columns to distinguish them before merging

# %%
print(aqi_2017.columns)
aqi_2017.head()
# Out:
# Index(['GeoFIPS', 'State Name', 'county Name', 'Date_2017', 'AQI_2017',
#        'Category_2017', 'Defining Parameter_2017'],
#       dtype='object')
#   GeoFIPS State Name county Name   Date_2017  AQI_2017 Category_2017  \
# 0   01003    Alabama     Baldwin  2017-01-01        21          Good
# 1   01003    Alabama     Baldwin  2017-01-04        22          Good
# 2   01003    Alabama     Baldwin  2017-01-10        19          Good
# 3   01003    Alabama     Baldwin  2017-01-13        30          Good
# 4   01003    Alabama     Baldwin  2017-01-16        16          Good
#
#   Defining Parameter_2017
# 0                   PM2.5
# 1                   PM2.5
# 2                   PM2.5
# 3                   PM2.5
# 4                   PM2.5

# %%
print(aqi_2017.columns)
average_aqi_2017 = aqi_2017.groupby(['GeoFIPS', 'State Name', 'county Name'], as_index=False)[['AQI_2017']].mean()
average_aqi_2018 = aqi_2018.groupby(['GeoFIPS', 'State Name', 'county Name'], as_index=False)[['AQI_2018']].mean()
average_aqi_2019 = aqi_2019.groupby(['GeoFIPS', 'State Name', 'county Name'], as_index=False)[['AQI_2019']].mean()

display(average_aqi_2017)
display(average_aqi_2018)
display(average_aqi_2019)
# Out:
# Index(['GeoFIPS', 'State Name', 'county Name', 'Date_2017', 'AQI_2017',
#        'Category_2017', 'Defining Parameter_2017'],
#       dtype='object')
#      GeoFIPS         State Name            county Name   AQI_2017
# 0      01003            Alabama                Baldwin  37.503704
# 1      01027            Alabama                   Clay  32.457627
# 2      01033            Alabama                Colbert  36.155477
# 3      01049            Alabama                 DeKalb  38.239554
# 4      01051            Alabama                 Elmore  34.371681
# ...      ...                ...                    ...        ...
# 1057   72127        Puerto Rico               San Juan   9.357724
# 1058   78010     Virgin Islands               St Croix  24.346154
# 1059   78020     Virgin Islands                St John  26.223881
# 1060   80002  Country Of Mexico  BAJA CALIFORNIA NORTE  74.343490
# 1061   80026  Country Of Mexico                 SONORA  41.282297
#
# [1062 rows x 4 columns]
#      GeoFIPS         State Name            county Name   AQI_2018
# 0      01003            Alabama                Baldwin  36.829630
# 1      01027            Alabama                   Clay  28.990909
# 2      01033            Alabama                Colbert  35.635379
# 3      01049            Alabama                 DeKalb  36.720000
# 4      01051            Alabama                 Elmore  35.328829
# ...      ...                ...                    ...        ...
# 1051   78010     Virgin Islands               St Croix  29.090909
# 1052   78020     Virgin Islands                St John  21.000000
# 1053   78030     Virgin Islands              St Thomas  33.207650
# 1054   80002  Country Of Mexico  BAJA CALIFORNIA NORTE  85.000000
# 1055   80026  Country Of Mexico                 SONORA  40.477901
#
# [1056 rows x 4 columns]
#      GeoFIPS         State Name            county Name   AQI_2019
# 0      01003            Alabama                Baldwin  38.291513
# 1      01027            Alabama                   Clay  31.149533
# 2      01033            Alabama                Colbert  35.520913
# 3      01049            Alabama                 DeKalb  39.711911
# 4      01051            Alabama                 Elmore  38.421053
# ...      ...                ...                    ...        ...
# 1048   78010     Virgin Islands               St Croix  24.877193
# 1049   78020     Virgin Islands                St John  21.752475
# 1050   78030     Virgin Islands              St Thomas  32.738806
# 1051   80002  Country Of Mexico  BAJA CALIFORNIA NORTE  77.125000
# 1052   80026  Country Of Mexico                 SONORA  44.416201
#
# [1053 rows x 4 columns]

# %% [markdown]
# ## clean demographic data

# %%
county_demographic = county_demographic.loc[county_demographic.YEAR > 9]
# keep only totals of dem; disregard ages
county_demographic = county_demographic.loc[county_demographic.AGEGRP == 0]
county_demographic
# Out:
#         SUMLEV  STATE  COUNTY   STNAME          CTYNAME  YEAR  AGEGRP  \
# 171         50      1       1  Alabama   Autauga County    10       0
# 190         50      1       1  Alabama   Autauga County    11       0
# 209         50      1       1  Alabama   Autauga County    12       0
# 399         50      1       3  Alabama   Baldwin County    10       0
# 418         50      1       3  Alabama   Baldwin County    11       0
# ...        ...    ...     ...      ...              ...   ...     ...
# 716110      50     56      43  Wyoming  Washakie County    11       0
# 716129      50     56      43  Wyoming  Washakie County    12       0
# 716319      50     56      45  Wyoming    Weston County    10       0
# 716338      50     56      45  Wyoming    Weston County    11       0
# 716357      50     56      45  Wyoming    Weston County    12       0
#
#         TOT_POP  TOT_MALE  TOT_FEMALE  ...  HWAC_MALE  HWAC_FEMALE  HBAC_MALE  \
# 171       55390     27010       28380  ...        699          643        111
# 190       55533     27006       28527  ...        764          672         90
# 209       55869     27092       28777  ...        778          687         89
# 399      212521    103218      109303  ...       4767         4252        259
# 418      217855    105702      112153  ...       4970         4473        263
# ...         ...       ...         ...  ...        ...          ...        ...
# 716110     7877      3984        3893  ...        515          489          9
# 716129     7805      3963        3842  ...        512          489          7
# 716319     6968      3660        3308  ...        140          118          6
# 716338     6924      3627        3297  ...        132          112          6
# 716357     6927      3624        3303  ...        132          120          5
#
#         HBAC_FEMALE  HIAC_MALE  HIAC_FEMALE  HAAC_MALE  HAAC_FEMALE  \
# 171              78         39           41         12           15
# 190              75         39           32         20           16
# 209              93         40           27         15           19
# 399             270        240          162         42           56
# 418             263        258          186         62           56
# ...             ...        ...          ...        ...          ...
# 716110            8         56           57          5            8
# 716129            9         54           59          7            8
# 716319            7         23           18          2            6
# 716338            8         24           22          5            1
# 716357            8         23           20          6            4
#
#         HNAC_MALE  HNAC_FEMALE
# 171            17           15
# 190            19           13
# 209            16           11
# 399            44           40
# 418            50           31
# ...           ...          ...
# 716110          5            4
# 716129          4            2
# 716319          2            2
# 716338          1            0
# 716357          2            0
#
# [9426 rows x 80 columns]

# %% [markdown]
# * county_demographic contains all county demographic data for US
# * Only 2017-2019 data is retained
# * All age groups are considered for ethnicities

# %%
demographic = county_demographic.columns.values[8:]
county_dem_ratio = county_demographic

for dem in demographic:
    county_dem_ratio[dem + '_ratio'] = county_demographic[dem] / county_demographic['TOT_POP'] * 100

display(county_dem_ratio)
# Out:
#         SUMLEV  STATE  COUNTY   STNAME          CTYNAME  YEAR  AGEGRP  \
# 171         50      1       1  Alabama   Autauga County    10       0
# 190         50      1       1  Alabama   Autauga County    11       0
# 209         50      1       1  Alabama   Autauga County    12       0
# 399         50      1       3  Alabama   Baldwin County    10       0
# 418         50      1       3  Alabama   Baldwin County    11       0
# ...        ...    ...     ...      ...              ...   ...     ...
# 716110      50     56      43  Wyoming  Washakie County    11       0
# 716129      50     56      43  Wyoming  Washakie County    12       0
# 716319      50     56      45  Wyoming    Weston County    10       0
# 716338      50     56      45  Wyoming    Weston County    11       0
# 716357      50     56      45  Wyoming    Weston County    12       0
#
#         TOT_POP  TOT_MALE  TOT_FEMALE  ...  HWAC_MALE_ratio  \
# 171       55390     27010       28380  ...         1.261961
# 190       55533     27006       28527  ...         1.375759
# 209       55869     27092       28777  ...         1.392543
# 399      212521    103218      109303  ...         2.243072
# 418      217855    105702      112153  ...         2.281334
# ...         ...       ...         ...  ...              ...
# 716110     7877      3984        3893  ...         6.538022
# 716129     7805      3963        3842  ...         6.559898
# 716319     6968      3660        3308  ...         2.009185
# 716338     6924      3627        3297  ...         1.906412
# 716357     6927      3624        3303  ...         1.905587
#
#         HWAC_FEMALE_ratio  HBAC_MALE_ratio  HBAC_FEMALE_ratio  \
# 171              1.160859         0.200397           0.140820
# 190              1.210091         0.162066           0.135055
# 209              1.229662         0.159301           0.166461
# 399              2.000743         0.121870           0.127046
# 418              2.053201         0.120722           0.120722
# ...                   ...              ...                ...
# 716110           6.207947         0.114257           0.101562
# 716129           6.265215         0.089686           0.115311
# 716319           1.693456         0.086108           0.100459
# 716338           1.617562         0.086655           0.115540
# 716357           1.732352         0.072181           0.115490
#
#         HIAC_MALE_ratio  HIAC_FEMALE_ratio  HAAC_MALE_ratio  \
# 171            0.070410           0.074021         0.021665
# 190            0.070229           0.057623         0.036015
# 209            0.071596           0.048327         0.026849
# 399            0.112930           0.076228         0.019763
# 418            0.118427           0.085378         0.028459
# ...                 ...                ...              ...
# 716110         0.710931           0.723626         0.063476
# 716129         0.691864           0.755926         0.089686
# 716319         0.330080           0.258324         0.028703
# 716338         0.346620           0.317735         0.072213
# 716357         0.332034           0.288725         0.086618
#
#         HAAC_FEMALE_ratio  HNAC_MALE_ratio  HNAC_FEMALE_ratio
# 171              0.027081         0.030691           0.027081
# 190              0.028812         0.034214           0.023410
# 209              0.034008         0.028638           0.019689
# 399              0.026350         0.020704           0.018822
# 418              0.025705         0.022951           0.014230
# ...                   ...              ...                ...
# 716110           0.101562         0.063476           0.050781
# 716129           0.102498         0.051249           0.025625
# 716319           0.086108         0.028703           0.028703
# 716338           0.014443         0.014443           0.000000
# 716357           0.057745         0.028873           0.000000
#
# [9426 rows x 152 columns]

# %% [markdown]
# * Columns of demographic ratios are produced
# * Ratios are demographic / county population

# %%
county_dem_ratio = get_df_with_geofips(county_dem_ratio, 'STATE', 'COUNTY')

# %%
cols_to_remove =  ['AGEGRP', 'STATE', 'COUNTY', 'SUMLEV']
county_dem_ratio = remove_col(county_dem_ratio, cols_to_remove)
display(county_dem_ratio)
# Out:
#        GeoFIPS   STNAME          CTYNAME  YEAR  TOT_POP  TOT_MALE  TOT_FEMALE  \
# 171      01001  Alabama   Autauga County    10    55390     27010       28380
# 190      01001  Alabama   Autauga County    11    55533     27006       28527
# 209      01001  Alabama   Autauga County    12    55869     27092       28777
# 399      01003  Alabama   Baldwin County    10   212521    103218      109303
# 418      01003  Alabama   Baldwin County    11   217855    105702      112153
# ...        ...      ...              ...   ...      ...       ...         ...
# 716110   56043  Wyoming  Washakie County    11     7877      3984        3893
# 716129   56043  Wyoming  Washakie County    12     7805      3963        3842
# 716319   56045  Wyoming    Weston County    10     6968      3660        3308
# 716338   56045  Wyoming    Weston County    11     6924      3627        3297
# 716357   56045  Wyoming    Weston County    12     6927      3624        3303
#
#         WA_MALE  WA_FEMALE  BA_MALE  ...  HWAC_MALE_ratio  HWAC_FEMALE_ratio  \
# 171       20876      21705     5139  ...         1.261961           1.160859
# 190       20917      21749     5116  ...         1.375759           1.210091
# 209       20878      21729     5237  ...         1.392543           1.229662
# 399       90360      95215     9279  ...         2.243072           2.000743
# 418       92613      97815     9372  ...         2.281334           2.053201
# ...         ...        ...      ...  ...              ...                ...
# 716110     3781       3670       25  ...         6.538022           6.207947
# 716129     3759       3618       25  ...         6.559898           6.265215
# 716319     3447       3111       29  ...         2.009185           1.693456
# 716338     3401       3073       32  ...         1.906412           1.617562
# 716357     3392       3062       32  ...         1.905587           1.732352
#
#         HBAC_MALE_ratio  HBAC_FEMALE_ratio  HIAC_MALE_ratio  \
# 171            0.200397           0.140820         0.070410
# 190            0.162066           0.135055         0.070229
# 209            0.159301           0.166461         0.071596
# 399            0.121870           0.127046         0.112930
# 418            0.120722           0.120722         0.118427
# ...                 ...                ...              ...
# 716110         0.114257           0.101562         0.710931
# 716129         0.089686           0.115311         0.691864
# 716319         0.086108           0.100459         0.330080
# 716338         0.086655           0.115540         0.346620
# 716357         0.072181           0.115490         0.332034
#
#         HIAC_FEMALE_ratio  HAAC_MALE_ratio  HAAC_FEMALE_ratio  \
# 171              0.074021         0.021665           0.027081
# 190              0.057623         0.036015           0.028812
# 209              0.048327         0.026849           0.034008
# 399              0.076228         0.019763           0.026350
# 418              0.085378         0.028459           0.025705
# ...                   ...              ...                ...
# 716110           0.723626         0.063476           0.101562
# 716129           0.755926         0.089686           0.102498
# 716319           0.258324         0.028703           0.086108
# 716338           0.317735         0.072213           0.014443
# 716357           0.288725         0.086618           0.057745
#
#         HNAC_MALE_ratio  HNAC_FEMALE_ratio
# 171            0.030691           0.027081
# 190            0.034214           0.023410
# 209            0.028638           0.019689
# 399            0.020704           0.018822
# 418            0.022951           0.014230
# ...                 ...                ...
# 716110         0.063476           0.050781
# 716129         0.051249           0.025625
# 716319         0.028703           0.028703
# 716338         0.014443           0.000000
# 716357         0.028873           0.000000
#
# [9426 rows x 149 columns]

# %% [markdown]
# * GeoFIPS column added
# * Redundant column removes and columns with lack of data variety

# %%
county_dem_ratio_17 = county_dem_ratio.loc[county_demographic.YEAR == 10]
county_dem_ratio_18 = county_dem_ratio.loc[county_demographic.YEAR == 11]
county_dem_ratio_19 = county_dem_ratio.loc[county_demographic.YEAR == 12]

county_dem_ratio_17.drop('YEAR', axis=1, inplace=True)
county_dem_ratio_18.drop('YEAR', axis=1, inplace=True)
county_dem_ratio_19.drop('YEAR', axis=1, inplace=True)
# Out:
# /home/wkc/.local/lib/python3.8/site-packages/pandas/core/frame.py:4167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %% [markdown]
# # Merge data

# %% [markdown]
# ## merge poverty rates for 2017-2019 into one dataframe

# %%
pov_cols

for col in pov_cols:
    pov_rate_2017.rename(columns={col:col + '_2017'}, inplace=True)
    pov_rate_2018.rename(columns={col:col + '_2018'}, inplace=True)
    pov_rate_2019.rename(columns={col:col + '_2019'}, inplace=True)

# pov_rate_2017.rename(columns={'Poverty Percent, All Ages':'Poverty Percent, All Ages 2017'}, inplace=True)
# pov_rate_2018.rename(columns={'Poverty Percent, All Ages':'Poverty Percent, All Ages 2018'}, inplace=True)
# pov_rate_2019.rename(columns={'Poverty Percent, All Ages':'Poverty Percent, All Ages 2019'}, inplace=True)
#
pov_rate_2017_2018 = pd.merge(pov_rate_2017, pov_rate_2018, how='inner')
pov_rate_2017_2019 = pd.merge(pov_rate_2017_2018, pov_rate_2019, how='inner')
pov_rate_2017_2019
# Out:
#      State FIPS Code County FIPS Code Postal Code               Name  \
# 0                 01              001          AL     Autauga County
# 1                 01              003          AL     Baldwin County
# 2                 01              005          AL     Barbour County
# 3                 01              007          AL        Bibb County
# 4                 01              009          AL      Blount County
# ...              ...              ...         ...                ...
# 3001              56              037          WY  Sweetwater County
# 3002              56              039          WY       Teton County
# 3003              56              041          WY       Uinta County
# 3004              56              043          WY    Washakie County
# 3005              56              045          WY      Weston County
#
#       Poverty Estimate, All Ages_2017  90% CI LB All Ages_2017  \
# 0                              7390.0                   6147.0
# 1                             21199.0                  17444.0
# 2                              7414.0                   6325.0
# 3                              4137.0                   3187.0
# 4                              7343.0                   5805.0
# ...                               ...                      ...
# 3001                           4253.0                   3540.0
# 3002                           1348.0                   1021.0
# 3003                           2067.0                   1623.0
# 3004                            845.0                    632.0
# 3005                            699.0                    541.0
#
#       90% CI UB All Ages_2017  Poverty Percent, All Ages_2017  \
# 0                      8633.0                       13.400000
# 1                     24954.0                       10.100000
# 2                      8503.0                       33.400002
# 3                      5087.0                       20.200001
# 4                      8881.0                       12.800000
# ...                       ...                             ...
# 3001                   4966.0                       10.000000
# 3002                   1675.0                        5.800000
# 3003                   2511.0                       10.200000
# 3004                   1058.0                       10.700000
# 3005                    857.0                       10.600000
#
#       90% CI LB percent_2017  90% CI UB percent_2017  ...  \
# 0                       11.1               15.700000  ...
# 1                        8.3               11.900000  ...
# 2                       28.5               38.299999  ...
# 3                       15.5               24.900000  ...
# 4                       10.1               15.500000  ...
# ...                      ...                     ...  ...
# 3001                     8.3               11.700000  ...
# 3002                     4.4                7.200000  ...
# 3003                     8.0               12.400000  ...
# 3004                     8.0               13.400000  ...
# 3005                     8.2               13.000000  ...
#
#       90% CI UB 0-17 percent_2019  \
# 0                       20.299999
# 1                       17.400000
# 2                       50.799999
# 3                       33.099998
# 4                       25.299999
# ...                           ...
# 3001                    13.000000
# 3002                     7.800000
# 3003                    13.100000
# 3004                    18.900000
# 3005                    18.700001
#
#       Poverty Estimate, Age 5-17 in Families_2019  90% CI LB 5-17 fam_2019  \
# 0                                          1376.0                    902.0
# 1                                          4641.0                   3295.0
# 2                                          1468.0                   1114.0
# 3                                           808.0                    566.0
# 4                                          2067.0                   1641.0
# ...                                           ...                      ...
# 3001                                        644.0                    416.0
# 3002                                        142.0                     83.0
# 3003                                        336.0                    193.0
# 3004                                        160.0                     94.0
# 3005                                        120.0                     70.0
#
#       90% CI UB 5-17 fam_2019  Poverty Percent, Age 5-17 in Families_2019  \
# 0                      1850.0                                   14.400000
# 1                      5987.0                                   13.300000
# 2                      1822.0                                   39.500000
# 3                      1050.0                                   25.200001
# 4                      2493.0                                   21.400000
# ...                       ...                                         ...
# 3001                    872.0                                    8.200000
# 3002                    201.0                                    4.700000
# 3003                    479.0                                    7.800000
# 3004                    226.0                                   12.300000
# 3005                    170.0                                   11.800000
#
#       90% CI LB 5-17 percent_2019  90% CI UB percent 5-17 percent_2019  \
# 0                        9.400000                            19.400000
# 1                        9.400000                            17.200001
# 2                       30.000000                            49.000000
# 3                       17.700001                            32.700001
# 4                       17.000000                            25.799999
# ...                           ...                                  ...
# 3001                     5.300000                            11.100000
# 3002                     2.700000                             6.700000
# 3003                     4.500000                            11.100000
# 3004                     7.200000                            17.400000
# 3005                     6.900000                            16.700001
#
#       Median Household Income_2019  90% CI Lower Bound LB medh inc_2019  \
# 0                          58233.0                              52517.0
# 1                          59871.0                              54593.0
# 2                          35972.0                              31822.0
# 3                          47918.0                              42291.0
# 4                          52902.0                              46777.0
# ...                            ...                                  ...
# 3001                       80639.0                              73437.0
# 3002                       98837.0                              86531.0
# 3003                       70756.0                              63191.0
# 3004                       55122.0                              50050.0
# 3005                       59410.0                              52275.0
#
#       90% CI UB medh inc_2019
# 0                     63949.0
# 1                     65149.0
# 2                     40122.0
# 3                     53545.0
# 4                     59027.0
# ...                       ...
# 3001                  87841.0
# 3002                 111143.0
# 3003                  78321.0
# 3004                  60194.0
# 3005                  66545.0
#
# [3006 rows x 67 columns]

# %%
state_code = pov_rate_2017_2019['State FIPS Code'].astype(str).values
county_code = pov_rate_2017_2019['County FIPS Code'].astype(str).values
geofips = []
for stateID, countyID in zip(state_code, county_code):
    id = ''
    id += stateID
    id += countyID
    geofips.append(id)
pov_rate_2017_2019.insert(loc=0, column='GeoFIPS', value=geofips)

# %%
pov_rate_2017_2019.drop(['State FIPS Code', 'County FIPS Code'], axis=1, inplace=True)
display(pov_rate_2017_2019)
# Out:
#      GeoFIPS Postal Code               Name  Poverty Estimate, All Ages_2017  \
# 0      01001          AL     Autauga County                           7390.0
# 1      01003          AL     Baldwin County                          21199.0
# 2      01005          AL     Barbour County                           7414.0
# 3      01007          AL        Bibb County                           4137.0
# 4      01009          AL      Blount County                           7343.0
# ...      ...         ...                ...                              ...
# 3001   56037          WY  Sweetwater County                           4253.0
# 3002   56039          WY       Teton County                           1348.0
# 3003   56041          WY       Uinta County                           2067.0
# 3004   56043          WY    Washakie County                            845.0
# 3005   56045          WY      Weston County                            699.0
#
#       90% CI LB All Ages_2017  90% CI UB All Ages_2017  \
# 0                      6147.0                   8633.0
# 1                     17444.0                  24954.0
# 2                      6325.0                   8503.0
# 3                      3187.0                   5087.0
# 4                      5805.0                   8881.0
# ...                       ...                      ...
# 3001                   3540.0                   4966.0
# 3002                   1021.0                   1675.0
# 3003                   1623.0                   2511.0
# 3004                    632.0                   1058.0
# 3005                    541.0                    857.0
#
#       Poverty Percent, All Ages_2017  90% CI LB percent_2017  \
# 0                          13.400000                    11.1
# 1                          10.100000                     8.3
# 2                          33.400002                    28.5
# 3                          20.200001                    15.5
# 4                          12.800000                    10.1
# ...                              ...                     ...
# 3001                       10.000000                     8.3
# 3002                        5.800000                     4.4
# 3003                       10.200000                     8.0
# 3004                       10.700000                     8.0
# 3005                       10.600000                     8.2
#
#       90% CI UB percent_2017  Poverty Estimate, Age 0-17_2017  ...  \
# 0                  15.700000                           2542.0  ...
# 1                  11.900000                           6734.0  ...
# 2                  38.299999                           2606.0  ...
# 3                  24.900000                           1242.0  ...
# 4                  15.500000                           2484.0  ...
# ...                      ...                              ...  ...
# 3001               11.700000                           1509.0  ...
# 3002                7.200000                            296.0  ...
# 3003               12.400000                            697.0  ...
# 3004               13.400000                            260.0  ...
# 3005               13.000000                            198.0  ...
#
#       90% CI UB 0-17 percent_2019  \
# 0                       20.299999
# 1                       17.400000
# 2                       50.799999
# 3                       33.099998
# 4                       25.299999
# ...                           ...
# 3001                    13.000000
# 3002                     7.800000
# 3003                    13.100000
# 3004                    18.900000
# 3005                    18.700001
#
#       Poverty Estimate, Age 5-17 in Families_2019  90% CI LB 5-17 fam_2019  \
# 0                                          1376.0                    902.0
# 1                                          4641.0                   3295.0
# 2                                          1468.0                   1114.0
# 3                                           808.0                    566.0
# 4                                          2067.0                   1641.0
# ...                                           ...                      ...
# 3001                                        644.0                    416.0
# 3002                                        142.0                     83.0
# 3003                                        336.0                    193.0
# 3004                                        160.0                     94.0
# 3005                                        120.0                     70.0
#
#       90% CI UB 5-17 fam_2019  Poverty Percent, Age 5-17 in Families_2019  \
# 0                      1850.0                                   14.400000
# 1                      5987.0                                   13.300000
# 2                      1822.0                                   39.500000
# 3                      1050.0                                   25.200001
# 4                      2493.0                                   21.400000
# ...                       ...                                         ...
# 3001                    872.0                                    8.200000
# 3002                    201.0                                    4.700000
# 3003                    479.0                                    7.800000
# 3004                    226.0                                   12.300000
# 3005                    170.0                                   11.800000
#
#       90% CI LB 5-17 percent_2019  90% CI UB percent 5-17 percent_2019  \
# 0                        9.400000                            19.400000
# 1                        9.400000                            17.200001
# 2                       30.000000                            49.000000
# 3                       17.700001                            32.700001
# 4                       17.000000                            25.799999
# ...                           ...                                  ...
# 3001                     5.300000                            11.100000
# 3002                     2.700000                             6.700000
# 3003                     4.500000                            11.100000
# 3004                     7.200000                            17.400000
# 3005                     6.900000                            16.700001
#
#       Median Household Income_2019  90% CI Lower Bound LB medh inc_2019  \
# 0                          58233.0                              52517.0
# 1                          59871.0                              54593.0
# 2                          35972.0                              31822.0
# 3                          47918.0                              42291.0
# 4                          52902.0                              46777.0
# ...                            ...                                  ...
# 3001                       80639.0                              73437.0
# 3002                       98837.0                              86531.0
# 3003                       70756.0                              63191.0
# 3004                       55122.0                              50050.0
# 3005                       59410.0                              52275.0
#
#       90% CI UB medh inc_2019
# 0                     63949.0
# 1                     65149.0
# 2                     40122.0
# 3                     53545.0
# 4                     59027.0
# ...                       ...
# 3001                  87841.0
# 3002                 111143.0
# 3003                  78321.0
# 3004                  60194.0
# 3005                  66545.0
#
# [3006 rows x 66 columns]

# %% [markdown]
# ## merge education and vehicle rates for 2017-2019 into one dataframe

# %%
educ_vehicle_2017
# Out:
#                               NAME  state  county  POP_2017  EDU_TOT_2017  \
# 0    St. Lawrence County, New York     36      89    109623       72555.0
# 1        Saratoga County, New York     36      91    229869      164414.0
# 2     Schenectady County, New York     36      93    155565      107453.0
# 3         Steuben County, New York     36     101     96281       68011.0
# 4         Suffolk County, New York     36     103   1492953     1036946.0
# ..                             ...    ...     ...       ...           ...
# 832        Putnam County, New York     36      79     99323       71447.0
# 833        Queens County, New York     36      81   2358582     1695302.0
# 834    Rensselaer County, New York     36      83    159722      111047.0
# 835      Richmond County, New York     36      85    479458      334079.0
# 836      Rockland County, New York     36      87    328868      205985.0
#
#      LESS_HS_TOT_2017  HS_TOT_2017  COL_OR_ASSOC_TOT_2017  BACH_TOT_2017  \
# 0              9164.0      25858.0                20091.0         8279.0
# 1             10656.0      39033.0                45561.0        37886.0
# 2             10085.0      32144.0                35263.0        17210.0
# 3              6510.0      25920.0                20685.0         7451.0
# 4            102621.0     277080.0               279213.0       208064.0
# ..                ...          ...                    ...            ...
# 832            5090.0      20597.0                18095.0        14929.0
# 833          304984.0     493794.0               372885.0       335990.0
# 834            9095.0      31730.0                34954.0        20143.0
# 835           39031.0     100730.0                83679.0        66108.0
# 836           22972.0      46985.0                51510.0        46786.0
#
#      GRAD_TOT_2017  VEHICLE_TOT_2017  EDU_TOT_ratio_2017  \
# 0           9163.0             35920           66.185928
# 1          31278.0            105705           71.525086
# 2          12751.0             60290           69.072735
# 3           7445.0             35585           70.638028
# 4         169968.0            617715           69.456038
# ..             ...               ...                 ...
# 832        12736.0             42395           71.933993
# 833       187649.0            391980           71.878018
# 834        15125.0             65720           69.525175
# 835        44531.0            127985           69.678470
# 836        37732.0            112645           62.634552
#
#      LESS_HS_TOT_ratio_2017  HS_TOT_ratio_2017  COL_OR_ASSOC_TOT_ratio_2017  \
# 0                  8.359560          23.588116                    18.327358
# 1                  4.635684          16.980541                    19.820419
# 2                  6.482821          20.662745                    22.667695
# 3                  6.761459          26.921199                    21.483990
# 4                  6.873693          18.559191                    18.702062
# ..                      ...                ...                          ...
# 832                5.124694          20.737392                    18.218338
# 833               12.930820          20.936054                    15.809711
# 834                5.694269          19.865767                    21.884274
# 835                8.140650          21.009139                    17.452832
# 836                6.985173          14.286887                    15.662819
#
#      BACH_TOT_ratio_2017  GRAD_TOT_ratio_2017  VEHICLE_TOT_ratio_2017
# 0               7.552247             8.358647               32.766846
# 1              16.481561            13.606880               45.984887
# 2              11.062900             8.196574               38.755504
# 3               7.738806             7.732574               36.959525
# 4              13.936407            11.384685               41.375382
# ..                   ...                  ...                     ...
# 832            15.030758            12.822810               42.683970
# 833            14.245424             7.956009               16.619308
# 834            12.611287             9.469578               41.146492
# 835            13.788069             9.287779               26.693683
# 836            14.226377            11.473296               34.252344
#
# [837 rows x 18 columns]

# %%
educ_vehicle_2017_2018 = pd.merge(educ_vehicle_2017, educ_vehicle_2018, how='inner')
educ_vehicle_2017_2019 = pd.merge(educ_vehicle_2017_2018, educ_vehicle_2019, how='inner')
educ_vehicle_2017_2019
# Out:
#                               NAME  state  county  POP_2017  EDU_TOT_2017  \
# 0    St. Lawrence County, New York     36      89    109623       72555.0
# 1        Saratoga County, New York     36      91    229869      164414.0
# 2     Schenectady County, New York     36      93    155565      107453.0
# 3         Steuben County, New York     36     101     96281       68011.0
# 4         Suffolk County, New York     36     103   1492953     1036946.0
# ..                             ...    ...     ...       ...           ...
# 831        Putnam County, New York     36      79     99323       71447.0
# 832        Queens County, New York     36      81   2358582     1695302.0
# 833    Rensselaer County, New York     36      83    159722      111047.0
# 834      Richmond County, New York     36      85    479458      334079.0
# 835      Rockland County, New York     36      87    328868      205985.0
#
#      LESS_HS_TOT_2017  HS_TOT_2017  COL_OR_ASSOC_TOT_2017  BACH_TOT_2017  \
# 0              9164.0      25858.0                20091.0         8279.0
# 1             10656.0      39033.0                45561.0        37886.0
# 2             10085.0      32144.0                35263.0        17210.0
# 3              6510.0      25920.0                20685.0         7451.0
# 4            102621.0     277080.0               279213.0       208064.0
# ..                ...          ...                    ...            ...
# 831            5090.0      20597.0                18095.0        14929.0
# 832          304984.0     493794.0               372885.0       335990.0
# 833            9095.0      31730.0                34954.0        20143.0
# 834           39031.0     100730.0                83679.0        66108.0
# 835           22972.0      46985.0                51510.0        46786.0
#
#      GRAD_TOT_2017  ...  BACH_TOT_2019  GRAD_TOT_2019  VEHICLE_TOT_2019  \
# 0           9163.0  ...         8684.0         7733.0             33650
# 1          31278.0  ...        40148.0        30363.0            104085
# 2          12751.0  ...        22627.0        15566.0             59970
# 3           7445.0  ...         8066.0         8475.0             35505
# 4         169968.0  ...       214035.0       182346.0            629360
# ..             ...  ...            ...            ...               ...
# 831        12736.0  ...        15240.0        12261.0             42420
# 832       187649.0  ...       334272.0       207624.0            387870
# 833        15125.0  ...        20896.0        18203.0             65615
# 834        44531.0  ...        71914.0        48875.0            128740
# 835        37732.0  ...        46487.0        39510.0            111705
#
#      EDU_TOT_ratio_2019  LESS_HS_TOT_ratio_2019  HS_TOT_ratio_2019  \
# 0             67.044737                8.564136          23.762762
# 1             72.095118                4.492676          17.754924
# 2             70.183324                5.047682          20.198456
# 3             71.044989                6.093585          25.791841
# 4             70.148605                6.397598          18.389192
# ..                  ...                     ...                ...
# 831           73.443857                5.721115          19.355167
# 832           72.484558               12.328372          19.812340
# 833           70.327759                5.902441          19.919478
# 834           70.041143                7.701258          20.426427
# 835           62.486456                6.950511          13.296029
#
#      COL_OR_ASSOC_TOT_ratio_2019  BACH_TOT_ratio_2019  GRAD_TOT_ratio_2019  \
# 0                      19.480230             8.060145             7.177464
# 1                      19.172290            17.466056            13.209172
# 2                      20.343982            14.569959            10.023245
# 3                      21.817171             8.456788             8.885604
# 4                      18.517663            14.495114            12.349037
# ..                           ...                  ...                  ...
# 831                    20.396664            15.500407            12.470504
# 832                    16.300805            14.831103             9.211938
# 833                    19.870963            13.165820            11.469058
# 834                    16.545240            15.103446            10.264773
# 835                    15.843383            14.269051            12.127481
#
#      VEHICLE_TOT_ratio_2019
# 0                 31.232597
# 1                 45.281320
# 2                 38.615831
# 3                 37.225175
# 4                 42.622211
# ..                      ...
# 831               43.144833
# 832               17.209159
# 833               41.341659
# 834               27.038096
# 835               34.287530
#
# [836 rows x 48 columns]

# %%
educ_vehicle_2017_2019 = get_df_with_geofips(educ_vehicle_2017_2019, 'state', 'county')
educ_vehicle_2017_2019
# Out:
#     GeoFIPS                           NAME  state  county  POP_2017  \
# 0     36089  St. Lawrence County, New York     36      89    109623
# 1     36091      Saratoga County, New York     36      91    229869
# 2     36093   Schenectady County, New York     36      93    155565
# 3     36101       Steuben County, New York     36     101     96281
# 4     36103       Suffolk County, New York     36     103   1492953
# ..      ...                            ...    ...     ...       ...
# 831   36079        Putnam County, New York     36      79     99323
# 832   36081        Queens County, New York     36      81   2358582
# 833   36083    Rensselaer County, New York     36      83    159722
# 834   36085      Richmond County, New York     36      85    479458
# 835   36087      Rockland County, New York     36      87    328868
#
#      EDU_TOT_2017  LESS_HS_TOT_2017  HS_TOT_2017  COL_OR_ASSOC_TOT_2017  \
# 0         72555.0            9164.0      25858.0                20091.0
# 1        164414.0           10656.0      39033.0                45561.0
# 2        107453.0           10085.0      32144.0                35263.0
# 3         68011.0            6510.0      25920.0                20685.0
# 4       1036946.0          102621.0     277080.0               279213.0
# ..            ...               ...          ...                    ...
# 831       71447.0            5090.0      20597.0                18095.0
# 832     1695302.0          304984.0     493794.0               372885.0
# 833      111047.0            9095.0      31730.0                34954.0
# 834      334079.0           39031.0     100730.0                83679.0
# 835      205985.0           22972.0      46985.0                51510.0
#
#      BACH_TOT_2017  ...  BACH_TOT_2019  GRAD_TOT_2019  VEHICLE_TOT_2019  \
# 0           8279.0  ...         8684.0         7733.0             33650
# 1          37886.0  ...        40148.0        30363.0            104085
# 2          17210.0  ...        22627.0        15566.0             59970
# 3           7451.0  ...         8066.0         8475.0             35505
# 4         208064.0  ...       214035.0       182346.0            629360
# ..             ...  ...            ...            ...               ...
# 831        14929.0  ...        15240.0        12261.0             42420
# 832       335990.0  ...       334272.0       207624.0            387870
# 833        20143.0  ...        20896.0        18203.0             65615
# 834        66108.0  ...        71914.0        48875.0            128740
# 835        46786.0  ...        46487.0        39510.0            111705
#
#      EDU_TOT_ratio_2019  LESS_HS_TOT_ratio_2019  HS_TOT_ratio_2019  \
# 0             67.044737                8.564136          23.762762
# 1             72.095118                4.492676          17.754924
# 2             70.183324                5.047682          20.198456
# 3             71.044989                6.093585          25.791841
# 4             70.148605                6.397598          18.389192
# ..                  ...                     ...                ...
# 831           73.443857                5.721115          19.355167
# 832           72.484558               12.328372          19.812340
# 833           70.327759                5.902441          19.919478
# 834           70.041143                7.701258          20.426427
# 835           62.486456                6.950511          13.296029
#
#      COL_OR_ASSOC_TOT_ratio_2019  BACH_TOT_ratio_2019  GRAD_TOT_ratio_2019  \
# 0                      19.480230             8.060145             7.177464
# 1                      19.172290            17.466056            13.209172
# 2                      20.343982            14.569959            10.023245
# 3                      21.817171             8.456788             8.885604
# 4                      18.517663            14.495114            12.349037
# ..                           ...                  ...                  ...
# 831                    20.396664            15.500407            12.470504
# 832                    16.300805            14.831103             9.211938
# 833                    19.870963            13.165820            11.469058
# 834                    16.545240            15.103446            10.264773
# 835                    15.843383            14.269051            12.127481
#
#      VEHICLE_TOT_ratio_2019
# 0                 31.232597
# 1                 45.281320
# 2                 38.615831
# 3                 37.225175
# 4                 42.622211
# ..                      ...
# 831               43.144833
# 832               17.209159
# 833               41.341659
# 834               27.038096
# 835               34.287530
#
# [836 rows x 49 columns]

# %% [markdown]
# ## Merge demographic years as one spanning 2017-2019

# %%
# add suffix to each column name then merge
demographic = county_dem_ratio_17.columns.values[3:]

for dem in demographic:
    county_dem_ratio_17.rename(columns={dem:dem + '_2017'}, inplace=True)
    county_dem_ratio_18.rename(columns={dem:dem + '_2018'}, inplace=True)
    county_dem_ratio_19.rename(columns={dem:dem + '_2019'}, inplace=True)
# Out:
# /home/wkc/.local/lib/python3.8/site-packages/pandas/core/frame.py:4300: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
county_dem_ratio_17
# Out:
#        GeoFIPS   STNAME            CTYNAME  TOT_POP_2017  TOT_MALE_2017  \
# 171      01001  Alabama     Autauga County         55390          27010
# 399      01003  Alabama     Baldwin County        212521         103218
# 627      01005  Alabama     Barbour County         25157          13230
# 855      01007  Alabama        Bibb County         22550          12056
# 1083     01009  Alabama      Blount County         57787          28449
# ...        ...      ...                ...           ...            ...
# 715407   56037  Wyoming  Sweetwater County         43464          22438
# 715635   56039  Wyoming       Teton County         23384          12133
# 715863   56041  Wyoming       Uinta County         20431          10339
# 716091   56043  Wyoming    Washakie County          8010           4055
# 716319   56045  Wyoming      Weston County          6968           3660
#
#         TOT_FEMALE_2017  WA_MALE_2017  WA_FEMALE_2017  BA_MALE_2017  \
# 171               28380         20876           21705          5139
# 399              109303         90360           95215          9279
# 627               11927          6533            5918          6360
# 855               10494          8853            8453          2996
# 1083              29338         27301           28144           488
# ...                 ...           ...             ...           ...
# 715407            21026         21098           19776           342
# 715635            11251         11592           10705            95
# 715863            10092          9884            9625            79
# 716091             3955          3865            3735            23
# 716319             3308          3447            3111            29
#
#         BA_FEMALE_2017  ...  HWAC_MALE_ratio_2017  HWAC_FEMALE_ratio_2017  \
# 171               5636  ...              1.261961                1.160859
# 399               9973  ...              2.243072                2.000743
# 627               5744  ...              2.015344                1.617840
# 855               1848  ...              1.312639                0.975610
# 1083               450  ...              4.696558                4.173949
# ...                ...  ...                   ...                     ...
# 715407             254  ...              7.815664                6.996595
# 715635              56  ...              7.496579                6.654122
# 715863              84  ...              4.145661                3.998825
# 716091              18  ...              6.641698                6.317104
# 716319              15  ...              2.009185                1.693456
#
#         HBAC_MALE_ratio_2017  HBAC_FEMALE_ratio_2017  HIAC_MALE_ratio_2017  \
# 171                 0.200397                0.140820              0.070410
# 399                 0.121870                0.127046              0.112930
# 627                 0.210677                0.190802              0.262352
# 855                 0.133038                0.075388              0.035477
# 1083                0.133248                0.119404              0.109021
# ...                      ...                     ...                   ...
# 715407              0.174857                0.163354              0.485459
# 715635              0.102634                0.098358              0.423366
# 715863              0.088101                0.107680              0.386667
# 716091              0.049938                0.124844              0.649189
# 716319              0.086108                0.100459              0.330080
#
#         HIAC_FEMALE_ratio_2017  HAAC_MALE_ratio_2017  HAAC_FEMALE_ratio_2017  \
# 171                   0.074021              0.021665                0.027081
# 399                   0.076228              0.019763                0.026350
# 627                   0.111301              0.007950                0.003975
# 855                   0.053215              0.013304                0.004435
# 1083                  0.126326              0.027688                0.031149
# ...                        ...                   ...                     ...
# 715407                0.400331              0.096632                0.098932
# 715635                0.329285              0.051317                0.055594
# 715863                0.499241              0.034262                0.063629
# 716091                0.711610              0.074906                0.162297
# 716319                0.258324              0.028703                0.086108
#
#         HNAC_MALE_ratio_2017  HNAC_FEMALE_ratio_2017
# 171                 0.030691                0.027081
# 399                 0.020704                0.018822
# 627                 0.059626                0.031800
# 855                 0.075388                0.013304
# 1083                0.048454                0.032879
# ...                      ...                     ...
# 715407              0.046015                0.020707
# 715635              0.068423                0.038488
# 715863              0.053840                0.009789
# 716091              0.087391                0.099875
# 716319              0.028703                0.028703
#
# [3142 rows x 148 columns]

# %%
county_dem_ratio_2017_2018 = pd.merge(county_dem_ratio_17, county_dem_ratio_18, how='inner')
county_dem_ratio_2017_2019 = pd.merge(county_dem_ratio_2017_2018, county_dem_ratio_19, how='inner')
county_dem_ratio_2017_2019.shape
display(county_dem_ratio_2017_2019)
# Out:
#      GeoFIPS   STNAME            CTYNAME  TOT_POP_2017  TOT_MALE_2017  \
# 0      01001  Alabama     Autauga County         55390          27010
# 1      01003  Alabama     Baldwin County        212521         103218
# 2      01005  Alabama     Barbour County         25157          13230
# 3      01007  Alabama        Bibb County         22550          12056
# 4      01009  Alabama      Blount County         57787          28449
# ...      ...      ...                ...           ...            ...
# 3137   56037  Wyoming  Sweetwater County         43464          22438
# 3138   56039  Wyoming       Teton County         23384          12133
# 3139   56041  Wyoming       Uinta County         20431          10339
# 3140   56043  Wyoming    Washakie County          8010           4055
# 3141   56045  Wyoming      Weston County          6968           3660
#
#       TOT_FEMALE_2017  WA_MALE_2017  WA_FEMALE_2017  BA_MALE_2017  \
# 0               28380         20876           21705          5139
# 1              109303         90360           95215          9279
# 2               11927          6533            5918          6360
# 3               10494          8853            8453          2996
# 4               29338         27301           28144           488
# ...               ...           ...             ...           ...
# 3137            21026         21098           19776           342
# 3138            11251         11592           10705            95
# 3139            10092          9884            9625            79
# 3140             3955          3865            3735            23
# 3141             3308          3447            3111            29
#
#       BA_FEMALE_2017  ...  HWAC_MALE_ratio_2019  HWAC_FEMALE_ratio_2019  \
# 0               5636  ...              1.392543                1.229662
# 1               9973  ...              2.304308                2.081224
# 2               5744  ...              2.061897                1.652759
# 3               1848  ...              1.299455                1.129767
# 4                450  ...              4.831737                4.350984
# ...              ...  ...                   ...                     ...
# 3137             254  ...              7.843091                7.077911
# 3138              56  ...              7.577566                6.725196
# 3139              84  ...              4.153070                4.153070
# 3140              18  ...              6.559898                6.265215
# 3141              15  ...              1.905587                1.732352
#
#       HBAC_MALE_ratio_2019  HBAC_FEMALE_ratio_2019  HIAC_MALE_ratio_2019  \
# 0                 0.159301                0.166461              0.071596
# 1                 0.120053                0.125877              0.118262
# 2                 0.255205                0.202544              0.247104
# 3                 0.142895                0.084844              0.026793
# 4                 0.131429                0.100301              0.115865
# ...                    ...                     ...                   ...
# 3137              0.196018                0.172402              0.500673
# 3138              0.106546                0.098023              0.447494
# 3139              0.084050                0.113715              0.405419
# 3140              0.089686                0.115311              0.691864
# 3141              0.072181                0.115490              0.332034
#
#       HIAC_FEMALE_ratio_2019  HAAC_MALE_ratio_2019  HAAC_FEMALE_ratio_2019  \
# 0                   0.048327              0.026849                0.034008
# 1                   0.088248              0.030909                0.029117
# 2                   0.105323              0.004051                0.000000
# 3                   0.066982              0.022327                0.004465
# 4                   0.114136              0.031128                0.036316
# ...                      ...                   ...                     ...
# 3137                0.462886              0.077935                0.085020
# 3138                0.345210              0.068190                0.063928
# 3139                0.548799              0.014832                0.059330
# 3140                0.755926              0.089686                0.102498
# 3141                0.288725              0.086618                0.057745
#
#       HNAC_MALE_ratio_2019  HNAC_FEMALE_ratio_2019
# 0                 0.028638                0.019689
# 1                 0.024638                0.015679
# 2                 0.056712                0.032407
# 3                 0.075913                0.013396
# 4                 0.058797                0.036316
# ...                    ...                     ...
# 3137              0.037787                0.021255
# 3138              0.051142                0.029833
# 3139              0.039553                0.009888
# 3140              0.051249                0.025625
# 3141              0.028873                0.000000
#
# [3142 rows x 438 columns]

# %% [markdown]
# ## Merge avg northeast aqi data

# %%
avg_aqi_2017_2018 = pd.merge(average_aqi_2017, average_aqi_2018, how='inner')
avg_aqi_2017_2019 = pd.merge(avg_aqi_2017_2018, average_aqi_2019, how='inner')
avg_aqi_2017_2019
# Out:
#      GeoFIPS         State Name            county Name   AQI_2017   AQI_2018  \
# 0      01003            Alabama                Baldwin  37.503704  36.829630
# 1      01027            Alabama                   Clay  32.457627  28.990909
# 2      01033            Alabama                Colbert  36.155477  35.635379
# 3      01049            Alabama                 DeKalb  38.239554  36.720000
# 4      01051            Alabama                 Elmore  34.371681  35.328829
# ...      ...                ...                    ...        ...        ...
# 1025   72113        Puerto Rico                  Ponce  33.734440  46.448179
# 1026   78010     Virgin Islands               St Croix  24.346154  29.090909
# 1027   78020     Virgin Islands                St John  26.223881  21.000000
# 1028   80002  Country Of Mexico  BAJA CALIFORNIA NORTE  74.343490  85.000000
# 1029   80026  Country Of Mexico                 SONORA  41.282297  40.477901
#
#        AQI_2019
# 0     38.291513
# 1     31.149533
# 2     35.520913
# 3     39.711911
# 4     38.421053
# ...         ...
# 1025  39.233618
# 1026  24.877193
# 1027  21.752475
# 1028  77.125000
# 1029  44.416201
#
# [1030 rows x 6 columns]

# %% [markdown]
# # saved cleaned up datasets

# %%
data_path = r'../../data/processed/county_incomes_2017_2019'
county_incomes_2017_2019.to_csv(data_path, index=False)

data_path = r'../../data/processed/clean_edu_vehicle_2017_2019.csv'
educ_vehicle_2017_2019.to_csv(data_path, index=False)

data_path = r'../../data/processed/clean_pov_rate_2017_2019.csv'
pov_rate_2017_2019.to_csv(data_path, index=False)

data_path = r'../../data/processed/clean_UE_rate_2017_2019.csv'
UE_county_rate.to_csv(data_path, index=False)

data_path = r'../../data/processed/clean_avg_aqi_2017_2019'
avg_aqi_2017_2019.to_csv(data_path, index=False)

data_path = r'../../data/processed/clean_county_dem_ratio_2017_2019.csv'
county_dem_ratio_2017_2019.to_csv(data_path, index=False)

# %% [markdown]
# # Merge datasets and check for relationships
# # Follows same processes in DataWrangling11

# %% [markdown]
# * have all data for 2017 all compiled together merged columns
# * then repeat for 2018 and 2019 data

# %%
unemploy_rate_2017_2019 = UE_county_rate

display(avg_aqi_2017_2019)
display(UE_county_rate)
display(pov_rate_2017_2019)
display(educ_vehicle_2017_2019)
display(county_dem_ratio_2017_2019)
display(county_incomes_2017_2019)
# Out:
#      GeoFIPS         State Name            county Name   AQI_2017   AQI_2018  \
# 0      01003            Alabama                Baldwin  37.503704  36.829630
# 1      01027            Alabama                   Clay  32.457627  28.990909
# 2      01033            Alabama                Colbert  36.155477  35.635379
# 3      01049            Alabama                 DeKalb  38.239554  36.720000
# 4      01051            Alabama                 Elmore  34.371681  35.328829
# ...      ...                ...                    ...        ...        ...
# 1025   72113        Puerto Rico                  Ponce  33.734440  46.448179
# 1026   78010     Virgin Islands               St Croix  24.346154  29.090909
# 1027   78020     Virgin Islands                St John  26.223881  21.000000
# 1028   80002  Country Of Mexico  BAJA CALIFORNIA NORTE  74.343490  85.000000
# 1029   80026  Country Of Mexico                 SONORA  41.282297  40.477901
#
#        AQI_2019
# 0     38.291513
# 1     31.149533
# 2     35.520913
# 3     39.711911
# 4     38.421053
# ...         ...
# 1025  39.233618
# 1026  24.877193
# 1027  21.752475
# 1028  77.125000
# 1029  44.416201
#
# [1030 rows x 6 columns]
#      GeoFIPS Stabr                area_name  Civilian_labor_force_2017  \
# 0      01001    AL       Autauga County, AL                      26075
# 1      01003    AL       Baldwin County, AL                      92456
# 2      01005    AL       Barbour County, AL                       8349
# 3      01007    AL          Bibb County, AL                       8583
# 4      01009    AL        Blount County, AL                      24822
# ...      ...   ...                      ...                        ...
# 3213   72145    PR  Vega Baja Municipio, PR                      13414
# 3214   72147    PR    Vieques Municipio, PR                       3027
# 3215   72149    PR   Villalba Municipio, PR                       7557
# 3216   72151    PR    Yabucoa Municipio, PR                       9000
# 3217   72153    PR      Yauco Municipio, PR                      10160
#
#       Employed_2017  Unemployed_2017  Unemployment_rate_2017  \
# 0             25062             1013                3.900000
# 1             88711             3745                4.100000
# 2              7863              486                5.800000
# 3              8208              375                4.400000
# 4             23824              998                4.000000
# ...             ...              ...                     ...
# 3213          11746             1668               12.400000
# 3214           2589              438               14.500000
# 3215           6090             1467               19.400000
# 3216           7512             1488               16.500000
# 3217           8409             1751               17.200001
#
#       Civilian_labor_force_2018  Employed_2018  Unemployed_2018  \
# 0                         26196          25261              935
# 1                         95233          91809             3424
# 2                          8414           7987              427
# 3                          8605           8268              337
# 4                         25069          24201              868
# ...                         ...            ...              ...
# 3213                      13117          11750             1367
# 3214                       2718           2269              449
# 3215                       7311           6154             1157
# 3216                       8762           7509             1253
# 3217                       9716           8288             1428
#
#       Unemployment_rate_2018  Civilian_labor_force_2019  Employed_2019  \
# 0                        3.6                      26172          25458
# 1                        3.6                      97328          94675
# 2                        5.1                       8537           8213
# 3                        3.9                       8685           8419
# 4                        3.5                      25331          24655
# ...                      ...                        ...            ...
# 3213                    10.4                      13037          11791
# 3214                    16.5                       2585           2406
# 3215                    15.8                       7406           6231
# 3216                    14.3                       8691           7552
# 3217                    14.7                       9759           8331
#
#       Unemployed_2019  Unemployment_rate_2019
# 0                 714                     2.7
# 1                2653                     2.7
# 2                 324                     3.8
# 3                 266                     3.1
# 4                 676                     2.7
# ...               ...                     ...
# 3213             1246                     9.6
# 3214              179                     6.9
# 3215             1175                    15.9
# 3216             1139                    13.1
# 3217             1428                    14.6
#
# [3218 rows x 15 columns]
#      GeoFIPS Postal Code               Name  Poverty Estimate, All Ages_2017  \
# 0      01001          AL     Autauga County                           7390.0
# 1      01003          AL     Baldwin County                          21199.0
# 2      01005          AL     Barbour County                           7414.0
# 3      01007          AL        Bibb County                           4137.0
# 4      01009          AL      Blount County                           7343.0
# ...      ...         ...                ...                              ...
# 3001   56037          WY  Sweetwater County                           4253.0
# 3002   56039          WY       Teton County                           1348.0
# 3003   56041          WY       Uinta County                           2067.0
# 3004   56043          WY    Washakie County                            845.0
# 3005   56045          WY      Weston County                            699.0
#
#       90% CI LB All Ages_2017  90% CI UB All Ages_2017  \
# 0                      6147.0                   8633.0
# 1                     17444.0                  24954.0
# 2                      6325.0                   8503.0
# 3                      3187.0                   5087.0
# 4                      5805.0                   8881.0
# ...                       ...                      ...
# 3001                   3540.0                   4966.0
# 3002                   1021.0                   1675.0
# 3003                   1623.0                   2511.0
# 3004                    632.0                   1058.0
# 3005                    541.0                    857.0
#
#       Poverty Percent, All Ages_2017  90% CI LB percent_2017  \
# 0                          13.400000                    11.1
# 1                          10.100000                     8.3
# 2                          33.400002                    28.5
# 3                          20.200001                    15.5
# 4                          12.800000                    10.1
# ...                              ...                     ...
# 3001                       10.000000                     8.3
# 3002                        5.800000                     4.4
# 3003                       10.200000                     8.0
# 3004                       10.700000                     8.0
# 3005                       10.600000                     8.2
#
#       90% CI UB percent_2017  Poverty Estimate, Age 0-17_2017  ...  \
# 0                  15.700000                           2542.0  ...
# 1                  11.900000                           6734.0  ...
# 2                  38.299999                           2606.0  ...
# 3                  24.900000                           1242.0  ...
# 4                  15.500000                           2484.0  ...
# ...                      ...                              ...  ...
# 3001               11.700000                           1509.0  ...
# 3002                7.200000                            296.0  ...
# 3003               12.400000                            697.0  ...
# 3004               13.400000                            260.0  ...
# 3005               13.000000                            198.0  ...
#
#       90% CI UB 0-17 percent_2019  \
# 0                       20.299999
# 1                       17.400000
# 2                       50.799999
# 3                       33.099998
# 4                       25.299999
# ...                           ...
# 3001                    13.000000
# 3002                     7.800000
# 3003                    13.100000
# 3004                    18.900000
# 3005                    18.700001
#
#       Poverty Estimate, Age 5-17 in Families_2019  90% CI LB 5-17 fam_2019  \
# 0                                          1376.0                    902.0
# 1                                          4641.0                   3295.0
# 2                                          1468.0                   1114.0
# 3                                           808.0                    566.0
# 4                                          2067.0                   1641.0
# ...                                           ...                      ...
# 3001                                        644.0                    416.0
# 3002                                        142.0                     83.0
# 3003                                        336.0                    193.0
# 3004                                        160.0                     94.0
# 3005                                        120.0                     70.0
#
#       90% CI UB 5-17 fam_2019  Poverty Percent, Age 5-17 in Families_2019  \
# 0                      1850.0                                   14.400000
# 1                      5987.0                                   13.300000
# 2                      1822.0                                   39.500000
# 3                      1050.0                                   25.200001
# 4                      2493.0                                   21.400000
# ...                       ...                                         ...
# 3001                    872.0                                    8.200000
# 3002                    201.0                                    4.700000
# 3003                    479.0                                    7.800000
# 3004                    226.0                                   12.300000
# 3005                    170.0                                   11.800000
#
#       90% CI LB 5-17 percent_2019  90% CI UB percent 5-17 percent_2019  \
# 0                        9.400000                            19.400000
# 1                        9.400000                            17.200001
# 2                       30.000000                            49.000000
# 3                       17.700001                            32.700001
# 4                       17.000000                            25.799999
# ...                           ...                                  ...
# 3001                     5.300000                            11.100000
# 3002                     2.700000                             6.700000
# 3003                     4.500000                            11.100000
# 3004                     7.200000                            17.400000
# 3005                     6.900000                            16.700001
#
#       Median Household Income_2019  90% CI Lower Bound LB medh inc_2019  \
# 0                          58233.0                              52517.0
# 1                          59871.0                              54593.0
# 2                          35972.0                              31822.0
# 3                          47918.0                              42291.0
# 4                          52902.0                              46777.0
# ...                            ...                                  ...
# 3001                       80639.0                              73437.0
# 3002                       98837.0                              86531.0
# 3003                       70756.0                              63191.0
# 3004                       55122.0                              50050.0
# 3005                       59410.0                              52275.0
#
#       90% CI UB medh inc_2019
# 0                     63949.0
# 1                     65149.0
# 2                     40122.0
# 3                     53545.0
# 4                     59027.0
# ...                       ...
# 3001                  87841.0
# 3002                 111143.0
# 3003                  78321.0
# 3004                  60194.0
# 3005                  66545.0
#
# [3006 rows x 66 columns]
#     GeoFIPS                           NAME  state  county  POP_2017  \
# 0     36089  St. Lawrence County, New York     36      89    109623
# 1     36091      Saratoga County, New York     36      91    229869
# 2     36093   Schenectady County, New York     36      93    155565
# 3     36101       Steuben County, New York     36     101     96281
# 4     36103       Suffolk County, New York     36     103   1492953
# ..      ...                            ...    ...     ...       ...
# 831   36079        Putnam County, New York     36      79     99323
# 832   36081        Queens County, New York     36      81   2358582
# 833   36083    Rensselaer County, New York     36      83    159722
# 834   36085      Richmond County, New York     36      85    479458
# 835   36087      Rockland County, New York     36      87    328868
#
#      EDU_TOT_2017  LESS_HS_TOT_2017  HS_TOT_2017  COL_OR_ASSOC_TOT_2017  \
# 0         72555.0            9164.0      25858.0                20091.0
# 1        164414.0           10656.0      39033.0                45561.0
# 2        107453.0           10085.0      32144.0                35263.0
# 3         68011.0            6510.0      25920.0                20685.0
# 4       1036946.0          102621.0     277080.0               279213.0
# ..            ...               ...          ...                    ...
# 831       71447.0            5090.0      20597.0                18095.0
# 832     1695302.0          304984.0     493794.0               372885.0
# 833      111047.0            9095.0      31730.0                34954.0
# 834      334079.0           39031.0     100730.0                83679.0
# 835      205985.0           22972.0      46985.0                51510.0
#
#      BACH_TOT_2017  ...  BACH_TOT_2019  GRAD_TOT_2019  VEHICLE_TOT_2019  \
# 0           8279.0  ...         8684.0         7733.0             33650
# 1          37886.0  ...        40148.0        30363.0            104085
# 2          17210.0  ...        22627.0        15566.0             59970
# 3           7451.0  ...         8066.0         8475.0             35505
# 4         208064.0  ...       214035.0       182346.0            629360
# ..             ...  ...            ...            ...               ...
# 831        14929.0  ...        15240.0        12261.0             42420
# 832       335990.0  ...       334272.0       207624.0            387870
# 833        20143.0  ...        20896.0        18203.0             65615
# 834        66108.0  ...        71914.0        48875.0            128740
# 835        46786.0  ...        46487.0        39510.0            111705
#
#      EDU_TOT_ratio_2019  LESS_HS_TOT_ratio_2019  HS_TOT_ratio_2019  \
# 0             67.044737                8.564136          23.762762
# 1             72.095118                4.492676          17.754924
# 2             70.183324                5.047682          20.198456
# 3             71.044989                6.093585          25.791841
# 4             70.148605                6.397598          18.389192
# ..                  ...                     ...                ...
# 831           73.443857                5.721115          19.355167
# 832           72.484558               12.328372          19.812340
# 833           70.327759                5.902441          19.919478
# 834           70.041143                7.701258          20.426427
# 835           62.486456                6.950511          13.296029
#
#      COL_OR_ASSOC_TOT_ratio_2019  BACH_TOT_ratio_2019  GRAD_TOT_ratio_2019  \
# 0                      19.480230             8.060145             7.177464
# 1                      19.172290            17.466056            13.209172
# 2                      20.343982            14.569959            10.023245
# 3                      21.817171             8.456788             8.885604
# 4                      18.517663            14.495114            12.349037
# ..                           ...                  ...                  ...
# 831                    20.396664            15.500407            12.470504
# 832                    16.300805            14.831103             9.211938
# 833                    19.870963            13.165820            11.469058
# 834                    16.545240            15.103446            10.264773
# 835                    15.843383            14.269051            12.127481
#
#      VEHICLE_TOT_ratio_2019
# 0                 31.232597
# 1                 45.281320
# 2                 38.615831
# 3                 37.225175
# 4                 42.622211
# ..                      ...
# 831               43.144833
# 832               17.209159
# 833               41.341659
# 834               27.038096
# 835               34.287530
#
# [836 rows x 49 columns]
#      GeoFIPS   STNAME            CTYNAME  TOT_POP_2017  TOT_MALE_2017  \
# 0      01001  Alabama     Autauga County         55390          27010
# 1      01003  Alabama     Baldwin County        212521         103218
# 2      01005  Alabama     Barbour County         25157          13230
# 3      01007  Alabama        Bibb County         22550          12056
# 4      01009  Alabama      Blount County         57787          28449
# ...      ...      ...                ...           ...            ...
# 3137   56037  Wyoming  Sweetwater County         43464          22438
# 3138   56039  Wyoming       Teton County         23384          12133
# 3139   56041  Wyoming       Uinta County         20431          10339
# 3140   56043  Wyoming    Washakie County          8010           4055
# 3141   56045  Wyoming      Weston County          6968           3660
#
#       TOT_FEMALE_2017  WA_MALE_2017  WA_FEMALE_2017  BA_MALE_2017  \
# 0               28380         20876           21705          5139
# 1              109303         90360           95215          9279
# 2               11927          6533            5918          6360
# 3               10494          8853            8453          2996
# 4               29338         27301           28144           488
# ...               ...           ...             ...           ...
# 3137            21026         21098           19776           342
# 3138            11251         11592           10705            95
# 3139            10092          9884            9625            79
# 3140             3955          3865            3735            23
# 3141             3308          3447            3111            29
#
#       BA_FEMALE_2017  ...  HWAC_MALE_ratio_2019  HWAC_FEMALE_ratio_2019  \
# 0               5636  ...              1.392543                1.229662
# 1               9973  ...              2.304308                2.081224
# 2               5744  ...              2.061897                1.652759
# 3               1848  ...              1.299455                1.129767
# 4                450  ...              4.831737                4.350984
# ...              ...  ...                   ...                     ...
# 3137             254  ...              7.843091                7.077911
# 3138              56  ...              7.577566                6.725196
# 3139              84  ...              4.153070                4.153070
# 3140              18  ...              6.559898                6.265215
# 3141              15  ...              1.905587                1.732352
#
#       HBAC_MALE_ratio_2019  HBAC_FEMALE_ratio_2019  HIAC_MALE_ratio_2019  \
# 0                 0.159301                0.166461              0.071596
# 1                 0.120053                0.125877              0.118262
# 2                 0.255205                0.202544              0.247104
# 3                 0.142895                0.084844              0.026793
# 4                 0.131429                0.100301              0.115865
# ...                    ...                     ...                   ...
# 3137              0.196018                0.172402              0.500673
# 3138              0.106546                0.098023              0.447494
# 3139              0.084050                0.113715              0.405419
# 3140              0.089686                0.115311              0.691864
# 3141              0.072181                0.115490              0.332034
#
#       HIAC_FEMALE_ratio_2019  HAAC_MALE_ratio_2019  HAAC_FEMALE_ratio_2019  \
# 0                   0.048327              0.026849                0.034008
# 1                   0.088248              0.030909                0.029117
# 2                   0.105323              0.004051                0.000000
# 3                   0.066982              0.022327                0.004465
# 4                   0.114136              0.031128                0.036316
# ...                      ...                   ...                     ...
# 3137                0.462886              0.077935                0.085020
# 3138                0.345210              0.068190                0.063928
# 3139                0.548799              0.014832                0.059330
# 3140                0.755926              0.089686                0.102498
# 3141                0.288725              0.086618                0.057745
#
#       HNAC_MALE_ratio_2019  HNAC_FEMALE_ratio_2019
# 0                 0.028638                0.019689
# 1                 0.024638                0.015679
# 2                 0.056712                0.032407
# 3                 0.075913                0.013396
# 4                 0.058797                0.036316
# ...                    ...                     ...
# 3137              0.037787                0.021255
# 3138              0.051142                0.029833
# 3139              0.039553                0.009888
# 3140              0.051249                0.025625
# 3141              0.028873                0.000000
#
# [3142 rows x 438 columns]
#      GeoFIPS         GeoName  Personal income (thousands of dollars) 2017  \
# 0      00000   United States                                 1.693758e+10
# 1      01000         Alabama                                 1.999998e+08
# 2      01001     Autauga, AL                                 2.276561e+06
# 3      01003     Baldwin, AL                                 9.471242e+06
# 4      01005     Barbour, AL                                 8.381840e+05
# ...      ...             ...                                          ...
# 3193   94000          Plains                                 1.055029e+09
# 3194   95000       Southeast                                 3.818755e+09
# 3195   96000       Southwest                                 1.924648e+09
# 3196   97000  Rocky Mountain                                 6.029942e+08
# 3197   98000        Far West                                 3.279058e+09
#
#       Personal income (thousands of dollars) 2018  \
# 0                                    1.783926e+10
# 1                                    2.087527e+08
# 2                                    2.360366e+06
# 3                                    1.006597e+07
# 4                                    8.721890e+05
# ...                                           ...
# 3193                                 1.107630e+09
# 3194                                 4.022276e+09
# 3195                                 2.051027e+09
# 3196                                 6.476007e+08
# 3197                                 3.472097e+09
#
#       Personal income (thousands of dollars) 2019  \
# 0                                    1.854226e+10
# 1                                    2.164490e+08
# 2                                    2.453617e+06
# 3                                    1.060026e+07
# 4                                    8.828340e+05
# ...                                           ...
# 3193                                 1.146515e+09
# 3194                                 4.173677e+09
# 3195                                 2.144764e+09
# 3196                                 6.803901e+08
# 3197                                 3.634009e+09
#
#       Per capita personal income (dollars) 2017  \
# 0                                       52118.0
# 1                                       41030.0
# 2                                       41101.0
# 3                                       44566.0
# 4                                       33318.0
# ...                                         ...
# 3193                                    49609.0
# 3194                                    45657.0
# 3195                                    46531.0
# 3196                                    49991.0
# 3197                                    58492.0
#
#       Per capita personal income (dollars) 2018  \
# 0                                       54606.0
# 1                                       42710.0
# 2                                       42504.0
# 3                                       46205.0
# 4                                       35067.0
# ...                                         ...
# 3193                                    51879.0
# 3194                                    47715.0
# 3195                                    49045.0
# 3196                                    52936.0
# 3197                                    61616.0
#
#       Per capita personal income (dollars) 2019
# 0                                       56490.0
# 1                                       44145.0
# 2                                       43917.0
# 3                                       47485.0
# 4                                       35763.0
# ...                                         ...
# 3193                                    53509.0
# 3194                                    49159.0
# 3195                                    50670.0
# 3196                                    54873.0
# 3197                                    64236.0
#
# [3198 rows x 8 columns]

# %% [markdown]
# ## Make one df of 2017
# * Cleaning for datasets were done in Data_Wrangling4 and Data_Wrangling7 files
# * So only transforming datasets into one will work

# %%
avg_aqi_2017 = avg_aqi_2017_2019.iloc[:,:4]
unemploy_rate_2017 = unemploy_rate_2017_2019.iloc[:, [0, 3, 4, 5, 6]]

pov_col_2017 = list(pov_rate_2017_2019.columns[0:1]) + list(pov_rate_2017_2019.columns[3:24])
pov_rate_2017 = pov_rate_2017_2019.loc[:, pov_col_2017]

county_incomes_2017 = county_incomes_2017_2019.iloc[:, [0, 2, 5]]

educ_vehicle_2017_col = list(educ_vehicle_2017_2019.columns[0:1]) + list(educ_vehicle_2017_2019.columns[4:19])
educ_vehicle_2017 = educ_vehicle_2017_2019.loc[:, educ_vehicle_2017_col]

dem_ratio_2017_col = list(county_dem_ratio_2017_2019.columns[0:1]) + list(county_dem_ratio_2017_2019.columns[3:148])
dem_ratio_2017 = county_dem_ratio_2017_2019.loc[:, dem_ratio_2017_col]

# %%
avg_aqi_unemploy_2017 = pd.merge(avg_aqi_2017, unemploy_rate_2017, how='inner')
avg_aqi_unemploy_pov_2017 = pd.merge(avg_aqi_unemploy_2017, pov_rate_2017, how='inner')
avg_aqi_unemploy_pov_inc_2017 = pd.merge(avg_aqi_unemploy_pov_2017, county_incomes_2017, how='inner')
avg_aqi_unemploy_pov_inc_educ_veh_2017 = pd.merge(avg_aqi_unemploy_pov_inc_2017, educ_vehicle_2017, how='inner')
df_2017 = pd.merge(avg_aqi_unemploy_pov_inc_educ_veh_2017, dem_ratio_2017, how='inner')

df_2017
# Out:
#     GeoFIPS State Name county Name   AQI_2017  Civilian_labor_force_2017  \
# 0     01003    Alabama     Baldwin  37.503704                      92456
# 1     01049    Alabama      DeKalb  38.239554                      29688
# 2     01051    Alabama      Elmore  34.371681                      37366
# 3     01055    Alabama      Etowah  45.630556                      43233
# 4     01069    Alabama     Houston  35.003559                      44882
# ..      ...        ...         ...        ...                        ...
# 579   55117  Wisconsin   Sheboygan  45.971429                      62584
# 580   55127  Wisconsin    Walworth  40.082305                      57960
# 581   55133  Wisconsin    Waukesha  40.573816                     226155
# 582   56021    Wyoming     Laramie  46.263014                      48230
# 583   56025    Wyoming     Natrona  45.383562                      39535
#
#      Employed_2017  Unemployed_2017  Unemployment_rate_2017  \
# 0            88711             3745                     4.1
# 1            28357             1331                     4.5
# 2            35990             1376                     3.7
# 3            41251             1982                     4.6
# 4            42923             1959                     4.4
# ..             ...              ...                     ...
# 579          60854             1730                     2.8
# 580          56062             1898                     3.3
# 581         219636             6519                     2.9
# 582          46472             1758                     3.6
# 583          37472             2063                     5.2
#
#      Poverty Estimate, All Ages_2017  90% CI LB All Ages_2017  ...  \
# 0                            21199.0                  17444.0  ...
# 1                            13785.0                  11467.0  ...
# 2                             9151.0                   7348.0  ...
# 3                            18257.0                  15600.0  ...
# 4                            17095.0                  15498.0  ...
# ..                               ...                      ...  ...
# 579                           8789.0                   7300.0  ...
# 580                          10618.0                   8877.0  ...
# 581                          19090.0                  16633.0  ...
# 582                           9294.0                   7767.0  ...
# 583                           8631.0                   7133.0  ...
#
#      HWAC_MALE_ratio_2017  HWAC_FEMALE_ratio_2017  HBAC_MALE_ratio_2017  \
# 0                2.243072                2.000743              0.121870
# 1                6.708008                5.977295              0.260369
# 2                1.266243                1.305544              0.124045
# 3                1.611541                1.460095              0.158242
# 4                1.517561                1.323076              0.184905
# ..                    ...                     ...                   ...
# 579              3.093258                2.856051              0.134678
# 580              5.593583                4.995625              0.142927
# 581              2.266406                2.199307              0.076328
# 582              7.126666                6.550312              0.264289
# 583              3.941648                3.660191              0.158319
#
#      HBAC_FEMALE_ratio_2017  HIAC_MALE_ratio_2017  HIAC_FEMALE_ratio_2017  \
# 0                  0.127046              0.112930                0.076228
# 1                  0.214175              0.531937                0.433949
# 2                  0.164575              0.084744                0.068777
# 3                  0.145621              0.148534                0.121351
# 4                  0.175324              0.114967                0.100596
# ..                      ...                   ...                     ...
# 579                0.103398              0.133809                0.147712
# 580                0.124453              0.212931                0.160428
# 581                0.092293              0.074832                0.076328
# 582                0.250058              0.433028                0.424896
# 583                0.149524              0.429724                0.341769
#
#      HAAC_MALE_ratio_2017  HAAC_FEMALE_ratio_2017  HNAC_MALE_ratio_2017  \
# 0                0.019763                0.026350              0.020704
# 1                0.085390                0.086790              0.334561
# 2                0.019651                0.024563              0.020879
# 3                0.047570                0.036891              0.138826
# 4                0.040238                0.036406              0.025868
# ..                    ...                     ...                   ...
# 579              0.047789                0.054740              0.013902
# 580              0.056393                0.049587              0.017501
# 581              0.031429                0.029933              0.013719
# 582              0.113848                0.112831              0.044726
# 583              0.074134                0.072877              0.021361
#
#      HNAC_FEMALE_ratio_2017
# 0                  0.018822
# 1                  0.258969
# 2                  0.020879
# 3                  0.114555
# 4                  0.019161
# ..                      ...
# 579                0.013033
# 580                0.021390
# 581                0.009978
# 582                0.028462
# 583                0.025130
#
# [584 rows x 191 columns]

# %% [markdown]
# * df_2017 contains data on NorthEastern counties of the US
# * The columns of df_2017 go from average aqi, unemployment rate, poverty rate, education attainment ratio, total vehicle ratio, demographic ratios

# %%
klib.corr_plot(df_2017, target='AQI_2017', method='pearson')
klib.corr_plot(df_2017, target='AQI_2017', method='kendall')
klib.corr_plot(df_2017, target='AQI_2017', method='spearman')
# Out:
# <AxesSubplot:title={'center':'Feature-correlation (spearman)'}>

# %% [markdown]
# ## Make one df of 2018
# * Cleaning for datasets were done in Data_Wrangling4 and Data_Wrangling7 files
# * So only transforming datasets into one will work

# %%
avg_aqi_2018 = avg_aqi_2017_2019.iloc[:, [0, 1, 2, 4]]

unemploy_col_2018 = list(unemploy_rate_2017_2019.columns[0:1]) + list(unemploy_rate_2017_2019.columns[7:11])
unemploy_rate_2018 = unemploy_rate_2017_2019.loc[:, unemploy_col_2018]

pov_col_2018 = list(pov_rate_2017_2019.columns[0:1]) + list(pov_rate_2017_2019.columns[24:45])
pov_rate_2018 = pov_rate_2017_2019.loc[:, pov_col_2018]

incomes_2018 = county_incomes_2017_2019.iloc[:, [0, 3, 6]]

educ_vehicle_2018_col = list(educ_vehicle_2017_2019.columns[0:1]) + list(educ_vehicle_2017_2019.columns[19:34])
educ_vehicle_2018 = educ_vehicle_2017_2019.loc[:, educ_vehicle_2018_col]

county_dem_ratio_2018_col = list(county_dem_ratio_2017_2019.columns[0:1]) + list(county_dem_ratio_2017_2019.columns[148:293])
county_dem_ratio_2018 = county_dem_ratio_2017_2019.loc[:, county_dem_ratio_2018_col]

# %%
avg_aqi_unemploy_2018 = pd.merge(avg_aqi_2018, unemploy_rate_2018, how='inner')
avg_aqi_unemploy_pov_2018 = pd.merge(avg_aqi_unemploy_2018, pov_rate_2018, how='inner')
avg_aqi_unemploy_pov_inc_2018 = pd.merge(avg_aqi_unemploy_pov_2018, incomes_2018, how='inner')
avg_aqi_unemploy_pov_inc_educ_veh_2018 = pd.merge(avg_aqi_unemploy_pov_inc_2018, educ_vehicle_2018, how='inner')
df_2018 = pd.merge(avg_aqi_unemploy_pov_inc_educ_veh_2018, county_dem_ratio_2018, how='inner')

df_2018
# Out:
#     GeoFIPS State Name county Name   AQI_2018  Civilian_labor_force_2018  \
# 0     01003    Alabama     Baldwin  36.829630                      95233
# 1     01049    Alabama      DeKalb  36.720000                      30289
# 2     01051    Alabama      Elmore  35.328829                      37590
# 3     01055    Alabama      Etowah  42.910494                      43252
# 4     01069    Alabama     Houston  35.729242                      45580
# ..      ...        ...         ...        ...                        ...
# 579   55117  Wisconsin   Sheboygan  48.171548                      62511
# 580   55127  Wisconsin    Walworth  41.915612                      58245
# 581   55133  Wisconsin    Waukesha  42.641096                     225674
# 582   56021    Wyoming     Laramie  44.331507                      48190
# 583   56025    Wyoming     Natrona  44.331507                      39259
#
#      Employed_2018  Unemployed_2018  Unemployment_rate_2018  \
# 0            91809             3424                     3.6
# 1            29153             1136                     3.8
# 2            36313             1277                     3.4
# 3            41502             1750                     4.0
# 4            43764             1816                     4.0
# ..             ...              ...                     ...
# 579          60949             1562                     2.5
# 580          56532             1713                     2.9
# 581         219707             5967                     2.6
# 582          46397             1793                     3.7
# 583          37509             1750                     4.5
#
#      Poverty Estimate, All Ages_2018  90% CI LB All Ages_2018  ...  \
# 0                            21069.0                  17390.0  ...
# 1                            14975.0                  13282.0  ...
# 2                             8559.0                   6765.0  ...
# 3                            17509.0                  15140.0  ...
# 4                            17032.0                  14978.0  ...
# ..                               ...                      ...  ...
# 579                           8432.0                   6839.0  ...
# 580                          10114.0                   8549.0  ...
# 581                          19937.0                  17306.0  ...
# 582                           8839.0                   7212.0  ...
# 583                           7677.0                   6133.0  ...
#
#      HWAC_MALE_ratio_2018  HWAC_FEMALE_ratio_2018  HBAC_MALE_ratio_2018  \
# 0                2.281334                2.053201              0.120722
# 1                6.814458                6.082037              0.263280
# 2                1.294886                1.308464              0.137018
# 3                1.727885                1.528101              0.158852
# 4                1.532882                1.356304              0.194712
# ..                    ...                     ...                   ...
# 579              3.164024                2.937527              0.131039
# 580              5.626268                4.988894              0.137132
# 581              2.295775                2.248573              0.080244
# 582              7.079351                6.603955              0.275123
# 583              4.061888                3.715819              0.157878
#
#      HBAC_FEMALE_ratio_2018  HIAC_MALE_ratio_2018  HIAC_FEMALE_ratio_2018  \
# 0                  0.120722              0.118427                0.085378
# 1                  0.207263              0.540563                0.441133
# 2                  0.175285              0.088877                0.076533
# 3                  0.135463              0.159827                0.128641
# 4                  0.189940              0.113582                0.102128
# ..                      ...                   ...                     ...
# 579                0.109344              0.140585                0.145792
# 580                0.118783              0.199903                0.163206
# 581                0.095647              0.077760                0.080741
# 582                0.258939              0.419764                0.412684
# 583                0.171771              0.445848                0.354910
#
#      HAAC_MALE_ratio_2018  HAAC_FEMALE_ratio_2018  HNAC_MALE_ratio_2018  \
# 0                0.028459                0.025705              0.022951
# 1                0.089627                0.096629              0.333301
# 2                0.019750                0.023454              0.023454
# 3                0.044830                0.038008              0.138387
# 4                0.038179                0.037224              0.024816
# ..                    ...                     ...                   ...
# 579              0.052068                0.052068              0.013017
# 580              0.055046                0.046354              0.019314
# 581              0.032545                0.031303              0.011925
# 582              0.138573                0.123401              0.044505
# 583              0.083360                0.074518              0.023997
#
#      HNAC_FEMALE_ratio_2018
# 0                  0.014230
# 1                  0.261879
# 2                  0.022219
# 3                  0.118896
# 4                  0.027680
# ..                      ...
# 579                0.009546
# 580                0.018349
# 581                0.009689
# 582                0.032367
# 583                0.031576
#
# [584 rows x 191 columns]

# %% [markdown]
# * df_2018 contains data on NorthEastern counties of the US
# * The columns of df_2018 go from average aqi, unemployment rate, poverty rate, education attainment ratio, total vehicle ratio, demographic ratios

# %%
klib.corr_plot(df_2018, target='AQI_2018', method='pearson')
klib.corr_plot(df_2018, target='AQI_2018', method='kendall')
klib.corr_plot(df_2018, target='AQI_2018', method='spearman')
# Out:
# <AxesSubplot:title={'center':'Feature-correlation (spearman)'}>

# %% [markdown]
# ## Make one df of 2019
# * Cleaning for datasets were done in Data_Wrangling4 and Data_Wrangling7 files
# * So only transforming datasets into one will work

# %%
avg_aqi_2019 = avg_aqi_2017_2019.iloc[:,[0, 1, 2, 5]]

unemploy_col_2019 = list(unemploy_rate_2017_2019.columns[0:1]) + list(unemploy_rate_2017_2019.columns[11:])
unemploy_rate_2019 = unemploy_rate_2017_2019.loc[:, unemploy_col_2019]

pov_col_2019 = list(pov_rate_2017_2019.columns[0:1]) + list(pov_rate_2017_2019.columns[45:])
pov_rate_2019 = pov_rate_2017_2019.loc[:, pov_col_2019]

incomes_2019 = county_incomes_2017_2019.iloc[:, [0, 4, 7]]

educ_vehicle_2019_col = list(educ_vehicle_2017_2019.columns[0:1]) + list(educ_vehicle_2017_2019.columns[34:])
educ_vehicle_2019 = educ_vehicle_2017_2019.loc[:, educ_vehicle_2019_col]

county_dem_ratio_2019_col = list(county_dem_ratio_2017_2019.columns[0:1]) + list(county_dem_ratio_2017_2019.columns[293:])
county_dem_ratio_2019 = county_dem_ratio_2017_2019.loc[:, county_dem_ratio_2019_col]

# %%
avg_aqi_unemploy_2019 = pd.merge(avg_aqi_2019, unemploy_rate_2019, how='inner')
avg_aqi_unemploy_pov_2019 = pd.merge(avg_aqi_unemploy_2019, pov_rate_2019, how='inner')
avg_aqi_unemploy_pov_inc_2019 = pd.merge(avg_aqi_unemploy_pov_2019, incomes_2019, how='inner')
avg_aqi_unemploy_pov_inc_educ_veh_2019 = pd.merge(avg_aqi_unemploy_pov_inc_2019, educ_vehicle_2019, how='inner')
df_2019 = pd.merge(avg_aqi_unemploy_pov_inc_educ_veh_2019, county_dem_ratio_2019, how='inner')

df_2019
# Out:
#     GeoFIPS State Name county Name   AQI_2019  Civilian_labor_force_2019  \
# 0     01003    Alabama     Baldwin  38.291513                      97328
# 1     01049    Alabama      DeKalb  39.711911                      31052
# 2     01051    Alabama      Elmore  38.421053                      37565
# 3     01055    Alabama      Etowah  41.666667                      42723
# 4     01069    Alabama     Houston  35.585714                      46234
# ..      ...        ...         ...        ...                        ...
# 579   55117  Wisconsin   Sheboygan  40.800971                      62144
# 580   55127  Wisconsin    Walworth  38.653659                      57872
# 581   55133  Wisconsin    Waukesha  41.254795                     224731
# 582   56021    Wyoming     Laramie  43.454795                      48491
# 583   56025    Wyoming     Natrona  42.153846                      39348
#
#      Employed_2019  Unemployed_2019  Unemployment_rate_2019  \
# 0            94675             2653                     2.7
# 1            30182              870                     2.8
# 2            36586              979                     2.6
# 3            41295             1428                     3.3
# 4            44844             1390                     3.0
# ..             ...              ...                     ...
# 579          60436             1708                     2.7
# 580          55975             1897                     3.3
# 581         218151             6580                     2.9
# 582          46813             1678                     3.5
# 583          37804             1544                     3.9
#
#      Poverty Estimate, All Ages_2019  90% CI LB All Ages_2019  ...  \
# 0                            22360.0                  18541.0  ...
# 1                            12848.0                  10674.0  ...
# 2                             8753.0                   6975.0  ...
# 3                            18801.0                  16286.0  ...
# 4                            20207.0                  18225.0  ...
# ..                               ...                      ...  ...
# 579                           9051.0                   7374.0  ...
# 580                           9532.0                   7892.0  ...
# 581                          18915.0                  16096.0  ...
# 582                           9194.0                   7774.0  ...
# 583                           7735.0                   6162.0  ...
#
#      HWAC_MALE_ratio_2019  HWAC_FEMALE_ratio_2019  HBAC_MALE_ratio_2019  \
# 0                2.304308                2.081224              0.120053
# 1                6.928810                6.186288              0.269881
# 2                1.382852                1.331133              0.146535
# 3                1.756170                1.607541              0.161341
# 4                1.564005                1.354338              0.189834
# ..                    ...                     ...                   ...
# 579              3.246922                3.014566              0.149991
# 580              5.648515                5.006354              0.141526
# 581              2.343406                2.297884              0.083870
# 582              7.128643                6.737688              0.269347
# 583              4.169902                3.735380              0.184077
#
#      HBAC_FEMALE_ratio_2019  HIAC_MALE_ratio_2019  HIAC_FEMALE_ratio_2019  \
# 0                  0.125877              0.118262                0.088248
# 1                  0.222337              0.546754                0.458658
# 2                  0.168701              0.096048                0.081272
# 3                  0.142762              0.166230                0.139829
# 4                  0.192667              0.114278                0.100111
# ..                      ...                   ...                     ...
# 579                0.108375              0.141321                0.150858
# 580                0.123233              0.206993                0.183887
# 581                0.098467              0.085602                0.085354
# 582                0.271357              0.423116                0.405025
# 583                0.187833              0.442035                0.363145
#
#      HAAC_MALE_ratio_2019  HAAC_FEMALE_ratio_2019  HNAC_MALE_ratio_2019  \
# 0                0.030909                0.029117              0.024638
# 1                0.099283                0.089494              0.321620
# 2                0.029553                0.029553              0.022165
# 3                0.041069                0.028357              0.142762
# 4                0.039667                0.034945              0.033056
# ..                    ...                     ...                   ...
# 579              0.047685                0.061557              0.014739
# 580              0.057766                0.043324              0.015404
# 581              0.036368                0.037111              0.012618
# 582              0.135678                0.125628              0.053266
# 583              0.082647                0.077638              0.021288
#
#      HNAC_FEMALE_ratio_2019
# 0                  0.015679
# 1                  0.267084
# 2                  0.022165
# 3                  0.122228
# 4                  0.033056
# ..                      ...
# 579                0.013872
# 580                0.024069
# 581                0.012123
# 582                0.045226
# 583                0.031306
#
# [584 rows x 191 columns]

# %% [markdown]
# * df_2019 contains data on NorthEastern counties of the US
# * The columns of df_2019 go from average aqi, unemployment rate, poverty rate, education attainment ratio, total vehicle ratio, demographic ratios

# %%
klib.corr_plot(df_2019, target='AQI_2019', method='pearson')
klib.corr_plot(df_2019, target='AQI_2019', method='kendall')
klib.corr_plot(df_2019, target='AQI_2019', method='spearman')
# Out:
# <AxesSubplot:title={'center':'Feature-correlation (spearman)'}>

# %% [markdown]
# # Merge dataframe into df 2017-2019

# %%
pd.set_option('display.max_columns', 200)

df_2017_2018 = pd.merge(df_2017, df_2018, how='inner')
df_2017_2019 = pd.merge(df_2017_2018, df_2019, how='inner')

df_2017_2019
# Out:
#     GeoFIPS State Name county Name   AQI_2017  Civilian_labor_force_2017  \
# 0     01003    Alabama     Baldwin  37.503704                      92456
# 1     01049    Alabama      DeKalb  38.239554                      29688
# 2     01051    Alabama      Elmore  34.371681                      37366
# 3     01055    Alabama      Etowah  45.630556                      43233
# 4     01069    Alabama     Houston  35.003559                      44882
# ..      ...        ...         ...        ...                        ...
# 579   55117  Wisconsin   Sheboygan  45.971429                      62584
# 580   55127  Wisconsin    Walworth  40.082305                      57960
# 581   55133  Wisconsin    Waukesha  40.573816                     226155
# 582   56021    Wyoming     Laramie  46.263014                      48230
# 583   56025    Wyoming     Natrona  45.383562                      39535
#
#      Employed_2017  Unemployed_2017  Unemployment_rate_2017  \
# 0            88711             3745                     4.1
# 1            28357             1331                     4.5
# 2            35990             1376                     3.7
# 3            41251             1982                     4.6
# 4            42923             1959                     4.4
# ..             ...              ...                     ...
# 579          60854             1730                     2.8
# 580          56062             1898                     3.3
# 581         219636             6519                     2.9
# 582          46472             1758                     3.6
# 583          37472             2063                     5.2
#
#      Poverty Estimate, All Ages_2017  90% CI LB All Ages_2017  \
# 0                            21199.0                  17444.0
# 1                            13785.0                  11467.0
# 2                             9151.0                   7348.0
# 3                            18257.0                  15600.0
# 4                            17095.0                  15498.0
# ..                               ...                      ...
# 579                           8789.0                   7300.0
# 580                          10618.0                   8877.0
# 581                          19090.0                  16633.0
# 582                           9294.0                   7767.0
# 583                           8631.0                   7133.0
#
#      90% CI UB All Ages_2017  Poverty Percent, All Ages_2017  \
# 0                    24954.0                            10.1
# 1                    16103.0                            19.5
# 2                    10954.0                            12.0
# 3                    20914.0                            18.1
# 4                    18692.0                            16.6
# ..                       ...                             ...
# 579                  10278.0                             7.8
# 580                  12359.0                            10.6
# 581                  21547.0                             4.8
# 582                  10821.0                             9.7
# 583                  10129.0                            11.1
#
#      90% CI LB percent_2017  90% CI UB percent_2017  \
# 0                  8.300000               11.900000
# 1                 16.200001               22.799999
# 2                  9.600000               14.400000
# 3                 15.500000               20.700001
# 4                 15.000000               18.200001
# ..                      ...                     ...
# 579                6.500000                9.100000
# 580                8.900000               12.300000
# 581                4.200000                5.400000
# 582                8.100000               11.300000
# 583                9.200000               13.000000
#
#      Poverty Estimate, Age 0-17_2017  90% CI LB percent 0-17_2017  \
# 0                             6734.0                       5079.0
# 1                             4799.0                       3840.0
# 2                             2979.0                       2250.0
# 3                             6399.0                       5373.0
# 4                             6301.0                       5621.0
# ..                               ...                          ...
# 579                           2482.0                       1861.0
# 580                           2515.0                       1903.0
# 581                           4251.0                       3459.0
# 582                           2625.0                       1967.0
# 583                           2509.0                       1878.0
#
#      90% CI UB 0-17_2017  Poverty Percent, Age 0-17_2017  \
# 0                 8389.0                       14.700000
# 1                 5758.0                       27.799999
# 2                 3708.0                       16.500000
# 3                 7425.0                       29.299999
# 4                 6981.0                       26.500000
# ..                   ...                             ...
# 579               3103.0                        9.800000
# 580               3127.0                       11.800000
# 581               5043.0                        5.000000
# 582               3283.0                       11.600000
# 583               3140.0                       13.300000
#
#      90% CI LB percent 0-17 percent_2017  90% CI UB 0-17 percent_2017  \
# 0                              11.100000                    18.299999
# 1                              22.200001                    33.400002
# 2                              12.500000                    20.500000
# 3                              24.600000                    34.000000
# 4                              23.600000                    29.400000
# ..                                   ...                          ...
# 579                             7.300000                    12.300000
# 580                             8.900000                    14.700000
# 581                             4.100000                     5.900000
# 582                             8.700000                    14.500000
# 583                            10.000000                    16.600000
#
#      Poverty Estimate, Age 5-17 in Families_2017  90% CI LB 5-17 fam_2017  \
# 0                                         4871.0                   3641.0
# 1                                         3468.0                   2739.0
# 2                                         2130.0                   1541.0
# 3                                         4369.0                   3594.0
# 4                                         4192.0                   3585.0
# ..                                           ...                      ...
# 579                                       1698.0                   1237.0
# 580                                       1768.0                   1306.0
# 581                                       2975.0                   2369.0
# 582                                       1723.0                   1244.0
# 583                                       1580.0                   1126.0
#
#      90% CI UB 5-17 fam_2017  Poverty Percent, Age 5-17 in Families_2017  \
# 0                     6101.0                                   14.300000
# 1                     4197.0                                   26.500000
# 2                     2719.0                                   15.900000
# 3                     5144.0                                   27.299999
# 4                     4799.0                                   23.799999
# ..                       ...                                         ...
# 579                   2159.0                                    9.000000
# 580                   2230.0                                   10.900000
# 581                   3581.0                                    4.600000
# 582                   2202.0                                   10.600000
# 583                   2034.0                                   11.800000
#
#      90% CI LB 5-17 percent_2017  90% CI UB percent 5-17 percent_2017  \
# 0                      10.700000                            17.900000
# 1                      20.900000                            32.099998
# 2                      11.500000                            20.299999
# 3                      22.500000                            32.099998
# 4                      20.299999                            27.299999
# ..                           ...                                  ...
# 579                     6.600000                            11.400000
# 580                     8.000000                            13.800000
# 581                     3.700000                             5.500000
# 582                     7.700000                            13.500000
# 583                     8.400000                            15.200000
#
#      Median Household Income_2017  90% CI Lower Bound LB medh inc_2017  \
# 0                         56607.0                              52439.0
# 1                         39906.0                              36346.0
# 2                         59652.0                              55049.0
# 3                         41791.0                              38946.0
# 4                         44753.0                              42919.0
# ..                            ...                                  ...
# 579                       59231.0                              56414.0
# 580                       60675.0                              57763.0
# 581                       82627.0                              80538.0
# 582                       61658.0                              57377.0
# 583                       61049.0                              57867.0
#
#      90% CI UB medh inc_2017  Personal income (thousands of dollars) 2017  \
# 0                    60775.0                                    9471242.0
# 1                    43466.0                                    2251689.0
# 2                    64255.0                                    3368910.0
# 3                    44636.0                                    3714857.0
# 4                    46587.0                                    4314958.0
# ..                       ...                                          ...
# 579                  62048.0                                    5849961.0
# 580                  63587.0                                    4915121.0
# 581                  84716.0                                   27650656.0
# 582                  65939.0                                    4888842.0
# 583                  64231.0                                    4994150.0
#
#      Per capita personal income (dollars) 2017  POP_2017  EDU_TOT_2017  \
# 0                                      44566.0    212628      152037.0
# 1                                      31520.0     71617       47604.0
# 2                                      41376.0     81677       55782.0
# 3                                      36064.0    102755       71846.0
# 4                                      41340.0    104346       72149.0
# ..                                         ...       ...           ...
# 579                                    50830.0    115344       79984.0
# 580                                    47789.0    103082       68366.0
# 581                                    68972.0    400621      282781.0
# 582                                    49695.0     98327       67446.0
# 583                                    62752.0     79547       53481.0
#
#      LESS_HS_TOT_2017  HS_TOT_2017  COL_OR_ASSOC_TOT_2017  BACH_TOT_2017  \
# 0             16318.0      38283.0                46361.0        34927.0
# 1             10814.0      17808.0                11785.0         4680.0
# 2              7464.0      17495.0                16958.0         8913.0
# 3             11545.0      23817.0                22602.0         8372.0
# 4              9340.0      23435.0                23478.0         9858.0
# ..                ...          ...                    ...            ...
# 579            5465.0      27886.0                26510.0        14080.0
# 580            6169.0      20863.0                20682.0        13057.0
# 581           10489.0      64016.0                79712.0        85939.0
# 582            5457.0      17351.0                25811.0        10821.0
# 583            3667.0      15424.0                21423.0         8442.0
#
#      GRAD_TOT_2017  VEHICLE_TOT_2017  EDU_TOT_ratio_2017  \
# 0          16148.0             79160           71.503753
# 1           2517.0             24955           66.470251
# 2           4952.0             31750           68.295848
# 3           5510.0             34170           69.919712
# 4           6038.0             41980           69.144002
# ..             ...               ...                 ...
# 579         6043.0             50070           69.343876
# 580         7595.0             46380           66.321957
# 581        42625.0            188650           70.585666
# 582         8006.0             40195           68.593570
# 583         4525.0             34120           67.231951
#
#      LESS_HS_TOT_ratio_2017  HS_TOT_ratio_2017  COL_OR_ASSOC_TOT_ratio_2017  \
# 0                  7.674436          18.004684                    21.803808
# 1                 15.099767          24.865605                    16.455590
# 2                  9.138436          21.419739                    20.762271
# 3                 11.235463          23.178434                    21.996010
# 4                  8.950990          22.458935                    22.500144
# ..                      ...                ...                          ...
# 579                4.738001          24.176377                    22.983423
# 580                5.984556          20.239227                    20.063639
# 581                2.618185          15.979192                    19.897110
# 582                5.549849          17.646221                    26.250165
# 583                4.609853          19.389795                    26.931248
#
#      BACH_TOT_ratio_2017  GRAD_TOT_ratio_2017  VEHICLE_TOT_ratio_2017  \
# 0              16.426341             7.594484               37.229340
# 1               6.534761             3.514529               34.845079
# 2              10.912497             6.062906               38.872632
# 3               8.147535             5.362269               33.253856
# 4               9.447415             5.786518               40.231537
# ..                   ...                  ...                     ...
# 579            12.206964             5.239111               43.409280
# 580            12.666615             7.367921               44.993306
# 581            21.451447            10.639732               47.089394
# 582            11.005116             8.142219               40.878904
# 583            10.612594             5.688461               42.892881
#
#      TOT_POP_2017  TOT_MALE_2017  TOT_FEMALE_2017  WA_MALE_2017  \
# 0          212521         103218           109303         90360
# 1           71437          35486            35951         32860
# 2           81422          39433            41989         29779
# 3          103007          49812            53195         40529
# 4          104378          50115            54263         35245
# ..            ...            ...              ...           ...
# 579        115089          57900            57189         51753
# 580        102850          51275            51575         49046
# 581        400899         197103           203796        182988
# 582         98377          49952            48425         45658
# 583         79586          40077            39509         37690
#
#      WA_FEMALE_2017  BA_MALE_2017  BA_FEMALE_2017  IA_MALE_2017  \
# 0             95215          9279            9973           861
# 1             33495           681             635           721
# 2             31969          8474            8704           221
# 3             42793          7540            8637           326
# 4             37262         13106           15001           257
# ..              ...           ...             ...           ...
# 579           51785          1593             831           315
# 580           49490           705             586           284
# 581          189406          3507            3121           614
# 582           44710          1618            1028           571
# 583           37198           562             480           628
#
#      IA_FEMALE_2017  AA_MALE_2017  AA_FEMALE_2017  NA_MALE_2017  \
# 0               772           864            1361            69
# 1               696           185             165           241
# 2               200           258             328            48
# 3               272           423             420           164
# 4               292           433             626            35
# ..              ...           ...             ...           ...
# 579             316          3238            3241            31
# 580             227           522             596            28
# 581             625          7090            7669            92
# 582             599           604             685            68
# 583             498           293             370            40
#
#      NA_FEMALE_2017  TOM_MALE_2017  TOM_FEMALE_2017  WAC_MALE_2017  \
# 0                69           1785             1913          92039
# 1               187            798              773          33608
# 2                46            653              742          30374
# 3               136            830              937          41314
# 4                49           1039             1033          36169
# ..              ...            ...              ...            ...
# 579              32            970              984          52676
# 580              29            690              647          49703
# 581              96           2812             2879         185719
# 582              65           1433             1338          47029
# 583              46            864              917          38518
#
#      WAC_FEMALE_2017  BAC_MALE_2017  BAC_FEMALE_2017  IAC_MALE_2017  \
# 0              97007          10009            10791           1706
# 1              34207            881              816           1288
# 2              32640           8791             9065            459
# 3              43679           7963             9114            689
# 4              38177          13681            15562            638
# ..               ...            ...              ...            ...
# 579            52724           2089             1312            601
# 580            50108            999              864            554
# 581           192173           4636             4304           1307
# 582            45976           2176             1561           1107
# 583            38076            880              841           1029
#
#      IAC_FEMALE_2017  AAC_MALE_2017  AAC_FEMALE_2017  NAC_MALE_2017  \
# 0               1638           1261             1794            158
# 1               1259            249              224            271
# 2                481            417              508             79
# 3                672            517              536            185
# 4                678            627              832             85
# ..               ...            ...              ...            ...
# 579              613           3497             3508             64
# 580              464            701              764             54
# 581             1351           8241             8803            190
# 582             1084           1019             1077            153
# 583              896            473              573             93
#
#      NAC_FEMALE_2017  NH_MALE_2017  NH_FEMALE_2017  NHWA_MALE_2017  \
# 0                168         98087          104753           85754
# 1                227         29949           31075           28168
# 2                 87         38254           40746           28794
# 3                162         47723           51337           38933
# 4                100         48277           52630           33757
# ..               ...           ...             ...             ...
# 579               69         54108           53660           48316
# 580               55         45221           46171           43408
# 581              201        187545          194478          174164
# 582              142         42411           41471           38921
# 583               96         36586           36319           34716
#
#      NHWA_FEMALE_2017  NHBA_MALE_2017  NHBA_FEMALE_2017  NHIA_MALE_2017  \
# 0               91114            9105              9783             735
# 1               29302             529               515             421
# 2               30939            8396              8596             179
# 3               41352            7418              8529             204
# 4               35957           12977             14858             187
# ..                ...             ...               ...             ...
# 579             48603            1500               755             229
# 580             44442             607               493             139
# 581            180876            3325              2882             438
# 582             38518            1465               887             296
# 583             34444             490               417             402
#
#      NHIA_FEMALE_2017  NHAA_MALE_2017  NHAA_FEMALE_2017  NHNA_MALE_2017  \
# 0                 704             850              1352              45
# 1                 453             134               114              19
# 2                 158             249               317              34
# 3                 177             387               391              25
# 4                 226             413               605              19
# ..                ...             ...               ...             ...
# 579               210            3202              3195              22
# 580               108             484               561              18
# 581               456            7022              7616              59
# 582               323             542               627              43
# 583               336             255               344              34
#
#      NHNA_FEMALE_2017  NHTOM_MALE_2017  NHTOM_FEMALE_2017  NHWAC_MALE_2017  \
# 0                  59             1598               1741            87272
# 1                  19              678                672            28816
# 2                  35              602                701            29343
# 3                  22              756                866            39654
# 4                  33              924                951            34585
# ..                ...              ...                ...              ...
# 579                24              839                873            49116
# 580                13              565                554            43950
# 581                77             2537               2571           176633
# 582                49             1144               1067            40018
# 583                32              689                746            35381
#
#      NHWAC_FEMALE_2017  NHBAC_MALE_2017  NHBAC_FEMALE_2017  NHIAC_MALE_2017  \
# 0                92755             9750              10521             1466
# 1                29937              695                663              908
# 2                31577             8690               8931              390
# 3                42175             7800               8964              536
# 4                36796            13488              15379              518
# ..                 ...              ...                ...              ...
# 579              49437             1934               1193              447
# 580              44970              852                736              335
# 581             183356             4330               3934             1007
# 582              39532             1916               1315              681
# 583              35163              754                722              687
#
#      NHIAC_FEMALE_2017  NHAAC_MALE_2017  NHAAC_FEMALE_2017  NHNAC_MALE_2017  \
# 0                 1476             1219               1738              114
# 1                  949              188                162               32
# 2                  425              401                488               62
# 3                  547              468                498               42
# 4                  573              585                794               58
# ..                 ...              ...                ...              ...
# 579                443             3442               3445               48
# 580                299              643                713               36
# 581               1045             8115               8683              135
# 582                666              907                966              109
# 583                624              414                515               76
#
#      NHNAC_FEMALE_2017  H_MALE_2017  H_FEMALE_2017  HWA_MALE_2017  \
# 0                  128         5131           4550           4606
# 1                   42         5537           4876           4692
# 2                   70         1179           1243            985
# 3                   44         2089           1858           1596
# 4                   80         1838           1633           1488
# ..                 ...          ...            ...            ...
# 579                 54         3792           3529           3437
# 580                 33         6054           5404           5638
# 581                161         9558           9318           8824
# 582                114         7541           6954           6737
# 583                 76         3491           3190           2974
#
#      HWA_FEMALE_2017  HBA_MALE_2017  ...  NHAAC_MALE_2019  NHAAC_FEMALE_2019  \
# 0               4101            174  ...             1336               1881
# 1               4193            152  ...              200                162
# 2               1030             78  ...              426                501
# 3               1441            122  ...              489                513
# 4               1305            129  ...              652                838
# ..               ...            ...  ...              ...                ...
# 579             3182             93  ...             3561               3500
# 580             5048             98  ...              663                706
# 581             8530            182  ...             8654               9139
# 582             6192            153  ...              969               1013
# 583             2754             72  ...              428                558
#
#      NHNAC_MALE_2019  NHNAC_FEMALE_2019  H_MALE_2019  H_FEMALE_2019  \
# 0                125                152         5545           4989
# 1                 36                 41         5715           5059
# 2                 58                 69         1289           1274
# 3                 44                 48         2225           2005
# 4                 65                 92         1920           1711
# ..               ...                ...          ...            ...
# 579               58                 50         3991           3724
# 580               36                 36         6167           5470
# 581              170                164        10013           9840
# 582              110                111         7627           7216
# 583               83                 73         3687           3282
#
#      HWA_MALE_2019  HWA_FEMALE_2019  HBA_MALE_2019  HBA_FEMALE_2019  \
# 0             4965             4486            178              200
# 1             4852             4348            161              122
# 2             1066             1044             88              113
# 3             1717             1577            120              106
# 4             1554             1355            141              150
# ..             ...              ...            ...              ...
# 579           3610             3360             99               77
# 580           5749             5095            103               93
# 581           9182             8951            215              254
# 582           6803             6431            148              149
# 583           3135             2801             71               79
#
#      HIA_MALE_2019  HIA_FEMALE_2019  HAA_MALE_2019  HAA_FEMALE_2019  \
# 0              150               85             21               13
# 1              310              259             57               56
# 2               50               49              9               12
# 3              129              107             30               20
# 4               69               70             21               21
# ..             ...              ...            ...              ...
# 579             89              108             36               50
# 580            140              122             38               34
# 581            212              187             69               66
# 582            255              256             75               57
# 583            230              166             41               28
#
#      HNA_MALE_2019  HNA_FEMALE_2019  HTOM_MALE_2019  HTOM_FEMALE_2019  \
# 0               21               10             210               195
# 1              215              173             120               101
# 2               12               13              64                43
# 3              141              120              88                75
# 4               17               19             118                96
# ..             ...              ...             ...               ...
# 579             12                8             145               121
# 580             11               17             126               109
# 581             28               26             307               356
# 582             30               28             316               295
# 583              6               12             204               196
#
#      HWAC_MALE_2019  HWAC_FEMALE_2019  HBAC_MALE_2019  HBAC_FEMALE_2019  \
# 0              5144              4646             268               281
# 1              4955              4424             193               159
# 2              1123              1081             119               137
# 3              1796              1644             165               146
# 4              1656              1434             201               204
# ..              ...               ...             ...               ...
# 579            3745              3477             173               125
# 580            5867              5200             147               128
# 581            9472              9288             339               398
# 582            7093              6704             268               270
# 583            3330              2983             147               150
#
#      HIAC_MALE_2019  HIAC_FEMALE_2019  HAAC_MALE_2019  HAAC_FEMALE_2019  \
# 0               264               197              69                65
# 1               391               328              71                64
# 2                78                66              24                24
# 3               170               143              42                29
# 4               121               106              42                37
# ..              ...               ...             ...               ...
# 579             163               174              55                71
# 580             215               191              60                45
# 581             346               345             147               150
# 582             421               403             135               125
# 583             353               290              66                62
#
#      HNAC_MALE_2019  HNAC_FEMALE_2019  TOT_MALE_ratio_2019  \
# 0                55                35            48.490373
# 1               230               191            49.748997
# 2                18                18            48.314842
# 3               146               125            48.398326
# 4                35                35            47.815493
# ..              ...               ...                  ...
# 579              17                16            50.430033
# 580              16                25            49.994223
# 581              51                49            49.203608
# 582              53                45            50.666332
# 583              17                25            50.403216
#
#      TOT_FEMALE_ratio_2019  WA_MALE_ratio_2019  WA_FEMALE_ratio_2019  \
# 0                51.509627           42.471129             44.969852
# 1                50.251003           45.963671             46.750940
# 2                51.685158           36.542748             39.139751
# 3                51.601674           39.225369             41.446005
# 4                52.184507           33.352222             35.471563
# ..                     ...                 ...                   ...
# 579              49.569967           44.821398             44.732096
# 580              50.005777           47.811646             47.970501
# 581              50.796392           45.456930             47.015077
# 582              49.333668           46.322613             45.528643
# 583              49.596784           47.300208             46.429913
#
#      BA_MALE_ratio_2019  BA_FEMALE_ratio_2019  IA_MALE_ratio_2019  \
# 0              4.249353              4.527536            0.404508
# 1              0.962063              0.911722            1.040370
# 2             10.275955             10.878105            0.261055
# 3              7.374741              8.370165            0.326593
# 4             12.688653             14.677660            0.242723
# ..                  ...                   ...                 ...
# 579            1.488642              0.796775            0.299116
# 580            0.677783              0.564178            0.266685
# 581            0.923310              0.831028            0.168729
# 582            1.525628              0.996985            0.561809
# 583            0.722532              0.712515            0.816449
#
#      IA_FEMALE_ratio_2019  AA_MALE_ratio_2019  AA_FEMALE_ratio_2019  \
# 0                0.375839            0.417499              0.648647
# 1                0.981640            0.278271              0.240516
# 2                0.247510            0.332475              0.418673
# 3                0.286502            0.402863              0.419486
# 4                0.299390            0.450502              0.623335
# ..                    ...                 ...                   ...
# 579              0.287845            2.906190              2.865441
# 580              0.222398            0.518928              0.559364
# 581              0.167245            1.858248              1.985413
# 582              0.584925            0.652261              0.706533
# 583              0.686218            0.376919              0.497132
#
#      NA_MALE_ratio_2019  NA_FEMALE_ratio_2019  TOM_MALE_ratio_2019  \
# 0              0.033149              0.035837             0.914735
# 1              0.335603              0.271279             1.169018
# 2              0.055413              0.057875             0.847197
# 3              0.162319              0.135917             0.906442
# 4              0.036833              0.054778             1.044559
# ..                  ...                   ...                  ...
# 579            0.032079              0.026877             0.882608
# 580            0.027920              0.029846             0.691262
# 581            0.023751              0.026472             0.772641
# 582            0.081407              0.075377             1.522613
# 583            0.048837              0.040071             1.138270
#
#      TOM_FEMALE_ratio_2019  WAC_MALE_ratio_2019  WAC_FEMALE_ratio_2019  \
# 0                 0.951916            43.331213              45.859054
# 1                 1.094906            47.075357              47.763344
# 2                 0.943245            37.314830              40.006650
# 3                 0.943599            40.079986              42.338757
# 4                 1.057781            34.274003              36.402788
# ..                     ...                  ...                    ...
# 579               0.860933            45.665857              45.553147
# 580               0.659491            48.477876              48.598221
# 581               0.771157            46.206562              47.766936
# 582               1.441206            47.766834              46.893467
# 583               1.230935            48.398407              47.613264
#
#      BAC_MALE_ratio_2019  BAC_FEMALE_ratio_2019  IAC_MALE_ratio_2019  \
# 0               4.634599               4.931148             0.814392
# 1               1.265504               1.195587             1.847217
# 2              10.687239              11.337413             0.547969
# 3               7.845074               8.871788             0.698166
# 4              13.262878              15.269829             0.615780
# ..                   ...                    ...                  ...
# 579             1.942084               1.226808             0.557482
# 580             0.973351               0.836639             0.530481
# 581             1.232069               1.145726             0.350571
# 582             2.130653               1.594975             1.112563
# 583             1.157054               1.209647             1.311077
#
#      IAC_FEMALE_ratio_2019  AAC_MALE_ratio_2019  AAC_FEMALE_ratio_2019  \
# 0                 0.799609             0.629384               0.871731
# 1                 1.763316             0.378952               0.316026
# 2                 0.582448             0.554126               0.646480
# 3                 0.662964             0.519224               0.529980
# 4                 0.665836             0.655447               0.826392
# ..                     ...                  ...                    ...
# 579               0.554881             3.135079               3.096064
# 580               0.481380             0.696076               0.723033
# 581               0.355519             2.177398               2.298131
# 582               1.074372             1.109548               1.143719
# 583               1.195873             0.618598               0.776378
#
#      NAC_MALE_ratio_2019  NAC_FEMALE_ratio_2019  NH_MALE_ratio_2019  \
# 0               0.080633               0.083769           46.006433
# 1               0.371960               0.324417           41.757443
# 2               0.093586               0.107131           46.727579
# 3               0.185786               0.169163           46.222670
# 4               0.094445               0.119945           46.002153
# ..                   ...                    ...                 ...
# 579             0.065025               0.057222           46.969828
# 580             0.050064               0.058728           44.056880
# 581             0.054676               0.052697           46.726357
# 582             0.163819               0.156784           43.001005
# 583             0.125222               0.122718           45.786271
#
#      NH_FEMALE_ratio_2019  NHWA_MALE_ratio_2019  NHWA_FEMALE_ratio_2019  \
# 0               49.274752             40.247005               42.960302
# 1               43.176765             39.178891               40.670927
# 2               50.116366             35.230085               37.854179
# 3               49.641139             37.546447               39.903978
# 4               50.568557             31.884551               34.191836
# ..                    ...                   ...                     ...
# 579             46.341252             41.691521               41.818970
# 580             44.739477             42.276736               43.065237
# 581             48.361941             43.185271               44.800568
# 582             42.081407             39.485427               39.065327
# 583             45.486989             43.374490               42.922437
#
#      NHBA_MALE_ratio_2019  NHBA_FEMALE_ratio_2019  NHIA_MALE_ratio_2019  \
# 0                4.169616                4.437944              0.337314
# 1                0.736929                0.741124              0.606883
# 2               10.167592               10.738958              0.199485
# 3                7.257402                8.266515              0.200454
# 4               12.555486               14.535993              0.177556
# ..                    ...                     ...                   ...
# 579              1.402809                0.730016              0.221952
# 580              0.578619                0.474641              0.131898
# 581              0.870118                0.768188              0.116280
# 582              1.376884                0.847236              0.305528
# 583              0.633625                0.613589              0.528438
#
#      NHIA_FEMALE_ratio_2019  NHAA_MALE_ratio_2019  NHAA_FEMALE_ratio_2019  \
# 0                  0.337762              0.408092                0.642823
# 1                  0.619468              0.198565                0.162208
# 2                  0.187171              0.321393                0.403896
# 3                  0.181875              0.373528                0.399930
# 4                  0.233279              0.430668                0.603502
# ..                      ...                   ...                     ...
# 579                0.194208              2.874978                2.822091
# 580                0.104941              0.482343                0.526630
# 581                0.120980              1.841177                1.969084
# 582                0.327638              0.576884                0.649246
# 583                0.478349              0.325578                0.462070
#
#      NHNA_MALE_ratio_2019  NHNA_FEMALE_ratio_2019  NHTOM_MALE_ratio_2019  \
# 0                0.023742                0.031357               0.820664
# 1                0.034959                0.029365               1.001217
# 2                0.040636                0.041867               0.768388
# 3                0.024446                0.018579               0.820393
# 4                0.020778                0.036833               0.933114
# ..                    ...                     ...                    ...
# 579              0.021675                0.019941               0.756893
# 580              0.017330                0.013479               0.569954
# 581              0.016823                0.020040               0.696688
# 582              0.051256                0.047236               1.205025
# 583              0.041323                0.025044               0.882817
#
#      NHTOM_FEMALE_ratio_2019  NHWAC_MALE_ratio_2019  NHWAC_FEMALE_ratio_2019  \
# 0                   0.864564              41.026905                43.777830
# 1                   0.953673              40.146547                41.577056
# 2                   0.890295              35.931978                38.675516
# 3                   0.870262              38.323816                40.731216
# 4                   0.967114              32.709998                35.048450
# ..                       ...                    ...                      ...
# 579                 0.756026              42.418935                42.538582
# 580                 0.554550              42.829360                43.591867
# 581                 0.683081              43.863156                45.469052
# 582                 1.144724              40.638191                40.155779
# 583                 0.985499              44.228506                43.877883
#
#      NHBAC_MALE_ratio_2019  NHBAC_FEMALE_ratio_2019  NHIAC_MALE_ratio_2019  \
# 0                 4.514545                 4.805272               0.696131
# 1                 0.995623                 0.973250               1.300463
# 2                10.540704                11.168713               0.451920
# 3                 7.683733                 8.729026               0.531936
# 4                13.073044                15.077161               0.501502
# ..                     ...                      ...                    ...
# 579               1.792093                 1.118432               0.416161
# 580               0.831825                 0.713405               0.323488
# 581               1.148200                 1.047259               0.264969
# 582               1.861307                 1.323618               0.689447
# 583               0.972977                 1.021814               0.869043
#
#      NHIAC_FEMALE_ratio_2019  NHAAC_MALE_ratio_2019  NHAAC_FEMALE_ratio_2019  \
# 0                   0.711361               0.598475                 0.842614
# 1                   1.304658               0.279669                 0.226532
# 2                   0.501176               0.524572                 0.616927
# 3                   0.523135               0.478155                 0.501623
# 4                   0.565724               0.615780                 0.791447
# ..                       ...                    ...                      ...
# 579                 0.404023               3.087394                 3.034507
# 580                 0.297493               0.638310                 0.679709
# 581                 0.270165               2.141030                 2.261021
# 582                 0.669347               0.973869                 1.018090
# 583                 0.832728               0.535951                 0.698740
#
#      NHNAC_MALE_ratio_2019  NHNAC_FEMALE_ratio_2019  H_MALE_ratio_2019  \
# 0                 0.055995                 0.068090           2.483941
# 1                 0.050340                 0.057332           7.991554
# 2                 0.071421                 0.084966           1.587262
# 3                 0.043024                 0.046936           2.175656
# 4                 0.061389                 0.086889           1.813339
# ..                     ...                      ...                ...
# 579               0.050286                 0.043350           3.460205
# 580               0.034659                 0.034659           5.937344
# 581               0.042059                 0.040574           2.477251
# 582               0.110553                 0.111558           7.665327
# 583               0.103934                 0.091412           4.616945
#
#      H_FEMALE_ratio_2019  HWA_MALE_ratio_2019  HWA_FEMALE_ratio_2019  \
# 0               2.234875             2.224124               2.009551
# 1               7.074238             6.784780               6.080013
# 2               1.568792             1.312662               1.285572
# 3               1.960535             1.678922               1.542027
# 4               1.615950             1.467672               1.279726
# ..                   ...                  ...                    ...
# 579             3.228715             3.129877               2.913126
# 580             5.266300             5.534910               4.905264
# 581             2.434450             2.271659               2.214509
# 582             7.252261             6.837186               6.463317
# 583             4.109795             3.925718               3.507476
#
#      HBA_MALE_ratio_2019  HBA_FEMALE_ratio_2019  HIA_MALE_ratio_2019  \
# 0               0.079737               0.089592             0.067194
# 1               0.225134               0.170598             0.433488
# 2               0.108362               0.139147             0.061570
# 3               0.117339               0.103649             0.126139
# 4               0.133167               0.141667             0.065167
# ..                   ...                    ...                  ...
# 579             0.085833               0.066759             0.077163
# 580             0.099164               0.089537             0.134786
# 581             0.053192               0.062840             0.052450
# 582             0.148744               0.149749             0.256281
# 583             0.088908               0.098926             0.288011
#
#      HIA_FEMALE_ratio_2019  HAA_MALE_ratio_2019  HAA_FEMALE_ratio_2019  \
# 0                 0.038077             0.009407               0.005823
# 1                 0.362172             0.079706               0.078307
# 2                 0.060338             0.011083               0.014777
# 3                 0.104627             0.029335               0.019556
# 4                 0.066111             0.019833               0.019833
# ..                     ...                  ...                    ...
# 579               0.093636             0.031212               0.043350
# 580               0.117457             0.036585               0.032734
# 581               0.046264             0.017071               0.016329
# 582               0.257286             0.075377               0.057286
# 583               0.207869             0.051341               0.035062
#
#      HNA_MALE_ratio_2019  HNA_FEMALE_ratio_2019  HTOM_MALE_ratio_2019  \
# 0               0.009407               0.004480              0.094072
# 1               0.300645               0.241914              0.167802
# 2               0.014777               0.016008              0.078809
# 3               0.137873               0.117339              0.086048
# 4               0.016056               0.017945              0.111445
# ..                   ...                    ...                   ...
# 579             0.010404               0.006936              0.125715
# 580             0.010590               0.016367              0.121308
# 581             0.006927               0.006432              0.075953
# 582             0.030151               0.028141              0.317588
# 583             0.007513               0.015027              0.255453
#
#      HTOM_FEMALE_ratio_2019  HWAC_MALE_ratio_2019  HWAC_FEMALE_ratio_2019  \
# 0                  0.087352              2.304308                2.081224
# 1                  0.141233              6.928810                6.186288
# 2                  0.052950              1.382852                1.331133
# 3                  0.073337              1.756170                1.607541
# 4                  0.090667              1.564005                1.354338
# ..                      ...                   ...                     ...
# 579                0.104907              3.246922                3.014566
# 580                0.104941              5.648515                5.006354
# 581                0.088076              2.343406                2.297884
# 582                0.296482              7.128643                6.737688
# 583                0.245436              4.169902                3.735380
#
#      HBAC_MALE_ratio_2019  HBAC_FEMALE_ratio_2019  HIAC_MALE_ratio_2019  \
# 0                0.120053                0.125877              0.118262
# 1                0.269881                0.222337              0.546754
# 2                0.146535                0.168701              0.096048
# 3                0.161341                0.142762              0.166230
# 4                0.189834                0.192667              0.114278
# ..                    ...                     ...                   ...
# 579              0.149991                0.108375              0.141321
# 580              0.141526                0.123233              0.206993
# 581              0.083870                0.098467              0.085602
# 582              0.269347                0.271357              0.423116
# 583              0.184077                0.187833              0.442035
#
#      HIAC_FEMALE_ratio_2019  HAAC_MALE_ratio_2019  HAAC_FEMALE_ratio_2019  \
# 0                  0.088248              0.030909                0.029117
# 1                  0.458658              0.099283                0.089494
# 2                  0.081272              0.029553                0.029553
# 3                  0.139829              0.041069                0.028357
# 4                  0.100111              0.039667                0.034945
# ..                      ...                   ...                     ...
# 579                0.150858              0.047685                0.061557
# 580                0.183887              0.057766                0.043324
# 581                0.085354              0.036368                0.037111
# 582                0.405025              0.135678                0.125628
# 583                0.363145              0.082647                0.077638
#
#      HNAC_MALE_ratio_2019  HNAC_FEMALE_ratio_2019
# 0                0.024638                0.015679
# 1                0.321620                0.267084
# 2                0.022165                0.022165
# 3                0.142762                0.122228
# 4                0.033056                0.033056
# ..                    ...                     ...
# 579              0.014739                0.013872
# 580              0.015404                0.024069
# 581              0.012618                0.012123
# 582              0.053266                0.045226
# 583              0.021288                0.031306
#
# [584 rows x 567 columns]

# %% [markdown]
# # save data

# %%
# save 2017-2019 dataset
data_path = r'../../data/processed/all_df_2017_2019'
df_2017_2019.to_csv(data_path, index=False)

# save datasets for individual years
data_path = r'../../data/processed/all_df_2017'
df_2017.to_csv(data_path, index=False)
data_path = r'../../data/processed/all_df_2018'
df_2018.to_csv(data_path, index=False)
data_path = r'../../data/processed/all_df_2019'
df_2019.to_csv(data_path, index=False)

# %%
display(df_2017.corr()['AQI_2017'].sort_values().tail(15))
display(df_2018.corr()['AQI_2018'].sort_values().tail(15))
display(df_2019.corr()['AQI_2019'].sort_values().tail(15))
# Out:
# HAA_FEMALE_2017          0.415021
# HAAC_MALE_2017           0.415654
# HAAC_FEMALE_2017         0.415682
# IA_MALE_2017             0.419897
# HAA_FEMALE_ratio_2017    0.424264
# HTOM_FEMALE_2017         0.434658
# HAA_MALE_ratio_2017      0.434679
# HTOM_MALE_2017           0.440040
# HIA_MALE_2017            0.442118
# HIA_FEMALE_2017          0.443410
# IAC_FEMALE_2017          0.444347
# IAC_MALE_2017            0.448977
# HIAC_MALE_2017           0.457833
# HIAC_FEMALE_2017         0.458071
# AQI_2017                 1.000000
# Name: AQI_2017, dtype: float64
# HAA_MALE_2018            0.430706
# WAC_MALE_2018            0.432205
# COL_OR_ASSOC_TOT_2018    0.436336
# HAA_MALE_ratio_2018      0.443019
# HTOM_FEMALE_2018         0.446144
# IA_FEMALE_2018           0.450461
# HTOM_MALE_2018           0.450952
# IA_MALE_2018             0.459532
# HIA_MALE_2018            0.470289
# HIA_FEMALE_2018          0.471187
# IAC_FEMALE_2018          0.479238
# IAC_MALE_2018            0.483922
# HIAC_FEMALE_2018         0.484120
# HIAC_MALE_2018           0.484217
# AQI_2018                 1.000000
# Name: AQI_2018, dtype: float64
# Unemployed_2019            0.452189
# WA_FEMALE_2019             0.452649
# WAC_FEMALE_2019            0.452967
# WA_MALE_2019               0.455182
# WAC_MALE_2019              0.455293
# 90% CI UB 0-17_2019        0.455602
# IAC_FEMALE_2019            0.456022
# 90% CI UB 5-17 fam_2019    0.458400
# IAC_MALE_2019              0.461095
# COL_OR_ASSOC_TOT_2019      0.462045
# HIA_FEMALE_2019            0.468722
# HIA_MALE_2019              0.469227
# HIAC_FEMALE_2019           0.472862
# HIAC_MALE_2019             0.474078
# AQI_2019                   1.000000
# Name: AQI_2019, dtype: float64

# %%
display(df_2017.shape)
display(df_2018.shape)
display(df_2019.shape)
# Out:
# (584, 191)
# (584, 191)
# (584, 191)
